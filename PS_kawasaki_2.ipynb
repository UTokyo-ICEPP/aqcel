# %%
from sample.onestepSim_LBNL import runQuantum as step_1
circuit_LBNL1 = step_1(gLR=1,dophisplit=1)
#circuit_LBNL1.draw('mpl',fold=100)

import icepp

# %%
backend_name = 'ibm_kawasaki'

# %%
from qiskit import *
IBMQ.load_account()
from pytket.extensions.qiskit import IBMQBackend, AerStateBackend, AerBackend

# Fill your provider information
# Example: provider = IBMQ.get_provider(hub=ibm-q'',group='open',project='main')
provider = IBMQ.get_provider(hub='',group='',project='')

backend = provider.get_backend(backend_name)
sim_b = AerBackend()
dev_b = IBMQBackend(backend_name=backend_name, hub='',group='',project='')

# %%
"""
import csv
header = ['name', 'original circuit', 'transpiled circuit', 'gate counts', 'depth', 'qubits', 'raw counts', 'F_sim', 'F_meas']

with open(backend_name+'_1step_qc.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(header)

f.close()
"""
# Out:
# "\nimport csv\nheader = ['name', 'original circuit', 'transpiled circuit', 'gate counts', 'depth', 'qubits', 'raw counts', 'F_sim', 'F_meas']\n\nwith open(backend_name+'_1step_qc.csv', 'w') as f:\n    writer = csv.writer(f)\n    writer.writerow(header)\n\nf.close()\n"

# %%
import csv
import math
from decimal import Decimal, ROUND_HALF_UP, ROUND_HALF_EVEN
def run(step, backend, threshold, qc_qcs, shots):
    
    if step == 1:
        ps = step_1(gLR=1,dophisplit=1)
    if step == 2:
        ps = step_2(gLR=1,dophisplit=1)
    
    b_qc = qc_qcs[0]
    t_qc = qc_qcs[1]
    counts = analysis(t_qc)
    
    simulation = dic_size(ps)
    Fsim = fidelity(simulation, dic_size(b_qc) ,1)
    
    results = experiment(t_qc, backend, shots)
    
    fidelities=[]
    for x in range(30):
        raw = results.get_counts(x)
        fidelities.append( fidelity(simulation,raw,shots) )
        
    key_result = [threshold, b_qc.data, t_qc.data, counts[1], counts[0], b_qc.num_qubits, raw, Fsim, fidelities]

    csv_generator(step, [key_result])
    

def experiment(qc, backend, shots):
    
    results = icepp.qc_experiment(qc_list=[qc]*30, backend=backend, shots=shots).run()
    
    return results

def csv_generator(step, final_result):
    # Job_is future work
    body = final_result

    if step == 1:
        step_str = '_1step_qc.csv'
    if step == 2:
        step_str = '_2step_qc.csv'
        
    with open(backend_name+step_str, 'a') as f:
        writer = csv.writer(f)
        writer.writerows(body)

    f.close()

def dic_size(qc):
    
    sim_result = icepp.simulator(qc).statevector_simulator(output='probabilities_distribution')
    
    new_sim_result = key_changer(qc, sim_result)
        
    return new_sim_result

def key_changer(qc, dic):
    measure_list = [0]*qc.num_clbits
    for op in qc.get_instructions('measure'):
        measure_list[op[2][0]._index] = qc.qubits.index(op[1][0])
    
    new_dic = {}
    for key in dic.keys():
        new_key = ''
        for index in reversed(measure_list):
            new_key = new_key + key[qc.num_qubits - index -1]
            
        if new_key in new_dic.keys():
            new_dic[new_key] = new_dic[new_key] + dic[key]
        else:
            new_dic[new_key] = dic[key]
        
    return new_dic

def fidelity(count1,count2,shots):
    fidelity=0
    for key in count1.keys():
        if (key in count2) and (count1[key] >0) and (count2[key] >0):
            fidelity += math.sqrt(count1[key]*count2[key]/shots)
    return float(Decimal(str(fidelity)).quantize(Decimal('0.00001'), rounding=ROUND_HALF_UP))

def analysis(qc):
    
    tr_qc = transpile(qc,basis_gates=['id','x','sx','rz','cx','reset'], optimization_level=0)
    time = schedule(qc, backend).duration*backend.configuration().dt
    
    return [time, tr_qc.count_ops()]

# %% [markdown]
# ## Measurement of bases by a Quantum computer (cutting-off noise bases)

# %%
results_1 = icepp.pass_manager(qc=circuit_LBNL1, level=2, backend=backend, backend_tket=dev_b, shots=8192, measure_type='qc', threshold_type=['constant',0.01], zne='off').auto_manager()
# Out:
#              ░
#  p0_0: ──────░────
#        ┌───┐ ░
#  p0_1: ┤ X ├─░────
#        ├───┤ ░ ┌─┐
#  p0_2: ┤ X ├─░─┤M├
#        └───┘ ░ └╥┘
#  p1_0: ──────░──╫─
#              ░  ║
#  p1_1: ──────░──╫─
#              ░  ║
#  p1_2: ──────░──╫─
#              ░  ║
#  h1_0: ──────░──╫─
#              ░  ║
#   e_0: ──────░──╫─
#              ░  ║
# phi_0: ──────░──╫─
#              ░  ║
#   a_0: ──────░──╫─
#              ░  ║
#   b_0: ──────░──╫─
#              ░  ║
#   w_0: ──────░──╫─
#              ░  ║
#   w_1: ──────░──╫─
#              ░  ║
#   w_2: ──────░──╫─
#              ░  ║
#   c: 1/═════════╩═
#                 0
# Job id : eac99741581b4545a477076f44fc0102-16486155056948202
# Job Status: job has successfully run
# Raw counts: {'0': 41, '1': 8151}
# Measurement error mitigated counts {'0': 4.043435336096166, '1': 8187.956564663904}
# Final counts after applying the threshold : {'1': 8187.956564663904}
# Threshold : 81.92
#        ┌─────────────┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├───────────░──╫─┤M├
#             ├───┤           ░  ║ └╥┘
#  p0_2: ─────┤ X ├───────────░──╫──╫─
#             └───┘           ░  ║  ║
#  p1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  h1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   e_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
# phi_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   a_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   b_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   c: 2/════════════════════════╩══╩═
#                                0  1
# Job id : f5232df0572d4dc7abeebe3ac56f7388-1648615649750491
# Job Status: job has successfully run
# Raw counts: {'00': 25, '01': 75, '10': 2215, '11': 5877}
# Measurement error mitigated counts {'00': 6.084022174945858e-14, '01': 9.719214815324314, '10': 2176.685066243324, '11': 6005.595718941353}
# Final counts after applying the threshold : {'10': 2176.685066243324, '11': 6005.595718941353}
# Threshold : 81.92
#        ┌─────────────┐┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───░───────
#             ├───┤            │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───░────┤M├
#             └───┘            │   ░    └╥┘
#  p1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_1: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_2: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  h1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   e_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
# phi_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   a_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   b_0: ──────────────────────┼───░─────╫─
#                            ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├─░─┤M├─╫─
#                            └───┘ ░ └╥┘ ║
#   w_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   w_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   c: 2/═════════════════════════════╩══╩═
#                                     0  1
# Job id : 415b886e96ff4d188a724fa62464fa49-1648615770873615
# Job Status: job has successfully run
# Raw counts: {'00': 28, '01': 65, '10': 2196, '11': 5903}
# Measurement error mitigated counts {'00': 1.2200002875814184, '01': 7.706730821046258, '10': 2153.676881022914, '11': 6029.396387868458}
# Final counts after applying the threshold : {'10': 2153.676881022914, '11': 6029.396387868458}
# Threshold : 81.92
#        ┌─────────────┐┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼────────░────
#             ├───┤            │        ░
#  p0_2: ─────┤ X ├────────────┼────────░────
#             └───┘            │        ░
#  p1_0: ──────────────────────┼────────░────
#                              │        ░
#  p1_1: ──────────────────────┼────────░────
#                              │        ░
#  p1_2: ──────────────────────┼────────░────
#                              │        ░
#  h1_0: ──────────────────────┼────────░────
#                              │        ░
#   e_0: ──────────────────────┼────────░────
#                              │        ░
# phi_0: ──────────────────────┼────────░────
#                              │  ┌───┐ ░ ┌─┐
#   a_0: ──────────────────────┼──┤ X ├─░─┤M├
#                              │  └─┬─┘ ░ └╥┘
#   b_0: ──────────────────────┼────┼───░──╫─
#                            ┌─┴─┐  │   ░  ║
#   w_0: ────────────────────┤ X ├──■───░──╫─
#                            └───┘      ░  ║
#   w_1: ───────────────────────────────░──╫─
#                                       ░  ║
#   w_2: ───────────────────────────────░──╫─
#                                       ░  ║
#   c: 1/══════════════════════════════════╩═
#                                          0
# Job id : c45d0e46f252484ea410c1d84419101b-164861591158807
# Job Status: job has successfully run
# Raw counts: {'0': 2289, '1': 5903}
# Measurement error mitigated counts {'0': 2248.8443613731624, '1': 5943.1556386268385}
# Final counts after applying the threshold : {'0': 2248.8443613731624, '1': 5943.1556386268385}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘  │                       │  └───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼────────░──╫─┤M├
#             ├───┤            │                       │        ░  ║ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼────────░──╫──╫─
#             └───┘            │                       │        ░  ║  ║
#  p1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_1: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_2: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  h1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │       ┌────────────┐  │        ░  ║  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼────────░──╫──╫─
#                              │       └─────┬──────┘  │        ░  ║  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘      ░  ║  ║
#   w_1: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════╩══╩═
#                                                                  0  1
# Job id : 098a46e9a0da4f5fa14807fbc876dc82-1648616259824197
# Job Status: job has successfully run
# Raw counts: {'00': 77, '01': 29, '10': 5800, '11': 2286}
# Measurement error mitigated counts {'10': 5961.517473757362, '11': 2230.482526242648}
# Final counts after applying the threshold : {'10': 5961.517473757362, '11': 2230.482526242648}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░───────
#             ├───┤            │                       │         │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░────┤M├
#             └───┘            │                       │         │   ░    └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │       ┌────────────┐  │         │   ░     ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───░─────╫─
#                              │       └─────┬──────┘  │         │   ░     ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼───░─────╫─
#                              │  ┌───┐      │         │         │   ░     ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼───░─────╫─
#                              │  └─┬─┘                │         │   ░     ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼───░─────╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├─░─┤M├─╫─
#                            └───┘                   └───┘     └───┘ ░ └╥┘ ║
#   w_1: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   w_2: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════╩══╩═
#                                                                       0  1
# Job id : 929944ee06344b4eafb50818fd991ded-164861650161719
# Job Status: job has successfully run
# Raw counts: {'00': 129, '01': 36, '10': 5774, '11': 2253}
# Measurement error mitigated counts {'10': 5943.65384901194, '11': 2248.3461509880735}
# Final counts after applying the threshold : {'10': 5943.65384901194, '11': 2248.3461509880735}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             ├───┤            │                       │         │        ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             └───┘            │                       │         │        ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │       ┌────────────┐  │         │        ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼────────░────
#                              │       └─────┬──────┘  │         │        ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼────────░────
#                              │  ┌───┐      │         │         │        ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼────────░────
#                              │  └─┬─┘                │         │  ┌───┐ ░ ┌─┐
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├─░─┤M├
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘ ░ └╥┘
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■───░──╫─
#                            └───┘                   └───┘     └───┘      ░  ║
#   w_1: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   w_2: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   c: 1/════════════════════════════════════════════════════════════════════╩═
#                                                                            0
# Job id : f3517f1dff02434094bddecdea5b2ad6-1648618542294682
# Job Status: job has successfully run
# Raw counts: {'0': 5741, '1': 2451}
# Measurement error mitigated counts {'0': 5753.175884406561, '1': 2438.8241155934393}
# Final counts after applying the threshold : {'0': 5753.175884406561, '1': 2438.8241155934393}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐ ░    ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├─░────┤M├
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘ ░    └╥┘
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             ├───┤            │                       │         │                        │        ░     ║
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             └───┘            │                       │         │                        │        ░     ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │        ░ ┌─┐ ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼────────░─┤M├─╫─
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │        ░ └╥┘ ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │         │              │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │         │  ┌───┐       │         │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘     └───┘                    └───┘      ░  ║  ║
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   w_2: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   c: 2/═════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                     0  1
# Job id : 57b111c7e8954caf80b0d927da5be648-16486186823766599
# Job Status: job has successfully run
# Raw counts: {'00': 2156, '01': 551, '10': 481, '11': 5004}
# Measurement error mitigated counts {'00': 2177.0831298318762, '01': 483.24718153942086, '10': 418.2628497590649, '11': 5113.406838869638}
# Final counts after applying the threshold : {'00': 2177.0831298318762, '01': 483.24718153942086, '10': 418.2628497590649, '11': 5113.406838869638}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├─░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │ ░ ┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░─┤M├───
#             ├───┤            │                       │         │                        │       │       │ ░ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#             └───┘            │                       │         │                        │       │       │ ░  ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │                       │         │                        │       │       │ ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │                       │         │                        │       │       │ ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │                       │         │                        │       │  Rccx │ ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │ ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├─░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │ ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├─░──╫────
#                              │  ┌───┐      │         │         │              │         │       │       │ ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├─░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │ ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├─░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │ ░  ║ ┌─┐
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├─░──╫─┤M├
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘ ░  ║ └╥┘
#   w_1: ───────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                           ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                           ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                              0  1
# Job id : da22cec6732241f9ad84aa546d9f2b04-16486188221016572
# Job Status: job has successfully run
# Raw counts: {'00': 22, '01': 2891, '10': 55, '11': 5224}
# Measurement error mitigated counts {'01': 2937.455691767798, '10': 7.858371964022412, '11': 5246.68593626818}
# Final counts after applying the threshold : {'01': 2937.455691767798, '11': 5246.68593626818}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │      ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░───────
#             ├───┤            │                       │         │                        │       │       │      ░ ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░─┤M├───
#             └───┘            │                       │         │                        │       │       │      ░ └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │                       │         │                        │       │       │      ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │                       │         │                        │       │       │      ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │                       │         │                        │       │  Rccx │      ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │      ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │      ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────░──╫────
#                              │  ┌───┐      │         │         │              │         │       │       │      ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │      ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │      ░  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───░──╫────
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐ ░  ║ ┌─┐
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░──╫─┤M├
#                                                                                                          └───┘ ░  ║ └╥┘
#   w_2: ────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                                ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                                   0  1
# Job id : 8de014b554364641b93211eda8b880d1-16486189223682072
# Job Status: job has successfully run
# Raw counts: {'00': 181, '01': 2447, '10': 393, '11': 5171}
# Measurement error mitigated counts {'00': 1.5306676731387638, '01': 2592.2147114326717, '10': 4.3417443338749955, '11': 5593.9128765603145}
# Final counts after applying the threshold : {'01': 2592.2147114326717, '11': 5593.9128765603145}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐           ░ »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├───────────░─»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │           ░ »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#             ├───┤            │                       │         │                        │       │       │           ░ »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#             └───┘            │                       │         │                        │       │       │           ░ »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │                       │         │                        │       │       │           ░ »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │                       │         │                        │       │       │           ░ »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │                       │         │                        │       │  Rccx │           ░ »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │           ░ »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├───────────░─»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │           ░ »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├───────────░─»
#                              │  ┌───┐      │         │         │              │         │       │       │           ░ »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├───────────░─»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │           ░ »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├───────────░─»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │           ░ »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■────────░─»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐      ░ »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■───░─»
#                                                                                                          └───┘┌─┴─┐ ░ »
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░─»
#                                                                                                               └───┘ ░ »
#   c: 1/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                       »
# «
# « p0_0: ───
# «
# « p0_1: ───
# «
# « p0_2: ───
# «
# « p1_0: ───
# «
# « p1_1: ───
# «
# « p1_2: ───
# «
# « h1_0: ───
# «
# «  e_0: ───
# «
# «phi_0: ───
# «
# «  a_0: ───
# «
# «  b_0: ───
# «
# «  w_0: ───
# «
# «  w_1: ───
# «       ┌─┐
# «  w_2: ┤M├
# «       └╥┘
# «  c: 1/═╩═
# «        0
# Job id : f9cd1f3f4b8c4f6aa28a003592a8e199-16486190005240178
# Job Status: job has successfully run
# Raw counts: {'0': 3229, '1': 4963}
# Measurement error mitigated counts {'0': 2909.650355428261, '1': 5282.349644571739}
# Final counts after applying the threshold : {'0': 2909.650355428261, '1': 5282.349644571739}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤            │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐ ░    ┌─┐
# « p0_0: ───────────────────┤1      ├┤ X ├─░────┤M├
# «                          │       │└───┘ ░    └╥┘
# « p0_1: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p0_2: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p1_0: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p1_1: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p1_2: ───────────────────┤       ├──────░─────╫─
# «       ┌───────┐          │  Rccx │      ░     ║
# « h1_0: ┤ Ry(π) ├──────────┤       ├──────░─────╫─
# «       └───┬───┘          │       │      ░ ┌─┐ ║
# «  e_0: ────┼──────────────┤0      ├──────░─┤M├─╫─
# «           │              │       │      ░ └╥┘ ║
# «phi_0: ────┼──────────────┤       ├──────░──╫──╫─
# «           │              │       │      ░  ║  ║
# «  a_0: ────┼──────────────┤       ├──────░──╫──╫─
# «           │              │       │      ░  ║  ║
# «  b_0: ────┼──────────────┤       ├──────░──╫──╫─
# «           │              │       │      ░  ║  ║
# «  w_0: ────┼───────────■──┤2      ├──────░──╫──╫─
# «           │         ┌─┴─┐└───────┘      ░  ║  ║
# «  w_1: ────┼──────■──┤ X ├───────────────░──╫──╫─
# «           │    ┌─┴─┐└───┘               ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────────░──╫──╫─
# «                └───┘                    ░  ║  ║
# «  c: 2/═════════════════════════════════════╩══╩═
# «                                            0  1
# Job id : c6cca973febb403b956feef7eaf8fcc5-1648619063284578
# Job Status: job has successfully run
# Raw counts: {'00': 2328, '01': 3158, '10': 1641, '11': 1065}
# Measurement error mitigated counts {'00': 2307.2460204044996, '01': 3181.6865529146016, '10': 1643.352969718676, '11': 1059.7144569622235}
# Final counts after applying the threshold : {'00': 2307.2460204044996, '01': 3181.6865529146016, '10': 1643.352969718676, '11': 1059.7144569622235}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤            │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐ ░
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├─░───────
# «                          │       │└───┘│       │ ░ ┌─┐
# « p0_1: ───────────────────┤       ├─────┤       ├─░─┤M├───
# «                          │       │     │       │ ░ └╥┘
# « p0_2: ───────────────────┤       ├─────┤       ├─░──╫────
# «                          │       │     │       │ ░  ║
# « p1_0: ───────────────────┤       ├─────┤       ├─░──╫────
# «                          │       │     │       │ ░  ║
# « p1_1: ───────────────────┤       ├─────┤       ├─░──╫────
# «                          │       │     │       │ ░  ║
# « p1_2: ───────────────────┤       ├─────┤       ├─░──╫────
# «       ┌───────┐          │  Rccx │     │  Rccx │ ░  ║
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├─░──╫────
# «       └───┬───┘          │       │     │       │ ░  ║
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├─░──╫────
# «           │              │       │     │       │ ░  ║
# «phi_0: ────┼──────────────┤       ├─────┤       ├─░──╫────
# «           │              │       │     │       │ ░  ║
# «  a_0: ────┼──────────────┤       ├─────┤       ├─░──╫────
# «           │              │       │     │       │ ░  ║
# «  b_0: ────┼──────────────┤       ├─────┤       ├─░──╫────
# «           │              │       │     │       │ ░  ║ ┌─┐
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├─░──╫─┤M├
# «           │         ┌─┴─┐└───────┘     └───────┘ ░  ║ └╥┘
# «  w_1: ────┼──────■──┤ X ├────────────────────────░──╫──╫─
# «           │    ┌─┴─┐└───┘                        ░  ║  ║
# «  w_2: ────■────┤ X ├─────────────────────────────░──╫──╫─
# «                └───┘                             ░  ║  ║
# «  c: 2/══════════════════════════════════════════════╩══╩═
# «                                                     0  1
# Job id : f6dd72b9ef9a4420a278481b25408ddd-1648619170950059
# Job Status: job has successfully run
# Raw counts: {'00': 82, '01': 4920, '10': 64, '11': 3126}
# Measurement error mitigated counts {'00': 37.259356897742286, '01': 4999.0108257342235, '10': 32.77645877573635, '11': 3122.9533585922986}
# Final counts after applying the threshold : {'01': 4999.0108257342235, '11': 3122.9533585922986}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤            │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐      ░
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├──────░───────
# «                          │       │└───┘│       │      ░
# « p0_1: ───────────────────┤       ├─────┤       ├──────░───────
# «                          │       │     │       │      ░ ┌─┐
# « p0_2: ───────────────────┤       ├─────┤       ├──────░─┤M├───
# «                          │       │     │       │      ░ └╥┘
# « p1_0: ───────────────────┤       ├─────┤       ├──────░──╫────
# «                          │       │     │       │      ░  ║
# « p1_1: ───────────────────┤       ├─────┤       ├──────░──╫────
# «                          │       │     │       │      ░  ║
# « p1_2: ───────────────────┤       ├─────┤       ├──────░──╫────
# «       ┌───────┐          │  Rccx │     │  Rccx │      ░  ║
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├──────░──╫────
# «       └───┬───┘          │       │     │       │      ░  ║
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «phi_0: ────┼──────────────┤       ├─────┤       ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «  a_0: ────┼──────────────┤       ├─────┤       ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «  b_0: ────┼──────────────┤       ├─────┤       ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├──■───░──╫────
# «           │         ┌─┴─┐└───────┘     └───────┘┌─┴─┐ ░  ║ ┌─┐
# «  w_1: ────┼──────■──┤ X ├───────────────────────┤ X ├─░──╫─┤M├
# «           │    ┌─┴─┐└───┘                       └───┘ ░  ║ └╥┘
# «  w_2: ────■────┤ X ├──────────────────────────────────░──╫──╫─
# «                └───┘                                  ░  ║  ║
# «  c: 2/═══════════════════════════════════════════════════╩══╩═
# «                                                          0  1
# Job id : c73de89e3ffd450d9ff922c959bf54a3-1648619312920644
# Job Status: job has successfully run
# Raw counts: {'00': 116, '01': 4961, '10': 77, '11': 3038}
# Measurement error mitigated counts {'01': 5099.131916220863, '10': 1.0891499895678528e-11, '11': 3092.8680837791826}
# Final counts after applying the threshold : {'01': 5099.131916220863, '11': 3092.8680837791826}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
# ...
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐                             ┌───────┐┌───┐               ┌───┐     »
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├─────────────────────────────┤1      ├┤ X ├──■─────────■──┤ X ├──■──»
# «                          │       │└───┘│       │                             │       │└───┘  │         │  └───┘  │  »
# « p0_1: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                             │       │       │         │         │  »
# « p0_2: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   ┌───┐     │       │       │         │         │  »
# « p1_0: ───────────────────┤       ├─────┤       ├───────────────────┤ X ├─────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   └─┬─┘     │       │       │         │         │  »
# « p1_1: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                     │       │       │       │         │         │  »
# « p1_2: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «       ┌───────┐          │  Rccx │     │  Rccx │          ┌───────┐  │       │  Rccx │       │         │         │  »
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├──────────┤ Ry(π) ├──■───────┤       ├───────┼─────────┼─────────┼──»
# «       └───┬───┘          │       │     │       │          └───┬───┘          │       │       │         │         │  »
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├──────────────┼──────────────┤0      ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │         │         │  »
# «phi_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  ┌───┐  │         │  »
# «  a_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼──┤ X ├──┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  └─┬─┘  │         │  »
# «  b_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼────┼────┼─────────┼──»
# «           │              │       │     │       │              │              │       │     ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐»
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├──■───────────┼───────────■──┤2      ├─────┤ X ├──■──┤ X ├─────┤ X ├»
# «           │         ┌─┴─┐└───────┘     └───────┘┌─┴─┐         │         ┌─┴─┐└───────┘     └───┘     └───┘     └───┘»
# «  w_1: ────┼──────■──┤ X ├───────────────────────┤ X ├──■──────┼──────■──┤ X ├───────────────────────────────────────»
# «           │    ┌─┴─┐└───┘                       └───┘┌─┴─┐    │    ┌─┴─┐└───┘                                       »
# «  w_2: ────■────┤ X ├─────────────────────────────────┤ X ├────■────┤ X ├────────────────────────────────────────────»
# «                └───┘                                 └───┘         └───┘                                            »
# «  c: 1/══════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                     »
# «                  ░
# « p0_0: ───────■───░────
# «              │   ░
# « p0_1: ───────┼───░────
# «              │   ░ ┌─┐
# « p0_2: ───────┼───░─┤M├
# «              │   ░ └╥┘
# « p1_0: ───────┼───░──╫─
# «              │   ░  ║
# « p1_1: ───────┼───░──╫─
# «              │   ░  ║
# « p1_2: ───────┼───░──╫─
# «              │   ░  ║
# « h1_0: ───────┼───░──╫─
# «              │   ░  ║
# «  e_0: ───────┼───░──╫─
# «              │   ░  ║
# «phi_0: ───────┼───░──╫─
# «              │   ░  ║
# «  a_0: ───────┼───░──╫─
# «       ┌───┐  │   ░  ║
# «  b_0: ┤ X ├──┼───░──╫─
# «       └─┬─┘┌─┴─┐ ░  ║
# «  w_0: ──■──┤ X ├─░──╫─
# «            └───┘ ░  ║
# «  w_1: ───────────░──╫─
# «                  ░  ║
# «  w_2: ───────────░──╫─
# «                  ░  ║
# «  c: 1/══════════════╩═
# «                     0
# Job id : 78081e57bae0472fa4da915db781cafb-1648619960854632
# Job Status: job has successfully run
# Raw counts: {'0': 118, '1': 8074}
# Measurement error mitigated counts {'0': 11.403695289258327, '1': 8180.596304710742}
# Final counts after applying the threshold : {'1': 8180.596304710742}
# Threshold : 81.92
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤     └───┘  │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐                             ┌───────┐┌───┐               ┌───┐     »
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├─────────────────────────────┤1      ├┤ X ├──■─────────■──┤ X ├──■──»
# «                          │       │└───┘│       │                             │       │└───┘  │         │  └───┘  │  »
# « p0_1: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                             │       │       │         │         │  »
# « p0_2: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   ┌───┐     │       │       │         │         │  »
# « p1_0: ───────────────────┤       ├─────┤       ├───────────────────┤ X ├─────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   └─┬─┘     │       │       │         │         │  »
# « p1_1: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                     │       │       │       │         │         │  »
# « p1_2: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «       ┌───────┐          │  Rccx │     │  Rccx │          ┌───────┐  │       │  Rccx │       │         │         │  »
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├──────────┤ Ry(π) ├──■───────┤       ├───────┼─────────┼─────────┼──»
# «       └───┬───┘          │       │     │       │          └───┬───┘          │       │       │         │         │  »
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├──────────────┼──────────────┤0      ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │         │         │  »
# «phi_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  ┌───┐  │         │  »
# «  a_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼──┤ X ├──┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  └─┬─┘  │         │  »
# «  b_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼────┼────┼─────────┼──»
# «           │              │       │     │       │              │              │       │     ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐»
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├──■───────────┼───────────■──┤2      ├─────┤ X ├──■──┤ X ├─────┤ X ├»
# «           │         ┌─┴─┐└───────┘     └───────┘┌─┴─┐         │         ┌─┴─┐└───────┘     └───┘     └───┘     └───┘»
# «  w_1: ────┼──────■──┤ X ├───────────────────────┤ X ├──■──────┼──────■──┤ X ├───────────────────────────────────────»
# «           │    ┌─┴─┐└───┘                       └───┘┌─┴─┐    │    ┌─┴─┐└───┘                                       »
# «  w_2: ────■────┤ X ├─────────────────────────────────┤ X ├────■────┤ X ├────────────────────────────────────────────»
# «                └───┘                                 └───┘         └───┘                                            »
# «  c: 1/══════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                     »
# «                 ┌────────────┐ ░
# « p0_0: ───────■──┤ Ry(1.1071) ├─░────
# «              │  └────────────┘ ░
# « p0_1: ───────┼─────────────────░────
# «              │                 ░
# « p0_2: ───────┼─────────────────░────
# «              │                 ░
# « p1_0: ───────┼─────────────────░────
# «              │                 ░
# « p1_1: ───────┼─────────────────░────
# «              │                 ░ ┌─┐
# « p1_2: ───────┼─────────────────░─┤M├
# «              │                 ░ └╥┘
# « h1_0: ───────┼─────────────────░──╫─
# «              │                 ░  ║
# «  e_0: ───────┼─────────────────░──╫─
# «              │                 ░  ║
# «phi_0: ───────┼─────────────────░──╫─
# «              │                 ░  ║
# «  a_0: ───────┼─────────────────░──╫─
# «       ┌───┐  │                 ░  ║
# «  b_0: ┤ X ├──┼─────────────────░──╫─
# «       └─┬─┘┌─┴─┐               ░  ║
# «  w_0: ──■──┤ X ├───────────────░──╫─
# «            └───┘               ░  ║
# «  w_1: ─────────────────────────░──╫─
# «                                ░  ║
# «  w_2: ─────────────────────────░──╫─
# «                                ░  ║
# «  c: 1/════════════════════════════╩═
# «                                   0
# Job id : 8cf631906d7842a8806114dcf7012edb-1648620032197938
# Job Status: job has successfully run
# Raw counts: {'0': 8113, '1': 79}
# Measurement error mitigated counts {'0': 8166.552684037126, '1': 25.4473159628735}
# Final counts after applying the threshold : {'0': 8166.552684037126}
# Threshold : 81.92

# %%
results_1[0].draw('mpl',fold=100)

# %%
run(step=1, backend=backend, threshold='0.01', qc_qcs=results_1, shots=10000)
# Out:
# Job id : 51e5dce4588949cd841c848d75bcfa67-1648620135971869
# Job Status: job has successfully run

# %%
results_15 = icepp.pass_manager(qc=circuit_LBNL1, level=2, backend=backend, backend_tket=dev_b, shots=8192, measure_type='qc', threshold_type=['constant',0.15], zne='off').auto_manager()
# Out:
#              ░
#  p0_0: ──────░────
#        ┌───┐ ░
#  p0_1: ┤ X ├─░────
#        ├───┤ ░ ┌─┐
#  p0_2: ┤ X ├─░─┤M├
#        └───┘ ░ └╥┘
#  p1_0: ──────░──╫─
#              ░  ║
#  p1_1: ──────░──╫─
#              ░  ║
#  p1_2: ──────░──╫─
#              ░  ║
#  h1_0: ──────░──╫─
#              ░  ║
#   e_0: ──────░──╫─
#              ░  ║
# phi_0: ──────░──╫─
#              ░  ║
#   a_0: ──────░──╫─
#              ░  ║
#   b_0: ──────░──╫─
#              ░  ║
#   w_0: ──────░──╫─
#              ░  ║
#   w_1: ──────░──╫─
#              ░  ║
#   w_2: ──────░──╫─
#              ░  ║
#   c: 1/═════════╩═
#                 0
# Job id : 17c3c96cd399465282c48fbe64009c5b-16486203529080489
# Job Status: job has successfully run
# Raw counts: {'0': 33, '1': 8159}
# Measurement error mitigated counts {'0': 1.0427718936814948e-13, '1': 8192.0}
# Final counts after applying the threshold : {'1': 8192.0}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├───────────░──╫─┤M├
#             ├───┤           ░  ║ └╥┘
#  p0_2: ─────┤ X ├───────────░──╫──╫─
#             └───┘           ░  ║  ║
#  p1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  h1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   e_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
# phi_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   a_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   b_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   c: 2/════════════════════════╩══╩═
#                                0  1
# Job id : acf0b4579f9f4a12b9e37d5de1fc05eb-1648620421692662
# Job Status: job has successfully run
# Raw counts: {'00': 31, '01': 55, '10': 2258, '11': 5848}
# Measurement error mitigated counts {'00': 6.325801631399281, '01': 3.0320190802513025e-13, '10': 2225.4120905438976, '11': 5960.262107824703}
# Final counts after applying the threshold : {'10': 2225.4120905438976, '11': 5960.262107824703}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───░───────
#             ├───┤            │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───░────┤M├
#             └───┘            │   ░    └╥┘
#  p1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_1: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_2: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  h1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   e_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
# phi_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   a_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   b_0: ──────────────────────┼───░─────╫─
#                            ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├─░─┤M├─╫─
#                            └───┘ ░ └╥┘ ║
#   w_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   w_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   c: 2/═════════════════════════════╩══╩═
#                                     0  1
# Job id : 6e846736fbd64e47ae6991c3a8d0cf8e-1648620502221524
# Job Status: job has successfully run
# Raw counts: {'00': 34, '01': 75, '10': 2194, '11': 5889}
# Measurement error mitigated counts {'00': 8.560488267000824, '01': 6.8512760040581515, '10': 2167.8338093422294, '11': 6008.754426386711}
# Final counts after applying the threshold : {'10': 2167.8338093422294, '11': 6008.754426386711}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼────────░────
#             ├───┤            │        ░
#  p0_2: ─────┤ X ├────────────┼────────░────
#             └───┘            │        ░
#  p1_0: ──────────────────────┼────────░────
#                              │        ░
#  p1_1: ──────────────────────┼────────░────
#                              │        ░
#  p1_2: ──────────────────────┼────────░────
#                              │        ░
#  h1_0: ──────────────────────┼────────░────
#                              │        ░
#   e_0: ──────────────────────┼────────░────
#                              │        ░
# phi_0: ──────────────────────┼────────░────
#                              │  ┌───┐ ░ ┌─┐
#   a_0: ──────────────────────┼──┤ X ├─░─┤M├
#                              │  └─┬─┘ ░ └╥┘
#   b_0: ──────────────────────┼────┼───░──╫─
#                            ┌─┴─┐  │   ░  ║
#   w_0: ────────────────────┤ X ├──■───░──╫─
#                            └───┘      ░  ║
#   w_1: ───────────────────────────────░──╫─
#                                       ░  ║
#   w_2: ───────────────────────────────░──╫─
#                                       ░  ║
#   c: 1/══════════════════════════════════╩═
#                                          0
# Job id : 0e5e635649ca4f6bb9f755852de7e109-1648620681449709
# Job Status: job has successfully run
# Raw counts: {'0': 2297, '1': 5895}
# Measurement error mitigated counts {'0': 2259.0184171217675, '1': 5932.981582878233}
# Final counts after applying the threshold : {'0': 2259.0184171217675, '1': 5932.981582878233}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘  │                       │  └───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼────────░──╫─┤M├
#             ├───┤            │                       │        ░  ║ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼────────░──╫──╫─
#             └───┘            │                       │        ░  ║  ║
#  p1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_1: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_2: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  h1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │       ┌────────────┐  │        ░  ║  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼────────░──╫──╫─
#                              │       └─────┬──────┘  │        ░  ║  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘      ░  ║  ║
#   w_1: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════╩══╩═
#                                                                  0  1
# Job id : 1c7ca3f55bd340bea2d09a66e3225a9d-1648620752589597
# Job Status: job has successfully run
# Raw counts: {'00': 96, '01': 32, '10': 5831, '11': 2233}
# Measurement error mitigated counts {'10': 5991.446465505377, '11': 2200.5535344946356}
# Final counts after applying the threshold : {'10': 5991.446465505377, '11': 2200.5535344946356}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░───────
#             ├───┤            │                       │         │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░────┤M├
#             └───┘            │                       │         │   ░    └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │       ┌────────────┐  │         │   ░     ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───░─────╫─
#                              │       └─────┬──────┘  │         │   ░     ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼───░─────╫─
#                              │  ┌───┐      │         │         │   ░     ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼───░─────╫─
#                              │  └─┬─┘                │         │   ░     ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼───░─────╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├─░─┤M├─╫─
#                            └───┘                   └───┘     └───┘ ░ └╥┘ ║
#   w_1: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   w_2: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════╩══╩═
#                                                                       0  1
# Job id : 3c62f8b1f01c48d1a0c3e8302d5c86fa-16486208501815832
# Job Status: job has successfully run
# Raw counts: {'00': 108, '01': 66, '10': 5786, '11': 2232}
# Measurement error mitigated counts {'01': 18.578838800381426, '10': 5923.909413231895, '11': 2249.5117479677237}
# Final counts after applying the threshold : {'10': 5923.909413231895, '11': 2249.5117479677237}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             ├───┤            │                       │         │        ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             └───┘            │                       │         │        ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │       ┌────────────┐  │         │        ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼────────░────
#                              │       └─────┬──────┘  │         │        ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼────────░────
#                              │  ┌───┐      │         │         │        ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼────────░────
#                              │  └─┬─┘                │         │  ┌───┐ ░ ┌─┐
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├─░─┤M├
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘ ░ └╥┘
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■───░──╫─
#                            └───┘                   └───┘     └───┘      ░  ║
#   w_1: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   w_2: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   c: 1/════════════════════════════════════════════════════════════════════╩═
#                                                                            0
# Job id : 0b0aaac10d4547b79898782c91caeff4-1648620971932132
# Job Status: job has successfully run
# Raw counts: {'0': 5823, '1': 2369}
# Measurement error mitigated counts {'0': 5858.751094981281, '1': 2333.248905018719}
# Final counts after applying the threshold : {'0': 5858.751094981281, '1': 2333.248905018719}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐ ░    ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├─░────┤M├
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘ ░    └╥┘
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             ├───┤            │                       │         │                        │        ░     ║
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             └───┘            │                       │         │                        │        ░     ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │        ░ ┌─┐ ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼────────░─┤M├─╫─
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │        ░ └╥┘ ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │         │              │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │         │  ┌───┐       │         │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘     └───┘                    └───┘      ░  ║  ║
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   w_2: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   c: 2/═════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                     0  1
# Job id : 4deea794466546e7af6d227d51ddf971-16486210416141171
# Job Status: job has successfully run
# Raw counts: {'00': 2021, '01': 534, '10': 547, '11': 5090}
# Measurement error mitigated counts {'00': 2034.771164661403, '01': 473.1156594872679, '10': 483.80032424562967, '11': 5200.312851605699}
# Final counts after applying the threshold : {'00': 2034.771164661403, '11': 5200.312851605699}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │   ░ ┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░─┤M├───
#             ├───┤            │                       │         │                        │         │   ░ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#             └───┘            │                       │         │                        │         │   ░  ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │   ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼───░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │   ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼───░──╫────
#                              │  ┌───┐      │         │         │              │         │         │   ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼───░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │   ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼───░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐ ░  ║ ┌─┐
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├─░──╫─┤M├
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘ ░  ║ └╥┘
#   w_1: ───────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                       ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                       ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                          0  1
# Job id : 814e2008c0244b988eef6ebe8d9edfe7-1648621211970798
# Job Status: job has successfully run
# Raw counts: {'00': 29, '01': 2826, '10': 51, '11': 5286}
# Measurement error mitigated counts {'00': 12.281215496715674, '01': 2794.425780599916, '10': 5.709946514893265, '11': 5379.583057388475}
# Final counts after applying the threshold : {'01': 2794.425780599916, '11': 5379.583057388475}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░───────
#             ├───┤            │                       │         │                        │         │        ░ ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░─┤M├───
#             └───┘            │                       │         │                        │         │        ░ └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │        ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │        ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────░──╫────
#                              │  ┌───┐      │         │         │              │         │         │        ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │        ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐      ░  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───░──╫────
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐ ░  ║ ┌─┐
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░──╫─┤M├
#                                                                                                      └───┘ ░  ║ └╥┘
#   w_2: ────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                            ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                               0  1
# Job id : 024464c26dfb4ceb90ec45267bbf50ae-16486212908969522
# Job Status: job has successfully run
# Raw counts: {'00': 46, '01': 2511, '10': 86, '11': 5549}
# Measurement error mitigated counts {'00': 27.92553331693128, '01': 2536.2576217118194, '10': 23.537444222950956, '11': 5604.279400748299}
# Final counts after applying the threshold : {'01': 2536.2576217118194, '11': 5604.279400748299}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐                ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■─────────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │             ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#             ├───┤            │                       │         │                        │         │             ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#             └───┘            │                       │         │                        │         │             ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │             ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼─────────────░────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │             ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼─────────────░────
#                              │  ┌───┐      │         │         │              │         │         │             ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼─────────────░────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │             ░
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼─────────────░────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐           ░
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■────────░────
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐      ░
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■───░────
#                                                                                                      └───┘┌─┴─┐ ░ ┌─┐
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░─┤M├
#                                                                                                           └───┘ ░ └╥┘
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═
#                                                                                                                    0
# Job id : 954452f3a6fa46a39a1032bd551f9eea-1648621413247159
# Job Status: job has successfully run
# Raw counts: {'0': 2997, '1': 5195}
# Measurement error mitigated counts {'0': 2619.70525887527, '1': 5572.29474112473}
# Final counts after applying the threshold : {'0': 2619.70525887527, '1': 5572.29474112473}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░    ┌─┐
# « p0_0: ─────────────────────■──┤ X ├─░────┤M├
# «                            │  └───┘ ░    └╥┘
# « p0_1: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p0_2: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_0: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_1: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_2: ─────────────────────┼────────░─────╫─
# «       ┌───────┐            │        ░     ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░─────╫─
# «       └───┬───┘            │        ░ ┌─┐ ║
# «  e_0: ────┼────────────────┼────────░─┤M├─╫─
# «           │                │        ░ └╥┘ ║
# «phi_0: ────┼────────────────┼────────░──╫──╫─
# «           │                │        ░  ║  ║
# «  a_0: ────┼────────────────┼────────░──╫──╫─
# «           │                │        ░  ║  ║
# «  b_0: ────┼────────────────┼────────░──╫──╫─
# «           │              ┌─┴─┐      ░  ║  ║
# «  w_0: ────┼───────────■──┤ X ├──────░──╫──╫─
# «           │         ┌─┴─┐└───┘      ░  ║  ║
# «  w_1: ────┼──────■──┤ X ├───────────░──╫──╫─
# «           │    ┌─┴─┐└───┘           ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : af00059544164f2496fb393387733bdb-1648621471520481
# Job Status: job has successfully run
# Raw counts: {'00': 579, '01': 5209, '10': 2029, '11': 375}
# Measurement error mitigated counts {'00': 495.9749470231643, '01': 5305.873639149846, '10': 2062.972524670947, '11': 327.1788891560428}
# Final counts after applying the threshold : {'01': 5305.873639149846, '10': 2062.972524670947}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░
# « p0_0: ─────────────────────■──┤ X ├─░───────
# «                            │  └───┘ ░ ┌─┐
# « p0_1: ─────────────────────┼────────░─┤M├───
# «                            │        ░ └╥┘
# « p0_2: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_0: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_1: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_2: ─────────────────────┼────────░──╫────
# «       ┌───────┐            │        ░  ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░──╫────
# «       └───┬───┘            │        ░  ║
# «  e_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «phi_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  a_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  b_0: ────┼────────────────┼────────░──╫────
# «           │              ┌─┴─┐      ░  ║ ┌─┐
# «  w_0: ────┼───────────■──┤ X ├──────░──╫─┤M├
# «           │         ┌─┴─┐└───┘      ░  ║ └╥┘
# «  w_1: ────┼──────■──┤ X ├───────────░──╫──╫─
# «           │    ┌─┴─┐└───┘           ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : ec5de5c364974e77b034a83414b748db-1648621563255508
# Job Status: job has successfully run
# Raw counts: {'00': 104, '01': 7734, '10': 4, '11': 350}
# Measurement error mitigated counts {'00': 32.4935227921676, '01': 7845.277195316333, '10': 0.8768138206353481, '11': 313.3524680708645}
# Final counts after applying the threshold : {'01': 7845.277195316333}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░
# « p0_0: ─────────────────────■──┤ X ├─░───────
# «                            │  └───┘ ░
# « p0_1: ─────────────────────┼────────░───────
# «                            │        ░ ┌─┐
# « p0_2: ─────────────────────┼────────░─┤M├───
# «                            │        ░ └╥┘
# « p1_0: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_1: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_2: ─────────────────────┼────────░──╫────
# «       ┌───────┐            │        ░  ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░──╫────
# «       └───┬───┘            │        ░  ║
# «  e_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «phi_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  a_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  b_0: ────┼────────────────┼────────░──╫────
# «           │              ┌─┴─┐      ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────░──╫────
# «           │         ┌─┴─┐└───┘      ░  ║ ┌─┐
# «  w_1: ────┼──────■──┤ X ├───────────░──╫─┤M├
# «           │    ┌─┴─┐└───┘           ░  ║ └╥┘
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : 874d6a267d9a4826950de862dba48d6d-1648621730611611
# Job Status: job has successfully run
# Raw counts: {'00': 180, '01': 7644, '10': 10, '11': 358}
# Measurement error mitigated counts {'01': 8039.385892645204, '10': 1.5123618133060173e-13, '11': 152.6141073547964}
# Final counts after applying the threshold : {'01': 8039.385892645204}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
# ...
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■───░───────
# «                            │  └───┘└───┘  │         │  └───┘  │   ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼───░───────
# «                            │              │         │         │   ░    ┌─┐
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼───░────┤M├
# «                ┌───┐       │              │         │         │   ░    └╥┘
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼───░─────╫─
# «                └─┬─┘       │              │         │         │   ░     ║
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «                  │         │              │         │         │   ░     ║
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «       ┌───────┐  │         │              │         │         │   ░     ║
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «       └───┬───┘            │              │         │         │   ░     ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «           │                │              │         │         │   ░     ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «           │                │              │  ┌───┐  │         │   ░     ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼───░─────╫─
# «           │                │              │  └─┬─┘  │         │   ░     ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼───░─────╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├─░─┤M├─╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘ ░ └╥┘ ║
# «  w_1: ────┼──────■──┤ X ├─────────────────────────────────────────░──╫──╫─
# «           │    ┌─┴─┐└───┘                                         ░  ║  ║
# «  w_2: ────■────┤ X ├──────────────────────────────────────────────░──╫──╫─
# «                └───┘                                              ░  ║  ║
# «  c: 2/═══════════════════════════════════════════════════════════════╩══╩═
# «                                                                      0  1
# Job id : 2a13bf7dc6f8427b9a0bbb1c342fae02-16486222509130292
# Job Status: job has successfully run
# Raw counts: {'00': 73, '01': 31, '10': 5712, '11': 2376}
# Measurement error mitigated counts {'00': 9.197371940917298, '01': 0.01772045482492391, '10': 5792.51802203178, '11': 2390.2668855724783}
# Final counts after applying the threshold : {'10': 5792.51802203178, '11': 2390.2668855724783}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤     └───┘  │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐┌───┐               ┌───┐                ░
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■─────────■───░────
# «                            │  └───┘└───┘  │         │  └───┘  │         │   ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼───░────
# «                            │              │         │         │         │   ░ ┌─┐
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼───░─┤M├
# «                ┌───┐       │              │         │         │         │   ░ └╥┘
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «                └─┬─┘       │              │         │         │         │   ░  ║
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «                  │         │              │         │         │         │   ░  ║
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «       ┌───────┐  │         │              │         │         │         │   ░  ║
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «       └───┬───┘            │              │         │         │         │   ░  ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «           │                │              │         │         │         │   ░  ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «           │                │              │  ┌───┐  │         │         │   ░  ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼─────────┼───░──╫─
# «           │                │              │  └─┬─┘  │         │  ┌───┐  │   ░  ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼──┤ X ├──┼───░──╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐└─┬─┘┌─┴─┐ ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├──■──┤ X ├─░──╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘     └───┘ ░  ║
# «  w_1: ────┼──────■──┤ X ├───────────────────────────────────────────────────░──╫─
# «           │    ┌─┴─┐└───┘                                                   ░  ║
# «  w_2: ────■────┤ X ├────────────────────────────────────────────────────────░──╫─
# «                └───┘                                                        ░  ║
# «  c: 1/═════════════════════════════════════════════════════════════════════════╩═
# «                                                                                0
# Job id : 32616995e3d242a5830b84820a6b87b5-1648622511863914
# Job Status: job has successfully run
# Raw counts: {'0': 114, '1': 8078}
# Measurement error mitigated counts {'0': 15.312149638245497, '1': 8176.6878503617545}
# Final counts after applying the threshold : {'1': 8176.6878503617545}
# Threshold : 1228.8
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤     └───┘  │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐┌───┐               ┌───┐               ┌────────────┐ ░
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■─────────■──┤ Ry(1.1071) ├─░────
# «                            │  └───┘└───┘  │         │  └───┘  │         │  └────────────┘ ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                            │              │         │         │         │                 ░
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                ┌───┐       │              │         │         │         │                 ░
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                └─┬─┘       │              │         │         │         │                 ░
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                  │         │              │         │         │         │                 ░ ┌─┐
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░─┤M├
# «       ┌───────┐  │         │              │         │         │         │                 ░ └╥┘
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «       └───┬───┘            │              │         │         │         │                 ░  ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │         │         │         │                 ░  ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │  ┌───┐  │         │         │                 ░  ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │  └─┬─┘  │         │  ┌───┐  │                 ░  ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼──┤ X ├──┼─────────────────░──╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐└─┬─┘┌─┴─┐               ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├──■──┤ X ├───────────────░──╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘     └───┘               ░  ║
# «  w_1: ────┼──────■──┤ X ├─────────────────────────────────────────────────────────────────░──╫─
# «           │    ┌─┴─┐└───┘                                                                 ░  ║
# «  w_2: ────■────┤ X ├──────────────────────────────────────────────────────────────────────░──╫─
# «                └───┘                                                                      ░  ║
# «  c: 1/═══════════════════════════════════════════════════════════════════════════════════════╩═
# «                                                                                              0
# Job id : 72da7d3c6720458bb8bb13793688c212-1648622552418596
# Job Status: job has successfully run
# Raw counts: {'0': 8122, '1': 70}
# Measurement error mitigated counts {'0': 8186.9149596436355, '1': 5.085040356364892}
# Final counts after applying the threshold : {'0': 8186.9149596436355}
# Threshold : 1228.8

# %%
results_15[0].draw('mpl',fold=100)

# %%
run(step=1, backend=backend, threshold='0.15', qc_qcs=results_15, shots=10000)
# Out:
# Job id : a7c4eb44546f4c2f9e0643129eb30034-1648622581793888
# Job Status: job has successfully run

# %%
results_30 = icepp.pass_manager(qc=circuit_LBNL1, level=2, backend=backend, backend_tket=dev_b, shots=8192, measure_type='qc', threshold_type=['constant',0.3], zne='off').auto_manager()
# Out:
#              ░
#  p0_0: ──────░────
#        ┌───┐ ░
#  p0_1: ┤ X ├─░────
#        ├───┤ ░ ┌─┐
#  p0_2: ┤ X ├─░─┤M├
#        └───┘ ░ └╥┘
#  p1_0: ──────░──╫─
#              ░  ║
#  p1_1: ──────░──╫─
#              ░  ║
#  p1_2: ──────░──╫─
#              ░  ║
#  h1_0: ──────░──╫─
#              ░  ║
#   e_0: ──────░──╫─
#              ░  ║
# phi_0: ──────░──╫─
#              ░  ║
#   a_0: ──────░──╫─
#              ░  ║
#   b_0: ──────░──╫─
#              ░  ║
#   w_0: ──────░──╫─
#              ░  ║
#   w_1: ──────░──╫─
#              ░  ║
#   w_2: ──────░──╫─
#              ░  ║
#   c: 1/═════════╩═
#                 0
# Job id : ede67fee94774498a3a3e6f00269ba21-16486227715910919
# Job Status: job has successfully run
# Raw counts: {'0': 44, '1': 8148}
# Measurement error mitigated counts {'0': 2.7799841557452423e-13, '1': 8192.0}
# Final counts after applying the threshold : {'1': 8192.0}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├───────────░──╫─┤M├
#             ├───┤           ░  ║ └╥┘
#  p0_2: ─────┤ X ├───────────░──╫──╫─
#             └───┘           ░  ║  ║
#  p1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  h1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   e_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
# phi_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   a_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   b_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   c: 2/════════════════════════╩══╩═
#                                0  1
# Job id : 4c0eb28124c2402d98cecd2c72484d80-1648622801085331
# Job Status: job has successfully run
# Raw counts: {'00': 32, '01': 67, '10': 2285, '11': 5808}
# Measurement error mitigated counts {'00': 8.62471746414482, '01': 1.937108410519705, '10': 2253.6549312867032, '11': 5927.783242838632}
# Final counts after applying the threshold : {'11': 5927.783242838632}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░───────
#        └────┬───┬────┘└───┘ ░
#  p0_1: ─────┤ X ├───────────░───────
#             ├───┤           ░    ┌─┐
#  p0_2: ─────┤ X ├───────────░────┤M├
#             └───┘           ░    └╥┘
#  p1_0: ─────────────────────░─────╫─
#                             ░     ║
#  p1_1: ─────────────────────░─────╫─
#                             ░     ║
#  p1_2: ─────────────────────░─────╫─
#                             ░     ║
#  h1_0: ─────────────────────░─────╫─
#                             ░     ║
#   e_0: ─────────────────────░─────╫─
#                             ░     ║
# phi_0: ─────────────────────░─────╫─
#                             ░     ║
#   a_0: ─────────────────────░─────╫─
#                             ░     ║
#   b_0: ─────────────────────░─────╫─
#             ┌───┐           ░ ┌─┐ ║
#   w_0: ─────┤ X ├───────────░─┤M├─╫─
#             └───┘           ░ └╥┘ ║
#   w_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   c: 2/════════════════════════╩══╩═
#                                0  1
# Job id : a40987ad85ee4d7b8f01dd67eb512752-1648622852035222
# Job Status: job has successfully run
# Raw counts: {'00': 2, '01': 31, '10': 108, '11': 8051}
# Measurement error mitigated counts {'01': 3.077274398977974e-12, '10': 2.119515653902231, '11': 8189.880484346095}
# Final counts after applying the threshold : {'11': 8189.880484346095}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░────
#        └────┬───┬────┘└───┘ ░
#  p0_1: ─────┤ X ├───────────░────
#             ├───┤           ░
#  p0_2: ─────┤ X ├───────────░────
#             └───┘           ░
#  p1_0: ─────────────────────░────
#                             ░
#  p1_1: ─────────────────────░────
#                             ░
#  p1_2: ─────────────────────░────
#                             ░
#  h1_0: ─────────────────────░────
#                             ░
#   e_0: ─────────────────────░────
#                             ░
# phi_0: ─────────────────────░────
#             ┌───┐           ░ ┌─┐
#   a_0: ─────┤ X ├───────────░─┤M├
#             └───┘           ░ └╥┘
#   b_0: ─────────────────────░──╫─
#             ┌───┐           ░  ║
#   w_0: ─────┤ X ├───────────░──╫─
#             └───┘           ░  ║
#   w_1: ─────────────────────░──╫─
#                             ░  ║
#   w_2: ─────────────────────░──╫─
#                             ░  ║
#   c: 1/════════════════════════╩═
#                                0
# Job id : ed371aace7aa422999e8e1e5804ba42e-1648622902021316
# Job Status: job has successfully run
# Raw counts: {'0': 112, '1': 8080}
# Measurement error mitigated counts {'0': 22.488644476516647, '1': 8169.511355523483}
# Final counts after applying the threshold : {'1': 8169.511355523483}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├────────────────░──╫─┤M├
#             ├───┤                ░  ║ └╥┘
#  p0_2: ─────┤ X ├────────────────░──╫──╫─
#             └───┘                ░  ║  ║
#  p1_0: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#  p1_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#  p1_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#  h1_0: ──────────────────────────░──╫──╫─
#         ┌────────────┐           ░  ║  ║
#   e_0: ─┤ Ry(2.8364) ├───────────░──╫──╫─
#         └────────────┘           ░  ║  ║
# phi_0: ──────────────────────────░──╫──╫─
#             ┌───┐                ░  ║  ║
#   a_0: ─────┤ X ├────────────────░──╫──╫─
#             └───┘                ░  ║  ║
#   b_0: ──────────────────────────░──╫──╫─
#             ┌───┐     ┌───┐      ░  ║  ║
#   w_0: ─────┤ X ├─────┤ X ├──────░──╫──╫─
#             └───┘     └───┘      ░  ║  ║
#   w_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   w_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   c: 2/═════════════════════════════╩══╩═
#                                     0  1
# Job id : 4802587b6e184eeeae781c5f04b6005f-1648622941857255
# Job Status: job has successfully run
# Raw counts: {'00': 66, '01': 24, '10': 5756, '11': 2346}
# Measurement error mitigated counts {'00': 7.553338093673089, '01': 4.360956040727615e-13, '10': 5869.593739582058, '11': 2314.8529223242676}
# Final counts after applying the threshold : {'10': 5869.593739582058}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├─░───────
#        └────┬───┬────┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├────────────────░───────
#             ├───┤                ░    ┌─┐
#  p0_2: ─────┤ X ├────────────────░────┤M├
#             └───┘                ░    └╥┘
#  p1_0: ──────────────────────────░─────╫─
#                                  ░     ║
#  p1_1: ──────────────────────────░─────╫─
#                                  ░     ║
#  p1_2: ──────────────────────────░─────╫─
#                                  ░     ║
#  h1_0: ──────────────────────────░─────╫─
#         ┌────────────┐           ░     ║
#   e_0: ─┤ Ry(2.8364) ├───────────░─────╫─
#         └────────────┘           ░     ║
# phi_0: ──────────────────────────░─────╫─
#             ┌───┐                ░     ║
#   a_0: ─────┤ X ├────────────────░─────╫─
#             └───┘                ░     ║
#   b_0: ──────────────────────────░─────╫─
#             ┌───┐     ┌───┐      ░ ┌─┐ ║
#   w_0: ─────┤ X ├─────┤ X ├──────░─┤M├─╫─
#             └───┘     └───┘      ░ └╥┘ ║
#   w_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   w_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   c: 2/═════════════════════════════╩══╩═
#                                     0  1
# Job id : b73853c229594c918a1cf766afb5ba68-1648622980695942
# Job Status: job has successfully run
# Raw counts: {'00': 40, '01': 2, '10': 7938, '11': 212}
# Measurement error mitigated counts {'01': 9.217176374583559e-14, '10': 8134.277914703697, '11': 57.722085296304776}
# Final counts after applying the threshold : {'10': 8134.277914703697}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├─░────
#        └────┬───┬────┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├────────────────░────
#             ├───┤                ░
#  p0_2: ─────┤ X ├────────────────░────
#             └───┘                ░
#  p1_0: ──────────────────────────░────
#                                  ░
#  p1_1: ──────────────────────────░────
#                                  ░
#  p1_2: ──────────────────────────░────
#                                  ░
#  h1_0: ──────────────────────────░────
#         ┌────────────┐           ░
#   e_0: ─┤ Ry(2.8364) ├───────────░────
#         └────────────┘           ░
# phi_0: ──────────────────────────░────
#             ┌───┐                ░
#   a_0: ─────┤ X ├────────────────░────
#             └───┘                ░ ┌─┐
#   b_0: ──────────────────────────░─┤M├
#             ┌───┐     ┌───┐      ░ └╥┘
#   w_0: ─────┤ X ├─────┤ X ├──────░──╫─
#             └───┘     └───┘      ░  ║
#   w_1: ──────────────────────────░──╫─
#                                  ░  ║
#   w_2: ──────────────────────────░──╫─
#                                  ░  ║
#   c: 1/═════════════════════════════╩═
#                                     0
# Job id : 21a8c844d65049659246c7f9b4ac34ba-1648623031803519
# Job Status: job has successfully run
# Raw counts: {'0': 8020, '1': 172}
# Measurement error mitigated counts {'0': 8150.432069547724, '1': 41.567930452276585}
# Final counts after applying the threshold : {'0': 8150.432069547724}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐ ░    ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├─░────┤M├
#        └────┬───┬────┘└───┘└───┘└───┘ ░    └╥┘
#  p0_1: ─────┤ X ├─────────────────────░─────╫─
#             ├───┤                     ░     ║
#  p0_2: ─────┤ X ├─────────────────────░─────╫─
#             └───┘                     ░     ║
#  p1_0: ───────────────────────────────░─────╫─
#                                       ░     ║
#  p1_1: ───────────────────────────────░─────╫─
#                                       ░     ║
#  p1_2: ───────────────────────────────░─────╫─
#                                       ░     ║
#  h1_0: ───────────────────────────────░─────╫─
#         ┌────────────┐                ░ ┌─┐ ║
#   e_0: ─┤ Ry(2.8364) ├────────────────░─┤M├─╫─
#         └────────────┘                ░ └╥┘ ║
# phi_0: ───────────────────────────────░──╫──╫─
#             ┌───┐                     ░  ║  ║
#   a_0: ─────┤ X ├─────────────────────░──╫──╫─
#             └───┘                     ░  ║  ║
#   b_0: ───────────────────────────────░──╫──╫─
#             ┌───┐     ┌───┐           ░  ║  ║
#   w_0: ─────┤ X ├─────┤ X ├───────────░──╫──╫─
#             └───┘     └───┘           ░  ║  ║
#   w_1: ───────────────────────────────░──╫──╫─
#                                       ░  ║  ║
#   w_2: ───────────────────────────────░──╫──╫─
#                                       ░  ║  ║
#   c: 2/══════════════════════════════════╩══╩═
#                                          0  1
# Job id : ed3e274dc96144dea7790979f5e0bf6d-16486230624311402
# Job Status: job has successfully run
# Raw counts: {'00': 93, '01': 2153, '10': 237, '11': 5709}
# Measurement error mitigated counts {'00': 50.07768143439183, '01': 2137.79672207714, '10': 132.36676089138763, '11': 5871.75883559708}
# Final counts after applying the threshold : {'11': 5871.75883559708}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├─░───────
#        └────┬───┬────┘└───┘└───┘└───┘ ░ ┌─┐
#  p0_1: ─────┤ X ├─────────────────────░─┤M├───
#             ├───┤                     ░ └╥┘
#  p0_2: ─────┤ X ├─────────────────────░──╫────
#             └───┘                     ░  ║
#  p1_0: ───────────────────────────────░──╫────
#                                       ░  ║
#  p1_1: ───────────────────────────────░──╫────
#                                       ░  ║
#  p1_2: ───────────────────────────────░──╫────
#                                       ░  ║
#  h1_0: ───────────────────────────────░──╫────
#         ┌────────────┐                ░  ║
#   e_0: ─┤ Ry(2.8364) ├────────────────░──╫────
#         └────────────┘                ░  ║
# phi_0: ───────────────────────────────░──╫────
#             ┌───┐                     ░  ║
#   a_0: ─────┤ X ├─────────────────────░──╫────
#             └───┘                     ░  ║
#   b_0: ───────────────────────────────░──╫────
#             ┌───┐     ┌───┐┌───┐      ░  ║ ┌─┐
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├──────░──╫─┤M├
#             └───┘     └───┘└───┘      ░  ║ └╥┘
#   w_1: ───────────────────────────────░──╫──╫─
#                                       ░  ║  ║
#   w_2: ───────────────────────────────░──╫──╫─
#                                       ░  ║  ║
#   c: 2/══════════════════════════════════╩══╩═
#                                          0  1
# Job id : 5687992a82dc484cbbcacb398125e6ab-16486231338117251
# Job Status: job has successfully run
# Raw counts: {'00': 2, '01': 111, '10': 75, '11': 8004}
# Measurement error mitigated counts {'11': 8192.0}
# Final counts after applying the threshold : {'11': 8192.0}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├─░───────
#        └────┬───┬────┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├─────────────────────░───────
#             ├───┤                     ░ ┌─┐
#  p0_2: ─────┤ X ├─────────────────────░─┤M├───
#             └───┘                     ░ └╥┘
#  p1_0: ───────────────────────────────░──╫────
#                                       ░  ║
#  p1_1: ───────────────────────────────░──╫────
#                                       ░  ║
#  p1_2: ───────────────────────────────░──╫────
#                                       ░  ║
#  h1_0: ───────────────────────────────░──╫────
#         ┌────────────┐                ░  ║
#   e_0: ─┤ Ry(2.8364) ├────────────────░──╫────
#         └────────────┘                ░  ║
# phi_0: ───────────────────────────────░──╫────
#             ┌───┐                     ░  ║
#   a_0: ─────┤ X ├─────────────────────░──╫────
#             └───┘                     ░  ║
#   b_0: ───────────────────────────────░──╫────
#             ┌───┐     ┌───┐┌───┐      ░  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├──────░──╫────
#             ├───┤     └───┘└───┘      ░  ║ ┌─┐
#   w_1: ─────┤ X ├─────────────────────░──╫─┤M├
#             └───┘                     ░  ║ └╥┘
#   w_2: ───────────────────────────────░──╫──╫─
#                                       ░  ║  ║
#   c: 2/══════════════════════════════════╩══╩═
#                                          0  1
# Job id : b0a8abb6119346d7bdb1cd2ce041b358-16486231933028228
# Job Status: job has successfully run
# Raw counts: {'00': 1, '01': 107, '10': 45, '11': 8039}
# Measurement error mitigated counts {'11': 8192.0}
# Final counts after applying the threshold : {'11': 8192.0}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├─░────
#        └────┬───┬────┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├─────────────────────░────
#             ├───┤                     ░
#  p0_2: ─────┤ X ├─────────────────────░────
#             └───┘                     ░
#  p1_0: ───────────────────────────────░────
#                                       ░
#  p1_1: ───────────────────────────────░────
#                                       ░
#  p1_2: ───────────────────────────────░────
#                                       ░
#  h1_0: ───────────────────────────────░────
#         ┌────────────┐                ░
#   e_0: ─┤ Ry(2.8364) ├────────────────░────
#         └────────────┘                ░
# phi_0: ───────────────────────────────░────
#             ┌───┐                     ░
#   a_0: ─────┤ X ├─────────────────────░────
#             └───┘                     ░
#   b_0: ───────────────────────────────░────
#             ┌───┐     ┌───┐┌───┐      ░
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├──────░────
#             ├───┤     └───┘└───┘      ░
#   w_1: ─────┤ X ├─────────────────────░────
#             ├───┤                     ░ ┌─┐
#   w_2: ─────┤ X ├─────────────────────░─┤M├
#             └───┘                     ░ └╥┘
#   c: 1/══════════════════════════════════╩═
#                                          0
# Job id : 4a400e162fe94afea5b0225c6fb48145-1648623230282121
# Job Status: job has successfully run
# Raw counts: {'0': 118, '1': 8074}
# Measurement error mitigated counts {'1': 8192.0}
# Final counts after applying the threshold : {'1': 8192.0}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐ ░    ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├─░────┤M├
#        └────┬───┬────┘└───┘└───┘└───┘└───┘ ░    └╥┘
#  p0_1: ─────┤ X ├──────────────────────────░─────╫─
#             ├───┤                          ░     ║
#  p0_2: ─────┤ X ├──────────────────────────░─────╫─
#             └───┘                          ░     ║
#  p1_0: ────────────────────────────────────░─────╫─
#                                            ░     ║
#  p1_1: ────────────────────────────────────░─────╫─
#                                            ░     ║
#  p1_2: ────────────────────────────────────░─────╫─
#           ┌───────┐                        ░     ║
#  h1_0: ───┤ Ry(π) ├────────────────────────░─────╫─
#         ┌─┴───────┴──┐                     ░ ┌─┐ ║
#   e_0: ─┤ Ry(2.8364) ├─────────────────────░─┤M├─╫─
#         └────────────┘                     ░ └╥┘ ║
# phi_0: ────────────────────────────────────░──╫──╫─
#             ┌───┐                          ░  ║  ║
#   a_0: ─────┤ X ├──────────────────────────░──╫──╫─
#             └───┘                          ░  ║  ║
#   b_0: ────────────────────────────────────░──╫──╫─
#             ┌───┐     ┌───┐┌───┐┌───┐      ░  ║  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├──────░──╫──╫─
#             ├───┤     ├───┤└───┘└───┘      ░  ║  ║
#   w_1: ─────┤ X ├─────┤ X ├────────────────░──╫──╫─
#             ├───┤     ├───┤                ░  ║  ║
#   w_2: ─────┤ X ├─────┤ X ├────────────────░──╫──╫─
#             └───┘     └───┘                ░  ║  ║
#   c: 2/═══════════════════════════════════════╩══╩═
#                                               0  1
# Job id : ae84f061422e4c629903c097eca80a47-1648623271560408
# Job Status: job has successfully run
# Raw counts: {'00': 258, '01': 5587, '10': 106, '11': 2241}
# Measurement error mitigated counts {'00': 138.98233079992184, '01': 5740.073038421313, '10': 60.19006851211652, '11': 2252.754562266648}
# Final counts after applying the threshold : {'01': 5740.073038421313}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├─░───────
#        └────┬───┬────┘└───┘└───┘└───┘└───┘ ░ ┌─┐
#  p0_1: ─────┤ X ├──────────────────────────░─┤M├───
#             ├───┤                          ░ └╥┘
#  p0_2: ─────┤ X ├──────────────────────────░──╫────
#             └───┘                          ░  ║
#  p1_0: ────────────────────────────────────░──╫────
#                                            ░  ║
#  p1_1: ────────────────────────────────────░──╫────
#                                            ░  ║
#  p1_2: ────────────────────────────────────░──╫────
#           ┌───────┐                        ░  ║
#  h1_0: ───┤ Ry(π) ├────────────────────────░──╫────
#         ┌─┴───────┴──┐                     ░  ║
#   e_0: ─┤ Ry(2.8364) ├─────────────────────░──╫────
#         └────────────┘                     ░  ║
# phi_0: ────────────────────────────────────░──╫────
#             ┌───┐                          ░  ║
#   a_0: ─────┤ X ├──────────────────────────░──╫────
#             └───┘                          ░  ║
#   b_0: ────────────────────────────────────░──╫────
#             ┌───┐     ┌───┐┌───┐┌───┐      ░  ║ ┌─┐
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├──────░──╫─┤M├
#             ├───┤     ├───┤└───┘└───┘      ░  ║ └╥┘
#   w_1: ─────┤ X ├─────┤ X ├────────────────░──╫──╫─
#             ├───┤     ├───┤                ░  ║  ║
#   w_2: ─────┤ X ├─────┤ X ├────────────────░──╫──╫─
#             └───┘     └───┘                ░  ║  ║
#   c: 2/═══════════════════════════════════════╩══╩═
#                                               0  1
# Job id : 213cb40eaece49c689a8334e63ea73fb-16486233116829839
# Job Status: job has successfully run
# Raw counts: {'00': 82, '01': 7906, '10': 1, '11': 203}
# Measurement error mitigated counts {'00': 1.399840028921376, '01': 8154.432108451567, '10': 0.571396122922405, '11': 35.596655396590066}
# Final counts after applying the threshold : {'01': 8154.432108451567}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├─░───────
#        └────┬───┬────┘└───┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├──────────────────────────░───────
#             ├───┤                          ░ ┌─┐
#  p0_2: ─────┤ X ├──────────────────────────░─┤M├───
#             └───┘                          ░ └╥┘
#  p1_0: ────────────────────────────────────░──╫────
#                                            ░  ║
#  p1_1: ────────────────────────────────────░──╫────
#                                            ░  ║
#  p1_2: ────────────────────────────────────░──╫────
#           ┌───────┐                        ░  ║
#  h1_0: ───┤ Ry(π) ├────────────────────────░──╫────
#         ┌─┴───────┴──┐                     ░  ║
#   e_0: ─┤ Ry(2.8364) ├─────────────────────░──╫────
#         └────────────┘                     ░  ║
# phi_0: ────────────────────────────────────░──╫────
#             ┌───┐                          ░  ║
#   a_0: ─────┤ X ├──────────────────────────░──╫────
#             └───┘                          ░  ║
#   b_0: ────────────────────────────────────░──╫────
#             ┌───┐     ┌───┐┌───┐┌───┐      ░  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├──────░──╫────
#             ├───┤     ├───┤└───┘└───┘      ░  ║ ┌─┐
#   w_1: ─────┤ X ├─────┤ X ├────────────────░──╫─┤M├
#             ├───┤     ├───┤                ░  ║ └╥┘
#   w_2: ─────┤ X ├─────┤ X ├────────────────░──╫──╫─
#             └───┘     └───┘                ░  ║  ║
#   c: 2/═══════════════════════════════════════╩══╩═
#                                               0  1
# Job id : 20bca8e7ca094f5aa095c4607cc428f2-16486233523102489
# Job Status: job has successfully run
# Raw counts: {'00': 34, '01': 8065, '11': 93}
# Measurement error mitigated counts {'01': 8165.76215650858, '10': 5.6538401685325154e-14, '11': 26.237843491421927}
# Final counts after applying the threshold : {'01': 8165.76215650858}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├─░────
#        └────┬───┬────┘└───┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├──────────────────────────░────
#             ├───┤                          ░
#  p0_2: ─────┤ X ├──────────────────────────░────
#             └───┘                          ░
#  p1_0: ────────────────────────────────────░────
#                                            ░
#  p1_1: ────────────────────────────────────░────
#                                            ░
#  p1_2: ────────────────────────────────────░────
#           ┌───────┐                        ░
#  h1_0: ───┤ Ry(π) ├────────────────────────░────
#         ┌─┴───────┴──┐                     ░
#   e_0: ─┤ Ry(2.8364) ├─────────────────────░────
#         └────────────┘                     ░
# phi_0: ────────────────────────────────────░────
#             ┌───┐                          ░
#   a_0: ─────┤ X ├──────────────────────────░────
#             └───┘                          ░
#   b_0: ────────────────────────────────────░────
#             ┌───┐     ┌───┐┌───┐┌───┐      ░
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├──────░────
#             ├───┤     ├───┤└───┘└───┘      ░
#   w_1: ─────┤ X ├─────┤ X ├────────────────░────
#             ├───┤     ├───┤                ░ ┌─┐
#   w_2: ─────┤ X ├─────┤ X ├────────────────░─┤M├
#             └───┘     └───┘                ░ └╥┘
#   c: 1/═══════════════════════════════════════╩═
#                                               0
# Job id : aac3e4620cbc4a658a99169fb2b565c1-1648623392776683
# Job Status: job has successfully run
# Raw counts: {'0': 8050, '1': 142}
# Measurement error mitigated counts {'0': 8192.0, '1': 2.6606499189713202e-15}
# Final counts after applying the threshold : {'0': 8192.0}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├─░────
#        └────┬───┬────┘└───┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├──────────────────────────░────
#             ├───┤                          ░
#  p0_2: ─────┤ X ├──────────────────────────░────
#             └───┘                          ░
#  p1_0: ────────────────────────────────────░────
#                                            ░
#  p1_1: ────────────────────────────────────░────
#                                            ░
#  p1_2: ────────────────────────────────────░────
#           ┌───────┐                        ░ ┌─┐
#  h1_0: ───┤ Ry(π) ├────────────────────────░─┤M├
#         ┌─┴───────┴──┐                     ░ └╥┘
#   e_0: ─┤ Ry(2.8364) ├─────────────────────░──╫─
#         └────────────┘                     ░  ║
# phi_0: ────────────────────────────────────░──╫─
#             ┌───┐                          ░  ║
#   a_0: ─────┤ X ├──────────────────────────░──╫─
#             └───┘                          ░  ║
#   b_0: ────────────────────────────────────░──╫─
#             ┌───┐     ┌───┐┌───┐┌───┐      ░  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├──────░──╫─
#             ├───┤     ├───┤└───┘└───┘      ░  ║
#   w_1: ─────┤ X ├─────┤ X ├────────────────░──╫─
#             ├───┤     ├───┤                ░  ║
#   w_2: ─────┤ X ├─────┤ X ├────────────────░──╫─
#             └───┘     └───┘                ░  ║
#   c: 1/═══════════════════════════════════════╩═
#                                               0
# Job id : 9958836062e548f6aba95bdc09fee377-16486234318513868
# Job Status: job has successfully run
# Raw counts: {'0': 87, '1': 8105}
# Measurement error mitigated counts {'0': 10.172606414313638, '1': 8181.827393585687}
# Final counts after applying the threshold : {'1': 8181.827393585687}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘└───┘└───┘└───┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├───────────────────────────────░──╫─┤M├
#             ├───┤                               ░  ║ └╥┘
#  p0_2: ─────┤ X ├───────────────────────────────░──╫──╫─
#             ├───┤                               ░  ║  ║
#  p1_0: ─────┤ X ├───────────────────────────────░──╫──╫─
#             └───┘                               ░  ║  ║
#  p1_1: ─────────────────────────────────────────░──╫──╫─
#                                                 ░  ║  ║
#  p1_2: ─────────────────────────────────────────░──╫──╫─
#           ┌───────┐                             ░  ║  ║
#  h1_0: ───┤ Ry(π) ├─────────────────────────────░──╫──╫─
#         ┌─┴───────┴──┐                          ░  ║  ║
#   e_0: ─┤ Ry(2.8364) ├──────────────────────────░──╫──╫─
#         └────────────┘                          ░  ║  ║
# phi_0: ─────────────────────────────────────────░──╫──╫─
#             ┌───┐                               ░  ║  ║
#   a_0: ─────┤ X ├───────────────────────────────░──╫──╫─
#             └───┘                               ░  ║  ║
#   b_0: ─────────────────────────────────────────░──╫──╫─
#             ┌───┐     ┌───┐┌───┐┌───┐           ░  ║  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├───────────░──╫──╫─
#             ├───┤     ├───┤└───┘└───┘           ░  ║  ║
#   w_1: ─────┤ X ├─────┤ X ├─────────────────────░──╫──╫─
#             ├───┤     ├───┤                     ░  ║  ║
#   w_2: ─────┤ X ├─────┤ X ├─────────────────────░──╫──╫─
#             └───┘     └───┘                     ░  ║  ║
#   c: 2/════════════════════════════════════════════╩══╩═
#                                                    0  1
# Job id : ca4e90acd0c64b5db337616b8eadef6a-1648623462011786
# Job Status: job has successfully run
# Raw counts: {'00': 21, '01': 58, '10': 2276, '11': 5837}
# Measurement error mitigated counts {'00': 3.0941915696303113e-13, '01': 5.591180880255285, '10': 2233.1516517344835, '11': 5953.25716738526}
# Final counts after applying the threshold : {'11': 5953.25716738526}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░───────
#        └────┬───┬────┘└───┘└───┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├───────────────────────────────░───────
#             ├───┤                               ░    ┌─┐
#  p0_2: ─────┤ X ├───────────────────────────────░────┤M├
#             ├───┤                               ░    └╥┘
#  p1_0: ─────┤ X ├───────────────────────────────░─────╫─
#             └───┘                               ░     ║
#  p1_1: ─────────────────────────────────────────░─────╫─
#                                                 ░     ║
#  p1_2: ─────────────────────────────────────────░─────╫─
#           ┌───────┐                             ░     ║
#  h1_0: ───┤ Ry(π) ├─────────────────────────────░─────╫─
#         ┌─┴───────┴──┐                          ░     ║
#   e_0: ─┤ Ry(2.8364) ├──────────────────────────░─────╫─
#         └────────────┘                          ░     ║
# phi_0: ─────────────────────────────────────────░─────╫─
#             ┌───┐                               ░     ║
#   a_0: ─────┤ X ├───────────────────────────────░─────╫─
#             └───┘                               ░     ║
#   b_0: ─────────────────────────────────────────░─────╫─
#             ┌───┐     ┌───┐┌───┐┌───┐┌───┐      ░ ┌─┐ ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├┤ X ├──────░─┤M├─╫─
#             ├───┤     ├───┤└───┘└───┘└───┘      ░ └╥┘ ║
#   w_1: ─────┤ X ├─────┤ X ├─────────────────────░──╫──╫─
#             ├───┤     ├───┤                     ░  ║  ║
#   w_2: ─────┤ X ├─────┤ X ├─────────────────────░──╫──╫─
#             └───┘     └───┘                     ░  ║  ║
#   c: 2/════════════════════════════════════════════╩══╩═
#                                                    0  1
# Job id : fac4620400994e238dad7f82bef89be1-16486235111809258
# Job Status: job has successfully run
# Raw counts: {'01': 35, '10': 121, '11': 8036}
# Measurement error mitigated counts {'10': 22.451655669170343, '11': 8169.548344330832}
# Final counts after applying the threshold : {'11': 8169.548344330832}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘└───┘└───┘└───┘└───┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├────────────────────────────────────░──╫─┤M├
#             ├───┤                                    ░  ║ └╥┘
#  p0_2: ─────┤ X ├────────────────────────────────────░──╫──╫─
#             ├───┤                                    ░  ║  ║
#  p1_0: ─────┤ X ├────────────────────────────────────░──╫──╫─
#             └───┘                                    ░  ║  ║
#  p1_1: ──────────────────────────────────────────────░──╫──╫─
#                                                      ░  ║  ║
#  p1_2: ──────────────────────────────────────────────░──╫──╫─
#           ┌───────┐                                  ░  ║  ║
#  h1_0: ───┤ Ry(π) ├──────────────────────────────────░──╫──╫─
#         ┌─┴───────┴──┐                               ░  ║  ║
#   e_0: ─┤ Ry(2.8364) ├───────────────────────────────░──╫──╫─
#         └────────────┘                               ░  ║  ║
# phi_0: ──────────────────────────────────────────────░──╫──╫─
#             ┌───┐     ┌───┐                          ░  ║  ║
#   a_0: ─────┤ X ├─────┤ X ├──────────────────────────░──╫──╫─
#             └───┘     └───┘                          ░  ║  ║
#   b_0: ──────────────────────────────────────────────░──╫──╫─
#             ┌───┐     ┌───┐┌───┐┌───┐┌───┐┌───┐      ░  ║  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├──────░──╫──╫─
#             ├───┤     ├───┤└───┘└───┘└───┘└───┘      ░  ║  ║
#   w_1: ─────┤ X ├─────┤ X ├──────────────────────────░──╫──╫─
#             ├───┤     ├───┤                          ░  ║  ║
#   w_2: ─────┤ X ├─────┤ X ├──────────────────────────░──╫──╫─
#             └───┘     └───┘                          ░  ║  ║
#   c: 2/═════════════════════════════════════════════════╩══╩═
#                                                         0  1
# Job id : d3037633e4d1467a85daa417d82b82bf-1648623551829495
# Job Status: job has successfully run
# Raw counts: {'00': 79, '01': 24, '10': 5846, '11': 2243}
# Measurement error mitigated counts {'00': 17.973668837703983, '01': 0.39997146088956814, '10': 5984.558244692889, '11': 2189.068115008518}
# Final counts after applying the threshold : {'10': 5984.558244692889}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░───────
#        └────┬───┬────┘└───┘└───┘└───┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├────────────────────────────────────░───────
#             ├───┤                                    ░    ┌─┐
#  p0_2: ─────┤ X ├────────────────────────────────────░────┤M├
#             ├───┤                                    ░    └╥┘
#  p1_0: ─────┤ X ├────────────────────────────────────░─────╫─
#             └───┘                                    ░     ║
#  p1_1: ──────────────────────────────────────────────░─────╫─
#                                                      ░     ║
#  p1_2: ──────────────────────────────────────────────░─────╫─
#           ┌───────┐                                  ░     ║
#  h1_0: ───┤ Ry(π) ├──────────────────────────────────░─────╫─
#         ┌─┴───────┴──┐                               ░     ║
#   e_0: ─┤ Ry(2.8364) ├───────────────────────────────░─────╫─
#         └────────────┘                               ░     ║
# phi_0: ──────────────────────────────────────────────░─────╫─
#             ┌───┐     ┌───┐                          ░     ║
#   a_0: ─────┤ X ├─────┤ X ├──────────────────────────░─────╫─
#             └───┘     └───┘                          ░     ║
#   b_0: ──────────────────────────────────────────────░─────╫─
#             ┌───┐     ┌───┐┌───┐┌───┐┌───┐┌───┐      ░ ┌─┐ ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├──────░─┤M├─╫─
#             ├───┤     ├───┤└───┘└───┘└───┘└───┘      ░ └╥┘ ║
#   w_1: ─────┤ X ├─────┤ X ├──────────────────────────░──╫──╫─
#             ├───┤     ├───┤                          ░  ║  ║
#   w_2: ─────┤ X ├─────┤ X ├──────────────────────────░──╫──╫─
#             └───┘     └───┘                          ░  ║  ║
#   c: 2/═════════════════════════════════════════════════╩══╩═
#                                                         0  1
# Job id : 8fc38d1f6bf84c4f99a04d78b66c6ae3-1648623591897247
# Job Status: job has successfully run
# Raw counts: {'00': 39, '10': 7962, '11': 191}
# Measurement error mitigated counts {'00': 10.92807329027624, '01': 9.818682115327078e-17, '10': 8170.841739352808, '11': 10.230187356915863}
# Final counts after applying the threshold : {'10': 8170.841739352808}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░────
#        └────┬───┬────┘├───┤└───┘└───┘└───┘└───┘└───┘ ░
#  p0_1: ─────┤ X ├─────┤ X ├──────────────────────────░────
#             ├───┤     └───┘                          ░ ┌─┐
#  p0_2: ─────┤ X ├────────────────────────────────────░─┤M├
#             ├───┤                                    ░ └╥┘
#  p1_0: ─────┤ X ├────────────────────────────────────░──╫─
#             └───┘                                    ░  ║
#  p1_1: ──────────────────────────────────────────────░──╫─
#                                                      ░  ║
#  p1_2: ──────────────────────────────────────────────░──╫─
#           ┌───────┐                                  ░  ║
#  h1_0: ───┤ Ry(π) ├──────────────────────────────────░──╫─
#         ┌─┴───────┴──┐                               ░  ║
#   e_0: ─┤ Ry(2.8364) ├───────────────────────────────░──╫─
#         └────────────┘                               ░  ║
# phi_0: ──────────────────────────────────────────────░──╫─
#             ┌───┐     ┌───┐                          ░  ║
#   a_0: ─────┤ X ├─────┤ X ├──────────────────────────░──╫─
#             └───┘     └───┘                          ░  ║
#   b_0: ──────────────────────────────────────────────░──╫─
#             ┌───┐     ┌───┐┌───┐┌───┐┌───┐┌───┐      ░  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├──────░──╫─
#             ├───┤     ├───┤└───┘└───┘└───┘└───┘      ░  ║
#   w_1: ─────┤ X ├─────┤ X ├──────────────────────────░──╫─
#             ├───┤     ├───┤                          ░  ║
#   w_2: ─────┤ X ├─────┤ X ├──────────────────────────░──╫─
#             └───┘     └───┘                          ░  ║
#   c: 1/═════════════════════════════════════════════════╩═
#                                                         0
# Job id : 32ee7d0c80d3459395f9d6811393ddeb-1648623642318809
# Job Status: job has successfully run
# Raw counts: {'0': 53, '1': 8139}
# Measurement error mitigated counts {'0': 5.06867960733935, '1': 8186.931320392661}
# Final counts after applying the threshold : {'1': 8186.931320392661}
# Threshold : 2457.6
#        ┌─────────────┐┌───┐┌───┐┌───┐┌───┐┌───┐┌───┐┌────────────┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├┤ Ry(1.1071) ├─░────
#        └────┬───┬────┘├───┤└───┘└───┘└───┘└───┘└───┘└────────────┘ ░
#  p0_1: ─────┤ X ├─────┤ X ├────────────────────────────────────────░────
#             ├───┤     └───┘                                        ░
#  p0_2: ─────┤ X ├──────────────────────────────────────────────────░────
#             ├───┤                                                  ░
#  p1_0: ─────┤ X ├──────────────────────────────────────────────────░────
#             └───┘                                                  ░
#  p1_1: ────────────────────────────────────────────────────────────░────
#                                                                    ░ ┌─┐
#  p1_2: ────────────────────────────────────────────────────────────░─┤M├
#           ┌───────┐                                                ░ └╥┘
#  h1_0: ───┤ Ry(π) ├────────────────────────────────────────────────░──╫─
#         ┌─┴───────┴──┐                                             ░  ║
#   e_0: ─┤ Ry(2.8364) ├─────────────────────────────────────────────░──╫─
#         └────────────┘                                             ░  ║
# phi_0: ────────────────────────────────────────────────────────────░──╫─
#             ┌───┐     ┌───┐                                        ░  ║
#   a_0: ─────┤ X ├─────┤ X ├────────────────────────────────────────░──╫─
#             └───┘     └───┘                                        ░  ║
#   b_0: ────────────────────────────────────────────────────────────░──╫─
#             ┌───┐     ┌───┐┌───┐┌───┐┌───┐┌───┐                    ░  ║
#   w_0: ─────┤ X ├─────┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├────────────────────░──╫─
#             ├───┤     ├───┤└───┘└───┘└───┘└───┘                    ░  ║
#   w_1: ─────┤ X ├─────┤ X ├────────────────────────────────────────░──╫─
#             ├───┤     ├───┤                                        ░  ║
#   w_2: ─────┤ X ├─────┤ X ├────────────────────────────────────────░──╫─
#             └───┘     └───┘                                        ░  ║
#   c: 1/═══════════════════════════════════════════════════════════════╩═
#                                                                       0
# Job id : d2b3ed99b5e94799be1eb704dad433cb-1648623712128526
# Job Status: job has successfully run
# Raw counts: {'0': 8071, '1': 121}
# Measurement error mitigated counts {'0': 8173.584113691748, '1': 18.415886308252258}
# Final counts after applying the threshold : {'0': 8173.584113691748}
# Threshold : 2457.6

# %%
results_30[0].draw('mpl',fold=100)

# %%
run(step=1, backend=backend, threshold='0.3', qc_qcs=results_30, shots=10000)
# Out:
# Job id : 758810cbbf7a4bd8a24a13ee449794cc-1648623741637724
# Job Status: job has successfully run
