# %%
from sample.onestepSim_LBNL import runQuantum as step_1
circuit_LBNL1 = step_1(gLR=1,dophisplit=1)
#circuit_LBNL1.draw('mpl',fold=100)

import icepp

# %%
backend_name = 'ibm_kawasaki'

# %%
from qiskit import *
IBMQ.load_account()
from pytket.extensions.qiskit import IBMQBackend, AerStateBackend, AerBackend

# Fill your provider information
# Example: provider = IBMQ.get_provider(hub=ibm-q'',group='open',project='main')
provider = IBMQ.get_provider(hub='',group='',project='')

backend = provider.get_backend(backend_name)
sim_b = AerBackend()
dev_b = IBMQBackend(backend_name=backend_name, hub='',group='',project='')

# %%
"""
import csv
header = ['name', 'original circuit', 'transpiled circuit', 'gate counts', 'depth', 'qubits', 'raw counts', 'F_sim', 'F_meas']

with open(backend_name+'_1step_qc.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(header)

f.close()
"""
# Out:
# "\nimport csv\nheader = ['name', 'original circuit', 'transpiled circuit', 'gate counts', 'depth', 'qubits', 'raw counts', 'F_sim', 'F_meas']\n\nwith open(backend_name+'_1step_qc.csv', 'w') as f:\n    writer = csv.writer(f)\n    writer.writerow(header)\n\nf.close()\n"

# %%
import csv
import math
from decimal import Decimal, ROUND_HALF_UP, ROUND_HALF_EVEN
def run(step, backend, threshold, qc_qcs, shots):
    
    if step == 1:
        ps = step_1(gLR=1,dophisplit=1)
    if step == 2:
        ps = step_2(gLR=1,dophisplit=1)
    
    b_qc = qc_qcs[0]
    t_qc = qc_qcs[1]
    counts = analysis(t_qc)
    
    simulation = dic_size(ps)
    Fsim = fidelity(simulation, dic_size(b_qc) ,1)
    
    results = experiment(t_qc, backend, shots)
    
    fidelities=[]
    for x in range(30):
        raw = results.get_counts(x)
        fidelities.append( fidelity(simulation,raw,shots) )
        
    key_result = [threshold, b_qc.data, t_qc.data, counts[1], counts[0], b_qc.num_qubits, raw, Fsim, fidelities]

    csv_generator(step, [key_result])
    

def experiment(qc, backend, shots):
    
    results = icepp.qc_experiment(qc_list=[qc]*30, backend=backend, shots=shots).run()
    
    return results

def csv_generator(step, final_result):
    # Job_is future work
    body = final_result

    if step == 1:
        step_str = '_1step_qc.csv'
    if step == 2:
        step_str = '_2step_qc.csv'
        
    with open(backend_name+step_str, 'a') as f:
        writer = csv.writer(f)
        writer.writerows(body)

    f.close()

def dic_size(qc):
    
    sim_result = icepp.simulator(qc).statevector_simulator(output='probabilities_distribution')
    
    new_sim_result = key_changer(qc, sim_result)
        
    return new_sim_result

def key_changer(qc, dic):
    measure_list = [0]*qc.num_clbits
    for op in qc.get_instructions('measure'):
        measure_list[op[2][0]._index] = qc.qubits.index(op[1][0])
    
    new_dic = {}
    for key in dic.keys():
        new_key = ''
        for index in reversed(measure_list):
            new_key = new_key + key[qc.num_qubits - index -1]
            
        if new_key in new_dic.keys():
            new_dic[new_key] = new_dic[new_key] + dic[key]
        else:
            new_dic[new_key] = dic[key]
        
    return new_dic

def fidelity(count1,count2,shots):
    fidelity=0
    for key in count1.keys():
        if (key in count2) and (count1[key] >0) and (count2[key] >0):
            fidelity += math.sqrt(count1[key]*count2[key]/shots)
    return float(Decimal(str(fidelity)).quantize(Decimal('0.00001'), rounding=ROUND_HALF_UP))

def analysis(qc):
    
    tr_qc = transpile(qc,basis_gates=['id','x','sx','rz','cx','reset'], optimization_level=0)
    time = schedule(qc, backend).duration*backend.configuration().dt
    
    return [time, tr_qc.count_ops()]

# %% [markdown]
# ## Measurement of bases by a Quantum computer (cutting-off noise bases)

# %%
results_05 = icepp.pass_manager(qc=circuit_LBNL1, level=2, backend=backend, backend_tket=dev_b, shots=8192, measure_type='qc', threshold_type=['constant',0.005], zne='off').auto_manager()
# Out:
#              ░
#  p0_0: ──────░────
#        ┌───┐ ░
#  p0_1: ┤ X ├─░────
#        ├───┤ ░ ┌─┐
#  p0_2: ┤ X ├─░─┤M├
#        └───┘ ░ └╥┘
#  p1_0: ──────░──╫─
#              ░  ║
#  p1_1: ──────░──╫─
#              ░  ║
#  p1_2: ──────░──╫─
#              ░  ║
#  h1_0: ──────░──╫─
#              ░  ║
#   e_0: ──────░──╫─
#              ░  ║
# phi_0: ──────░──╫─
#              ░  ║
#   a_0: ──────░──╫─
#              ░  ║
#   b_0: ──────░──╫─
#              ░  ║
#   w_0: ──────░──╫─
#              ░  ║
#   w_1: ──────░──╫─
#              ░  ║
#   w_2: ──────░──╫─
#              ░  ║
#   c: 1/═════════╩═
#                 0
# Job id : a65f62e32ebd423fa74b002150366e04-16486154990191581
# Job Status: job has successfully run
# Raw counts: {'0': 45, '1': 8147}
# Measurement error mitigated counts {'0': 4.048430939396397, '1': 8187.951569060603}
# Final counts after applying the threshold : {'1': 8187.951569060603}
# Threshold : 40.96
#        ┌─────────────┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├───────────░──╫─┤M├
#             ├───┤           ░  ║ └╥┘
#  p0_2: ─────┤ X ├───────────░──╫──╫─
#             └───┘           ░  ║  ║
#  p1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  h1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   e_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
# phi_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   a_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   b_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   c: 2/════════════════════════╩══╩═
#                                0  1
# Job id : 510fbe8c3e6d4972837ca6426fdc7c0a-1648615609622846
# Job Status: job has successfully run
# Raw counts: {'00': 23, '01': 52, '10': 2297, '11': 5820}
# Measurement error mitigated counts {'00': 2.1763184615578454e-13, '01': 9.883157917455212e-14, '10': 2261.341463811183, '11': 5930.6585361888165}
# Final counts after applying the threshold : {'10': 2261.341463811183, '11': 5930.6585361888165}
# Threshold : 40.96
#        ┌─────────────┐┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───░───────
#             ├───┤            │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───░────┤M├
#             └───┘            │   ░    └╥┘
#  p1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_1: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_2: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  h1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   e_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
# phi_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   a_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   b_0: ──────────────────────┼───░─────╫─
#                            ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├─░─┤M├─╫─
#                            └───┘ ░ └╥┘ ║
#   w_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   w_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   c: 2/═════════════════════════════╩══╩═
#                                     0  1
# Job id : 1138b8ae4243401baada787bb89ccaeb-1648615742828695
# Job Status: job has successfully run
# Raw counts: {'00': 27, '01': 83, '10': 2215, '11': 5867}
# Measurement error mitigated counts {'00': 0.2507255349139344, '01': 13.663258116307041, '10': 2178.517372273274, '11': 5999.568644075505}
# Final counts after applying the threshold : {'10': 2178.517372273274, '11': 5999.568644075505}
# Threshold : 40.96
#        ┌─────────────┐┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼────────░────
#             ├───┤            │        ░
#  p0_2: ─────┤ X ├────────────┼────────░────
#             └───┘            │        ░
#  p1_0: ──────────────────────┼────────░────
#                              │        ░
#  p1_1: ──────────────────────┼────────░────
#                              │        ░
#  p1_2: ──────────────────────┼────────░────
#                              │        ░
#  h1_0: ──────────────────────┼────────░────
#                              │        ░
#   e_0: ──────────────────────┼────────░────
#                              │        ░
# phi_0: ──────────────────────┼────────░────
#                              │  ┌───┐ ░ ┌─┐
#   a_0: ──────────────────────┼──┤ X ├─░─┤M├
#                              │  └─┬─┘ ░ └╥┘
#   b_0: ──────────────────────┼────┼───░──╫─
#                            ┌─┴─┐  │   ░  ║
#   w_0: ────────────────────┤ X ├──■───░──╫─
#                            └───┘      ░  ║
#   w_1: ───────────────────────────────░──╫─
#                                       ░  ║
#   w_2: ───────────────────────────────░──╫─
#                                       ░  ║
#   c: 1/══════════════════════════════════╩═
#                                          0
# Job id : c1dc984f45eb4f74a3b5da658096912d-1648615880344546
# Job Status: job has successfully run
# Raw counts: {'0': 2304, '1': 5888}
# Measurement error mitigated counts {'0': 2257.854899020652, '1': 5934.145100979348}
# Final counts after applying the threshold : {'0': 2257.854899020652, '1': 5934.145100979348}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘  │                       │  └───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼────────░──╫─┤M├
#             ├───┤            │                       │        ░  ║ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼────────░──╫──╫─
#             └───┘            │                       │        ░  ║  ║
#  p1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_1: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_2: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  h1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │       ┌────────────┐  │        ░  ║  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼────────░──╫──╫─
#                              │       └─────┬──────┘  │        ░  ║  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘      ░  ║  ║
#   w_1: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════╩══╩═
#                                                                  0  1
# Job id : 8e7df1f5f3c1436ab3c1f56d056390ca-16486162023413792
# Job Status: job has successfully run
# Raw counts: {'00': 88, '01': 30, '10': 5838, '11': 2236}
# Measurement error mitigated counts {'00': 3.0203714963122907e-13, '10': 6000.931335966333, '11': 2191.0686640336685}
# Final counts after applying the threshold : {'10': 6000.931335966333, '11': 2191.0686640336685}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░───────
#             ├───┤            │                       │         │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░────┤M├
#             └───┘            │                       │         │   ░    └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │       ┌────────────┐  │         │   ░     ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───░─────╫─
#                              │       └─────┬──────┘  │         │   ░     ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼───░─────╫─
#                              │  ┌───┐      │         │         │   ░     ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼───░─────╫─
#                              │  └─┬─┘                │         │   ░     ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼───░─────╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├─░─┤M├─╫─
#                            └───┘                   └───┘     └───┘ ░ └╥┘ ║
#   w_1: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   w_2: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════╩══╩═
#                                                                       0  1
# Job id : 68e81ffc4e1848959eeff1e3d42cbe4e-1648616472226604
# Job Status: job has successfully run
# Raw counts: {'00': 121, '01': 37, '10': 5751, '11': 2283}
# Measurement error mitigated counts {'10': 5899.294582813988, '11': 2292.7054171860264}
# Final counts after applying the threshold : {'10': 5899.294582813988, '11': 2292.7054171860264}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             ├───┤            │                       │         │        ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             └───┘            │                       │         │        ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │       ┌────────────┐  │         │        ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼────────░────
#                              │       └─────┬──────┘  │         │        ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼────────░────
#                              │  ┌───┐      │         │         │        ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼────────░────
#                              │  └─┬─┘                │         │  ┌───┐ ░ ┌─┐
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├─░─┤M├
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘ ░ └╥┘
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■───░──╫─
#                            └───┘                   └───┘     └───┘      ░  ║
#   w_1: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   w_2: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   c: 1/════════════════════════════════════════════════════════════════════╩═
#                                                                            0
# Job id : 5c83c2326bab43349b6a9c5ec4cab005-16486185402833018
# Job Status: job has successfully run
# Raw counts: {'0': 5753, '1': 2439}
# Measurement error mitigated counts {'0': 5768.325332680182, '1': 2423.6746673198177}
# Final counts after applying the threshold : {'0': 5768.325332680182, '1': 2423.6746673198177}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐ ░    ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├─░────┤M├
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘ ░    └╥┘
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             ├───┤            │                       │         │                        │        ░     ║
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             └───┘            │                       │         │                        │        ░     ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │        ░ ┌─┐ ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼────────░─┤M├─╫─
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │        ░ └╥┘ ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │         │              │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │         │  ┌───┐       │         │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘     └───┘                    └───┘      ░  ║  ║
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   w_2: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   c: 2/═════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                     0  1
# Job id : a53f55a82878450b9840476dfa3ca80e-1648618611001576
# Job Status: job has successfully run
# Raw counts: {'00': 2018, '01': 509, '10': 425, '11': 5240}
# Measurement error mitigated counts {'00': 2037.472807748977, '01': 434.02168013448124, '10': 369.2802707834873, '11': 5351.225241333055}
# Final counts after applying the threshold : {'00': 2037.472807748977, '01': 434.02168013448124, '10': 369.2802707834873, '11': 5351.225241333055}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐ ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├─░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │ ░ ┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░─┤M├───
#             ├───┤            │                       │         │                        │       │       │ ░ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#             └───┘            │                       │         │                        │       │       │ ░  ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │                       │         │                        │       │       │ ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │                       │         │                        │       │       │ ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │                       │         │                        │       │  Rccx │ ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├─░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │ ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├─░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │ ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├─░──╫────
#                              │  ┌───┐      │         │         │              │         │       │       │ ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├─░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │ ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├─░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │ ░  ║ ┌─┐
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├─░──╫─┤M├
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘ ░  ║ └╥┘
#   w_1: ───────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                           ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                           ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                              0  1
# Job id : 14a9325779014f11afc5bcd454979c63-1648618791947479
# Job Status: job has successfully run
# Raw counts: {'00': 21, '01': 2956, '10': 61, '11': 5154}
# Measurement error mitigated counts {'01': 3002.754131712686, '10': 8.101232775670784, '11': 5181.144635511644}
# Final counts after applying the threshold : {'01': 3002.754131712686, '11': 5181.144635511644}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │      ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░───────
#             ├───┤            │                       │         │                        │       │       │      ░ ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░─┤M├───
#             └───┘            │                       │         │                        │       │       │      ░ └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │                       │         │                        │       │       │      ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │                       │         │                        │       │       │      ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │                       │         │                        │       │  Rccx │      ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │      ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │      ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────░──╫────
#                              │  ┌───┐      │         │         │              │         │       │       │      ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │      ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │      ░  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───░──╫────
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐ ░  ║ ┌─┐
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░──╫─┤M├
#                                                                                                          └───┘ ░  ║ └╥┘
#   w_2: ────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                                ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                                   0  1
# Job id : c0d46f02aaaa4266b399f53778c64ea6-16486188729271948
# Job Status: job has successfully run
# Raw counts: {'00': 175, '01': 2441, '10': 394, '11': 5182}
# Measurement error mitigated counts {'00': 1.5974869248818206, '01': 2583.0709906839747, '10': 29.292019390028198, '11': 5578.039503001114}
# Final counts after applying the threshold : {'01': 2583.0709906839747, '11': 5578.039503001114}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐           ░ »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├───────────░─»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │           ░ »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#             ├───┤            │                       │         │                        │       │       │           ░ »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#             └───┘            │                       │         │                        │       │       │           ░ »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │                       │         │                        │       │       │           ░ »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │                       │         │                        │       │       │           ░ »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │                       │         │                        │       │  Rccx │           ░ »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├───────────░─»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │           ░ »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├───────────░─»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │           ░ »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├───────────░─»
#                              │  ┌───┐      │         │         │              │         │       │       │           ░ »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├───────────░─»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │           ░ »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├───────────░─»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │           ░ »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■────────░─»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐      ░ »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■───░─»
#                                                                                                          └───┘┌─┴─┐ ░ »
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░─»
#                                                                                                               └───┘ ░ »
#   c: 1/═══════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                       »
# «
# « p0_0: ───
# «
# « p0_1: ───
# «
# « p0_2: ───
# «
# « p1_0: ───
# «
# « p1_1: ───
# «
# « p1_2: ───
# «
# « h1_0: ───
# «
# «  e_0: ───
# «
# «phi_0: ───
# «
# «  a_0: ───
# «
# «  b_0: ───
# «
# «  w_0: ───
# «
# «  w_1: ───
# «       ┌─┐
# «  w_2: ┤M├
# «       └╥┘
# «  c: 1/═╩═
# «        0
# Job id : 9e2c0389cc7247be9cb2a8863e91b845-1648618974337399
# Job Status: job has successfully run
# Raw counts: {'0': 3254, '1': 4938}
# Measurement error mitigated counts {'0': 2905.861924333391, '1': 5286.13807566661}
# Final counts after applying the threshold : {'0': 2905.861924333391, '1': 5286.13807566661}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤            │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐ ░    ┌─┐
# « p0_0: ───────────────────┤1      ├┤ X ├─░────┤M├
# «                          │       │└───┘ ░    └╥┘
# « p0_1: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p0_2: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p1_0: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p1_1: ───────────────────┤       ├──────░─────╫─
# «                          │       │      ░     ║
# « p1_2: ───────────────────┤       ├──────░─────╫─
# «       ┌───────┐          │  Rccx │      ░     ║
# « h1_0: ┤ Ry(π) ├──────────┤       ├──────░─────╫─
# «       └───┬───┘          │       │      ░ ┌─┐ ║
# «  e_0: ────┼──────────────┤0      ├──────░─┤M├─╫─
# «           │              │       │      ░ └╥┘ ║
# «phi_0: ────┼──────────────┤       ├──────░──╫──╫─
# «           │              │       │      ░  ║  ║
# «  a_0: ────┼──────────────┤       ├──────░──╫──╫─
# «           │              │       │      ░  ║  ║
# «  b_0: ────┼──────────────┤       ├──────░──╫──╫─
# «           │              │       │      ░  ║  ║
# «  w_0: ────┼───────────■──┤2      ├──────░──╫──╫─
# «           │         ┌─┴─┐└───────┘      ░  ║  ║
# «  w_1: ────┼──────■──┤ X ├───────────────░──╫──╫─
# «           │    ┌─┴─┐└───┘               ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────────░──╫──╫─
# «                └───┘                    ░  ║  ║
# «  c: 2/═════════════════════════════════════╩══╩═
# «                                            0  1
# Job id : 295c8979ae294dabada3f032769bacd4-1648619022890094
# Job Status: job has successfully run
# Raw counts: {'00': 2313, '01': 3139, '10': 1637, '11': 1103}
# Measurement error mitigated counts {'00': 2287.5061443377617, '01': 3165.490027583893, '10': 1641.726647579941, '11': 1097.277180498403}
# Final counts after applying the threshold : {'00': 2287.5061443377617, '01': 3165.490027583893, '10': 1641.726647579941, '11': 1097.277180498403}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤            │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐ ░
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├─░───────
# «                          │       │└───┘│       │ ░ ┌─┐
# « p0_1: ───────────────────┤       ├─────┤       ├─░─┤M├───
# «                          │       │     │       │ ░ └╥┘
# « p0_2: ───────────────────┤       ├─────┤       ├─░──╫────
# «                          │       │     │       │ ░  ║
# « p1_0: ───────────────────┤       ├─────┤       ├─░──╫────
# «                          │       │     │       │ ░  ║
# « p1_1: ───────────────────┤       ├─────┤       ├─░──╫────
# «                          │       │     │       │ ░  ║
# « p1_2: ───────────────────┤       ├─────┤       ├─░──╫────
# «       ┌───────┐          │  Rccx │     │  Rccx │ ░  ║
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├─░──╫────
# «       └───┬───┘          │       │     │       │ ░  ║
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├─░──╫────
# «           │              │       │     │       │ ░  ║
# «phi_0: ────┼──────────────┤       ├─────┤       ├─░──╫────
# «           │              │       │     │       │ ░  ║
# «  a_0: ────┼──────────────┤       ├─────┤       ├─░──╫────
# «           │              │       │     │       │ ░  ║
# «  b_0: ────┼──────────────┤       ├─────┤       ├─░──╫────
# «           │              │       │     │       │ ░  ║ ┌─┐
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├─░──╫─┤M├
# «           │         ┌─┴─┐└───────┘     └───────┘ ░  ║ └╥┘
# «  w_1: ────┼──────■──┤ X ├────────────────────────░──╫──╫─
# «           │    ┌─┴─┐└───┘                        ░  ║  ║
# «  w_2: ────■────┤ X ├─────────────────────────────░──╫──╫─
# «                └───┘                             ░  ║  ║
# «  c: 2/══════════════════════════════════════════════╩══╩═
# «                                                     0  1
# Job id : f07c75e8e384465facd6e060c3af237b-1648619100913627
# Job Status: job has successfully run
# Raw counts: {'00': 86, '01': 4950, '10': 61, '11': 3095}
# Measurement error mitigated counts {'00': 38.11184520253689, '01': 5029.001453437432, '10': 28.74132252985625, '11': 3096.145378830175}
# Final counts after applying the threshold : {'01': 5029.001453437432, '11': 3096.145378830175}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤            │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐      ░
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├──────░───────
# «                          │       │└───┘│       │      ░
# « p0_1: ───────────────────┤       ├─────┤       ├──────░───────
# «                          │       │     │       │      ░ ┌─┐
# « p0_2: ───────────────────┤       ├─────┤       ├──────░─┤M├───
# «                          │       │     │       │      ░ └╥┘
# « p1_0: ───────────────────┤       ├─────┤       ├──────░──╫────
# «                          │       │     │       │      ░  ║
# « p1_1: ───────────────────┤       ├─────┤       ├──────░──╫────
# «                          │       │     │       │      ░  ║
# « p1_2: ───────────────────┤       ├─────┤       ├──────░──╫────
# «       ┌───────┐          │  Rccx │     │  Rccx │      ░  ║
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├──────░──╫────
# «       └───┬───┘          │       │     │       │      ░  ║
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «phi_0: ────┼──────────────┤       ├─────┤       ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «  a_0: ────┼──────────────┤       ├─────┤       ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «  b_0: ────┼──────────────┤       ├─────┤       ├──────░──╫────
# «           │              │       │     │       │      ░  ║
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├──■───░──╫────
# «           │         ┌─┴─┐└───────┘     └───────┘┌─┴─┐ ░  ║ ┌─┐
# «  w_1: ────┼──────■──┤ X ├───────────────────────┤ X ├─░──╫─┤M├
# «           │    ┌─┴─┐└───┘                       └───┘ ░  ║ └╥┘
# «  w_2: ────■────┤ X ├──────────────────────────────────░──╫──╫─
# «                └───┘                                  ░  ║  ║
# «  c: 2/═══════════════════════════════════════════════════╩══╩═
# «                                                          0  1
# Job id : 06ce2bd36acd40d3bc937c3255e1d40d-16486192828365288
# Job Status: job has successfully run
# Raw counts: {'00': 125, '01': 4853, '10': 80, '11': 3134}
# Measurement error mitigated counts {'00': 1.6484591469634324e-12, '01': 4998.538743172953, '10': 4.416577628877222e-14, '11': 3193.4612568270454}
# Final counts after applying the threshold : {'01': 4998.538743172953, '11': 3193.4612568270454}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
# ...
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐                             ┌───────┐┌───┐               ┌───┐     »
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├─────────────────────────────┤1      ├┤ X ├──■─────────■──┤ X ├──■──»
# «                          │       │└───┘│       │                             │       │└───┘  │         │  └───┘  │  »
# « p0_1: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                             │       │       │         │         │  »
# « p0_2: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   ┌───┐     │       │       │         │         │  »
# « p1_0: ───────────────────┤       ├─────┤       ├───────────────────┤ X ├─────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   └─┬─┘     │       │       │         │         │  »
# « p1_1: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                     │       │       │       │         │         │  »
# « p1_2: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «       ┌───────┐          │  Rccx │     │  Rccx │          ┌───────┐  │       │  Rccx │       │         │         │  »
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├──────────┤ Ry(π) ├──■───────┤       ├───────┼─────────┼─────────┼──»
# «       └───┬───┘          │       │     │       │          └───┬───┘          │       │       │         │         │  »
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├──────────────┼──────────────┤0      ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │         │         │  »
# «phi_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  ┌───┐  │         │  »
# «  a_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼──┤ X ├──┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  └─┬─┘  │         │  »
# «  b_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼────┼────┼─────────┼──»
# «           │              │       │     │       │              │              │       │     ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐»
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├──■───────────┼───────────■──┤2      ├─────┤ X ├──■──┤ X ├─────┤ X ├»
# «           │         ┌─┴─┐└───────┘     └───────┘┌─┴─┐         │         ┌─┴─┐└───────┘     └───┘     └───┘     └───┘»
# «  w_1: ────┼──────■──┤ X ├───────────────────────┤ X ├──■──────┼──────■──┤ X ├───────────────────────────────────────»
# «           │    ┌─┴─┐└───┘                       └───┘┌─┴─┐    │    ┌─┴─┐└───┘                                       »
# «  w_2: ────■────┤ X ├─────────────────────────────────┤ X ├────■────┤ X ├────────────────────────────────────────────»
# «                └───┘                                 └───┘         └───┘                                            »
# «  c: 1/══════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                     »
# «                  ░
# « p0_0: ───────■───░────
# «              │   ░
# « p0_1: ───────┼───░────
# «              │   ░ ┌─┐
# « p0_2: ───────┼───░─┤M├
# «              │   ░ └╥┘
# « p1_0: ───────┼───░──╫─
# «              │   ░  ║
# « p1_1: ───────┼───░──╫─
# «              │   ░  ║
# « p1_2: ───────┼───░──╫─
# «              │   ░  ║
# « h1_0: ───────┼───░──╫─
# «              │   ░  ║
# «  e_0: ───────┼───░──╫─
# «              │   ░  ║
# «phi_0: ───────┼───░──╫─
# «              │   ░  ║
# «  a_0: ───────┼───░──╫─
# «       ┌───┐  │   ░  ║
# «  b_0: ┤ X ├──┼───░──╫─
# «       └─┬─┘┌─┴─┐ ░  ║
# «  w_0: ──■──┤ X ├─░──╫─
# «            └───┘ ░  ║
# «  w_1: ───────────░──╫─
# «                  ░  ║
# «  w_2: ───────────░──╫─
# «                  ░  ║
# «  c: 1/══════════════╩═
# «                     0
# Job id : f4811167471f4306b272465e35fb4294-1648619903262505
# Job Status: job has successfully run
# Raw counts: {'0': 101, '1': 8091}
# Measurement error mitigated counts {'1': 8192.0}
# Final counts after applying the threshold : {'1': 8192.0}
# Threshold : 40.96
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐┌───────┐          »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├┤1      ├──────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘│       │          »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             ├───┤     └───┘  │                       │         │                        │       │       │          »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#             └───┘            │                       │         │                        │       │       │          »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │       │          »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │                       │         │                        │       │  Rccx │          »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼───────┤       ├──────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │       │       │          »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼───────┤0      ├──────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │       │       │          »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  ┌───┐      │         │         │              │         │       │       │          »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼───────┤       ├──────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │       │       │          »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼───────┤       ├──────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     │       │          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤2      ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───────┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                          └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                               └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                    »
# «                          ┌───────┐┌───┐┌───────┐                             ┌───────┐┌───┐               ┌───┐     »
# « p0_0: ───────────────────┤1      ├┤ X ├┤1      ├─────────────────────────────┤1      ├┤ X ├──■─────────■──┤ X ├──■──»
# «                          │       │└───┘│       │                             │       │└───┘  │         │  └───┘  │  »
# « p0_1: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                             │       │       │         │         │  »
# « p0_2: ───────────────────┤       ├─────┤       ├─────────────────────────────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   ┌───┐     │       │       │         │         │  »
# « p1_0: ───────────────────┤       ├─────┤       ├───────────────────┤ X ├─────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                   └─┬─┘     │       │       │         │         │  »
# « p1_1: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «                          │       │     │       │                     │       │       │       │         │         │  »
# « p1_2: ───────────────────┤       ├─────┤       ├─────────────────────┼───────┤       ├───────┼─────────┼─────────┼──»
# «       ┌───────┐          │  Rccx │     │  Rccx │          ┌───────┐  │       │  Rccx │       │         │         │  »
# « h1_0: ┤ Ry(π) ├──────────┤       ├─────┤       ├──────────┤ Ry(π) ├──■───────┤       ├───────┼─────────┼─────────┼──»
# «       └───┬───┘          │       │     │       │          └───┬───┘          │       │       │         │         │  »
# «  e_0: ────┼──────────────┤0      ├─────┤0      ├──────────────┼──────────────┤0      ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │         │         │  »
# «phi_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼─────────┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  ┌───┐  │         │  »
# «  a_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼──┤ X ├──┼─────────┼──»
# «           │              │       │     │       │              │              │       │       │  └─┬─┘  │         │  »
# «  b_0: ────┼──────────────┤       ├─────┤       ├──────────────┼──────────────┤       ├───────┼────┼────┼─────────┼──»
# «           │              │       │     │       │              │              │       │     ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐»
# «  w_0: ────┼───────────■──┤2      ├─────┤2      ├──■───────────┼───────────■──┤2      ├─────┤ X ├──■──┤ X ├─────┤ X ├»
# «           │         ┌─┴─┐└───────┘     └───────┘┌─┴─┐         │         ┌─┴─┐└───────┘     └───┘     └───┘     └───┘»
# «  w_1: ────┼──────■──┤ X ├───────────────────────┤ X ├──■──────┼──────■──┤ X ├───────────────────────────────────────»
# «           │    ┌─┴─┐└───┘                       └───┘┌─┴─┐    │    ┌─┴─┐└───┘                                       »
# «  w_2: ────■────┤ X ├─────────────────────────────────┤ X ├────■────┤ X ├────────────────────────────────────────────»
# «                └───┘                                 └───┘         └───┘                                            »
# «  c: 1/══════════════════════════════════════════════════════════════════════════════════════════════════════════════»
# «                                                                                                                     »
# «                 ┌────────────┐ ░
# « p0_0: ───────■──┤ Ry(1.1071) ├─░────
# «              │  └────────────┘ ░
# « p0_1: ───────┼─────────────────░────
# «              │                 ░
# « p0_2: ───────┼─────────────────░────
# «              │                 ░
# « p1_0: ───────┼─────────────────░────
# «              │                 ░
# « p1_1: ───────┼─────────────────░────
# «              │                 ░ ┌─┐
# « p1_2: ───────┼─────────────────░─┤M├
# «              │                 ░ └╥┘
# « h1_0: ───────┼─────────────────░──╫─
# «              │                 ░  ║
# «  e_0: ───────┼─────────────────░──╫─
# «              │                 ░  ║
# «phi_0: ───────┼─────────────────░──╫─
# «              │                 ░  ║
# «  a_0: ───────┼─────────────────░──╫─
# «       ┌───┐  │                 ░  ║
# «  b_0: ┤ X ├──┼─────────────────░──╫─
# «       └─┬─┘┌─┴─┐               ░  ║
# «  w_0: ──■──┤ X ├───────────────░──╫─
# «            └───┘               ░  ║
# «  w_1: ─────────────────────────░──╫─
# «                                ░  ║
# «  w_2: ─────────────────────────░──╫─
# «                                ░  ║
# «  c: 1/════════════════════════════╩═
# «                                   0
# Job id : 2cc0dd00a82f46f89d2234c79353bba2-1648619991202231
# Job Status: job has successfully run
# Raw counts: {'0': 8095, '1': 97}
# Measurement error mitigated counts {'0': 8142.197518029547, '1': 49.80248197045345}
# Final counts after applying the threshold : {'0': 8142.197518029547, '1': 49.80248197045345}
# Threshold : 40.96

# %%
results_05[0].draw('mpl',fold=100)

# %%
run(step=1, backend=backend, threshold='0.005', qc_qcs=results_05, shots=10000)
# Out:
# Job id : 683bc66ef9504822878ce87f67284d7a-16486200747140028
# Job Status: job has successfully run

# %%
results_10 = icepp.pass_manager(qc=circuit_LBNL1, level=2, backend=backend, backend_tket=dev_b, shots=8192, measure_type='qc', threshold_type=['constant',0.1], zne='off').auto_manager()
# Out:
#              ░
#  p0_0: ──────░────
#        ┌───┐ ░
#  p0_1: ┤ X ├─░────
#        ├───┤ ░ ┌─┐
#  p0_2: ┤ X ├─░─┤M├
#        └───┘ ░ └╥┘
#  p1_0: ──────░──╫─
#              ░  ║
#  p1_1: ──────░──╫─
#              ░  ║
#  p1_2: ──────░──╫─
#              ░  ║
#  h1_0: ──────░──╫─
#              ░  ║
#   e_0: ──────░──╫─
#              ░  ║
# phi_0: ──────░──╫─
#              ░  ║
#   a_0: ──────░──╫─
#              ░  ║
#   b_0: ──────░──╫─
#              ░  ║
#   w_0: ──────░──╫─
#              ░  ║
#   w_1: ──────░──╫─
#              ░  ║
#   w_2: ──────░──╫─
#              ░  ║
#   c: 1/═════════╩═
#                 0
# Job id : 19d3173450724811b066faca34b6e921-1648620241871358
# Job Status: job has successfully run
# Raw counts: {'0': 43, '1': 8149}
# Measurement error mitigated counts {'0': 2.022466360541368, '1': 8189.977533639459}
# Final counts after applying the threshold : {'1': 8189.977533639459}
# Threshold : 819.2
#        ┌─────────────┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├───────────░──╫─┤M├
#             ├───┤           ░  ║ └╥┘
#  p0_2: ─────┤ X ├───────────░──╫──╫─
#             └───┘           ░  ║  ║
#  p1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  h1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   e_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
# phi_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   a_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   b_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   c: 2/════════════════════════╩══╩═
#                                0  1
# Job id : 01f5d373e1e143d3a944fc8ddd85c786-1648620390721714
# Job Status: job has successfully run
# Raw counts: {'00': 13, '01': 59, '10': 2298, '11': 5822}
# Measurement error mitigated counts {'00': 7.0790595607661536e-12, '01': 2.2195877732644904, '10': 2262.792469946486, '11': 5926.987942280242}
# Final counts after applying the threshold : {'10': 2262.792469946486, '11': 5926.987942280242}
# Threshold : 819.2
#        ┌─────────────┐┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───░───────
#             ├───┤            │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───░────┤M├
#             └───┘            │   ░    └╥┘
#  p1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_1: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_2: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  h1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   e_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
# phi_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   a_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   b_0: ──────────────────────┼───░─────╫─
#                            ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├─░─┤M├─╫─
#                            └───┘ ░ └╥┘ ║
#   w_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   w_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   c: 2/═════════════════════════════╩══╩═
#                                     0  1
# Job id : b17bc2bc48b043fbab50db9dd85a0cfb-1648620452885081
# Job Status: job has successfully run
# Raw counts: {'00': 39, '01': 75, '10': 2204, '11': 5874}
# Measurement error mitigated counts {'00': 15.23161564970804, '01': 3.1086244689504383e-15, '10': 2183.254752176534, '11': 5993.513632173758}
# Final counts after applying the threshold : {'10': 2183.254752176534, '11': 5993.513632173758}
# Threshold : 819.2
#        ┌─────────────┐┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼────────░────
#             ├───┤            │        ░
#  p0_2: ─────┤ X ├────────────┼────────░────
#             └───┘            │        ░
#  p1_0: ──────────────────────┼────────░────
#                              │        ░
#  p1_1: ──────────────────────┼────────░────
#                              │        ░
#  p1_2: ──────────────────────┼────────░────
#                              │        ░
#  h1_0: ──────────────────────┼────────░────
#                              │        ░
#   e_0: ──────────────────────┼────────░────
#                              │        ░
# phi_0: ──────────────────────┼────────░────
#                              │  ┌───┐ ░ ┌─┐
#   a_0: ──────────────────────┼──┤ X ├─░─┤M├
#                              │  └─┬─┘ ░ └╥┘
#   b_0: ──────────────────────┼────┼───░──╫─
#                            ┌─┴─┐  │   ░  ║
#   w_0: ────────────────────┤ X ├──■───░──╫─
#                            └───┘      ░  ║
#   w_1: ───────────────────────────────░──╫─
#                                       ░  ║
#   w_2: ───────────────────────────────░──╫─
#                                       ░  ║
#   c: 1/══════════════════════════════════╩═
#                                          0
# Job id : f9ce7fa588fc4a569b45ce5c3346eeac-16486205721188989
# Job Status: job has successfully run
# Raw counts: {'0': 2208, '1': 5984}
# Measurement error mitigated counts {'0': 2150.972067037799, '1': 6041.027932962202}
# Final counts after applying the threshold : {'0': 2150.972067037799, '1': 6041.027932962202}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘  │                       │  └───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼────────░──╫─┤M├
#             ├───┤            │                       │        ░  ║ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼────────░──╫──╫─
#             └───┘            │                       │        ░  ║  ║
#  p1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_1: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_2: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  h1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │       ┌────────────┐  │        ░  ║  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼────────░──╫──╫─
#                              │       └─────┬──────┘  │        ░  ║  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘      ░  ║  ║
#   w_1: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════╩══╩═
#                                                                  0  1
# Job id : 2fdd3905872c4078b65d4a4686707c07-164862071048705
# Job Status: job has successfully run
# Raw counts: {'00': 90, '01': 33, '10': 5876, '11': 2193}
# Measurement error mitigated counts {'00': 4.070493725069624e-12, '01': 8.244448491579403e-13, '10': 6045.292297465231, '11': 2146.707702534765}
# Final counts after applying the threshold : {'10': 6045.292297465231, '11': 2146.707702534765}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░───────
#             ├───┤            │                       │         │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░────┤M├
#             └───┘            │                       │         │   ░    └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │       ┌────────────┐  │         │   ░     ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───░─────╫─
#                              │       └─────┬──────┘  │         │   ░     ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼───░─────╫─
#                              │  ┌───┐      │         │         │   ░     ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼───░─────╫─
#                              │  └─┬─┘                │         │   ░     ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼───░─────╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├─░─┤M├─╫─
#                            └───┘                   └───┘     └───┘ ░ └╥┘ ║
#   w_1: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   w_2: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════╩══╩═
#                                                                       0  1
# Job id : 9389fddf93b248e1868206fb6340de71-16486208118615959
# Job Status: job has successfully run
# Raw counts: {'00': 143, '01': 50, '10': 5786, '11': 2213}
# Measurement error mitigated counts {'00': 8.265765896207915, '01': 1.2418147792589838, '10': 5942.538492785386, '11': 2239.9539265391472}
# Final counts after applying the threshold : {'10': 5942.538492785386, '11': 2239.9539265391472}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             ├───┤            │                       │         │        ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             └───┘            │                       │         │        ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │       ┌────────────┐  │         │        ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼────────░────
#                              │       └─────┬──────┘  │         │        ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼────────░────
#                              │  ┌───┐      │         │         │        ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼────────░────
#                              │  └─┬─┘                │         │  ┌───┐ ░ ┌─┐
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├─░─┤M├
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘ ░ └╥┘
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■───░──╫─
#                            └───┘                   └───┘     └───┘      ░  ║
#   w_1: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   w_2: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   c: 1/════════════════════════════════════════════════════════════════════╩═
#                                                                            0
# Job id : 2fd27b0e02d94dad8a2b0c1cd076d4b7-1648620940719033
# Job Status: job has successfully run
# Raw counts: {'0': 5814, '1': 2378}
# Measurement error mitigated counts {'0': 5835.003508781214, '1': 2356.9964912187866}
# Final counts after applying the threshold : {'0': 5835.003508781214, '1': 2356.9964912187866}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐ ░    ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├─░────┤M├
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘ ░    └╥┘
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             ├───┤            │                       │         │                        │        ░     ║
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             └───┘            │                       │         │                        │        ░     ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │        ░ ┌─┐ ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼────────░─┤M├─╫─
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │        ░ └╥┘ ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │         │              │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │         │  ┌───┐       │         │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘     └───┘                    └───┘      ░  ║  ║
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   w_2: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   c: 2/═════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                     0  1
# Job id : 3b98444c6e084584b2113760eb173505-1648621010753824
# Job Status: job has successfully run
# Raw counts: {'00': 2096, '01': 510, '10': 549, '11': 5037}
# Measurement error mitigated counts {'00': 2120.734972974714, '01': 442.09182207137127, '10': 496.5797476801355, '11': 5132.593457273779}
# Final counts after applying the threshold : {'00': 2120.734972974714, '11': 5132.593457273779}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │   ░ ┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░─┤M├───
#             ├───┤            │                       │         │                        │         │   ░ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#             └───┘            │                       │         │                        │         │   ░  ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │   ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼───░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │   ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼───░──╫────
#                              │  ┌───┐      │         │         │              │         │         │   ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼───░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │   ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼───░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐ ░  ║ ┌─┐
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├─░──╫─┤M├
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘ ░  ║ └╥┘
#   w_1: ───────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                       ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                       ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                          0  1
# Job id : e6b6658893994562b90773f32f0de78a-1648621101880209
# Job Status: job has successfully run
# Raw counts: {'00': 31, '01': 2846, '10': 61, '11': 5254}
# Measurement error mitigated counts {'00': 4.880508606089926, '01': 2819.4510302998356, '10': 14.696643453898215, '11': 5352.971817640176}
# Final counts after applying the threshold : {'01': 2819.4510302998356, '11': 5352.971817640176}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░───────
#             ├───┤            │                       │         │                        │         │        ░ ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░─┤M├───
#             └───┘            │                       │         │                        │         │        ░ └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │        ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │        ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────░──╫────
#                              │  ┌───┐      │         │         │              │         │         │        ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │        ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐      ░  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───░──╫────
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐ ░  ║ ┌─┐
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░──╫─┤M├
#                                                                                                      └───┘ ░  ║ └╥┘
#   w_2: ────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                            ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                               0  1
# Job id : 4acfc51cd7494ddfac7815e313dca99c-16486212415424662
# Job Status: job has successfully run
# Raw counts: {'00': 29, '01': 2601, '10': 103, '11': 5459}
# Measurement error mitigated counts {'00': 4.635473189415265, '01': 2635.023057383126, '10': 38.19285304901593, '11': 5514.148616378443}
# Final counts after applying the threshold : {'01': 2635.023057383126, '11': 5514.148616378443}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐                ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■─────────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │             ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#             ├───┤            │                       │         │                        │         │             ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#             └───┘            │                       │         │                        │         │             ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │             ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼─────────────░────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │             ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼─────────────░────
#                              │  ┌───┐      │         │         │              │         │         │             ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼─────────────░────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │             ░
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼─────────────░────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐           ░
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■────────░────
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐      ░
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■───░────
#                                                                                                      └───┘┌─┴─┐ ░ ┌─┐
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░─┤M├
#                                                                                                           └───┘ ░ └╥┘
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═
#                                                                                                                    0
# Job id : 10df201fb632463fad411762a1537e88-1648621363146376
# Job Status: job has successfully run
# Raw counts: {'0': 2961, '1': 5231}
# Measurement error mitigated counts {'0': 2575.6842057898557, '1': 5616.315794210143}
# Final counts after applying the threshold : {'0': 2575.6842057898557, '1': 5616.315794210143}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░    ┌─┐
# « p0_0: ─────────────────────■──┤ X ├─░────┤M├
# «                            │  └───┘ ░    └╥┘
# « p0_1: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p0_2: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_0: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_1: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_2: ─────────────────────┼────────░─────╫─
# «       ┌───────┐            │        ░     ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░─────╫─
# «       └───┬───┘            │        ░ ┌─┐ ║
# «  e_0: ────┼────────────────┼────────░─┤M├─╫─
# «           │                │        ░ └╥┘ ║
# «phi_0: ────┼────────────────┼────────░──╫──╫─
# «           │                │        ░  ║  ║
# «  a_0: ────┼────────────────┼────────░──╫──╫─
# «           │                │        ░  ║  ║
# «  b_0: ────┼────────────────┼────────░──╫──╫─
# «           │              ┌─┴─┐      ░  ║  ║
# «  w_0: ────┼───────────■──┤ X ├──────░──╫──╫─
# «           │         ┌─┴─┐└───┘      ░  ║  ║
# «  w_1: ────┼──────■──┤ X ├───────────░──╫──╫─
# «           │    ┌─┴─┐└───┘           ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : 3ae5d6cb60dd44879054eb6ce35d8df6-1648621442119824
# Job Status: job has successfully run
# Raw counts: {'00': 580, '01': 5196, '10': 2015, '11': 401}
# Measurement error mitigated counts {'00': 498.1594429808999, '01': 5308.096159710898, '10': 2041.7908078916166, '11': 343.95358941658543}
# Final counts after applying the threshold : {'01': 5308.096159710898, '10': 2041.7908078916166}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░
# « p0_0: ─────────────────────■──┤ X ├─░───────
# «                            │  └───┘ ░ ┌─┐
# « p0_1: ─────────────────────┼────────░─┤M├───
# «                            │        ░ └╥┘
# « p0_2: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_0: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_1: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_2: ─────────────────────┼────────░──╫────
# «       ┌───────┐            │        ░  ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░──╫────
# «       └───┬───┘            │        ░  ║
# «  e_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «phi_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  a_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  b_0: ────┼────────────────┼────────░──╫────
# «           │              ┌─┴─┐      ░  ║ ┌─┐
# «  w_0: ────┼───────────■──┤ X ├──────░──╫─┤M├
# «           │         ┌─┴─┐└───┘      ░  ║ └╥┘
# «  w_1: ────┼──────■──┤ X ├───────────░──╫──╫─
# «           │    ┌─┴─┐└───┘           ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : dc96c91566884737b29be5628d33e78f-164862150292315
# Job Status: job has successfully run
# Raw counts: {'00': 95, '01': 7748, '10': 6, '11': 343}
# Measurement error mitigated counts {'00': 11.572264824787874, '01': 7869.000547283284, '10': 1.9473072256317796, '11': 309.47988066629665}
# Final counts after applying the threshold : {'01': 7869.000547283284}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░
# « p0_0: ─────────────────────■──┤ X ├─░───────
# «                            │  └───┘ ░
# « p0_1: ─────────────────────┼────────░───────
# «                            │        ░ ┌─┐
# « p0_2: ─────────────────────┼────────░─┤M├───
# «                            │        ░ └╥┘
# « p1_0: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_1: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_2: ─────────────────────┼────────░──╫────
# «       ┌───────┐            │        ░  ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░──╫────
# «       └───┬───┘            │        ░  ║
# «  e_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «phi_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  a_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  b_0: ────┼────────────────┼────────░──╫────
# «           │              ┌─┴─┐      ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────░──╫────
# «           │         ┌─┴─┐└───┘      ░  ║ ┌─┐
# «  w_1: ────┼──────■──┤ X ├───────────░──╫─┤M├
# «           │    ┌─┴─┐└───┘           ░  ║ └╥┘
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : a596cbace5644859a6007286dd638ded-16486216245597508
# Job Status: job has successfully run
# Raw counts: {'00': 191, '01': 7625, '10': 11, '11': 365}
# Measurement error mitigated counts {'00': 1.014619499528635e-10, '01': 8057.000299177049, '11': 134.99970082286677}
# Final counts after applying the threshold : {'01': 8057.000299177049}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
# ...
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■───░───────
# «                            │  └───┘└───┘  │         │  └───┘  │   ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼───░───────
# «                            │              │         │         │   ░    ┌─┐
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼───░────┤M├
# «                ┌───┐       │              │         │         │   ░    └╥┘
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼───░─────╫─
# «                └─┬─┘       │              │         │         │   ░     ║
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «                  │         │              │         │         │   ░     ║
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «       ┌───────┐  │         │              │         │         │   ░     ║
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «       └───┬───┘            │              │         │         │   ░     ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «           │                │              │         │         │   ░     ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «           │                │              │  ┌───┐  │         │   ░     ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼───░─────╫─
# «           │                │              │  └─┬─┘  │         │   ░     ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼───░─────╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├─░─┤M├─╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘ ░ └╥┘ ║
# «  w_1: ────┼──────■──┤ X ├─────────────────────────────────────────░──╫──╫─
# «           │    ┌─┴─┐└───┘                                         ░  ║  ║
# «  w_2: ────■────┤ X ├──────────────────────────────────────────────░──╫──╫─
# «                └───┘                                              ░  ║  ║
# «  c: 2/═══════════════════════════════════════════════════════════════╩══╩═
# «                                                                      0  1
# Job id : 1b0c5e85198b4c0492f9ce6724283745-164862221171757
# Job Status: job has successfully run
# Raw counts: {'00': 70, '01': 24, '10': 5846, '11': 2252}
# Measurement error mitigated counts {'00': 2.2337070986129266, '10': 5930.490844766975, '11': 2259.275448134412}
# Final counts after applying the threshold : {'10': 5930.490844766975, '11': 2259.275448134412}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤     └───┘  │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐┌───┐               ┌───┐                ░
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■─────────■───░────
# «                            │  └───┘└───┘  │         │  └───┘  │         │   ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼───░────
# «                            │              │         │         │         │   ░ ┌─┐
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼───░─┤M├
# «                ┌───┐       │              │         │         │         │   ░ └╥┘
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «                └─┬─┘       │              │         │         │         │   ░  ║
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «                  │         │              │         │         │         │   ░  ║
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «       ┌───────┐  │         │              │         │         │         │   ░  ║
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «       └───┬───┘            │              │         │         │         │   ░  ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «           │                │              │         │         │         │   ░  ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «           │                │              │  ┌───┐  │         │         │   ░  ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼─────────┼───░──╫─
# «           │                │              │  └─┬─┘  │         │  ┌───┐  │   ░  ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼──┤ X ├──┼───░──╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐└─┬─┘┌─┴─┐ ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├──■──┤ X ├─░──╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘     └───┘ ░  ║
# «  w_1: ────┼──────■──┤ X ├───────────────────────────────────────────────────░──╫─
# «           │    ┌─┴─┐└───┘                                                   ░  ║
# «  w_2: ────■────┤ X ├────────────────────────────────────────────────────────░──╫─
# «                └───┘                                                        ░  ║
# «  c: 1/═════════════════════════════════════════════════════════════════════════╩═
# «                                                                                0
# Job id : 22edccb263f34abd908a780814898634-16486224907448761
# Job Status: job has successfully run
# Raw counts: {'0': 113, '1': 8079}
# Measurement error mitigated counts {'0': 31.55859317205847, '1': 8160.441406827941}
# Final counts after applying the threshold : {'1': 8160.441406827941}
# Threshold : 819.2
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤     └───┘  │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐┌───┐               ┌───┐               ┌────────────┐ ░
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■─────────■──┤ Ry(1.1071) ├─░────
# «                            │  └───┘└───┘  │         │  └───┘  │         │  └────────────┘ ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                            │              │         │         │         │                 ░
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                ┌───┐       │              │         │         │         │                 ░
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                └─┬─┘       │              │         │         │         │                 ░
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                  │         │              │         │         │         │                 ░ ┌─┐
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░─┤M├
# «       ┌───────┐  │         │              │         │         │         │                 ░ └╥┘
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «       └───┬───┘            │              │         │         │         │                 ░  ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │         │         │         │                 ░  ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │  ┌───┐  │         │         │                 ░  ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │  └─┬─┘  │         │  ┌───┐  │                 ░  ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼──┤ X ├──┼─────────────────░──╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐└─┬─┘┌─┴─┐               ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├──■──┤ X ├───────────────░──╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘     └───┘               ░  ║
# «  w_1: ────┼──────■──┤ X ├─────────────────────────────────────────────────────────────────░──╫─
# «           │    ┌─┴─┐└───┘                                                                 ░  ║
# «  w_2: ────■────┤ X ├──────────────────────────────────────────────────────────────────────░──╫─
# «                └───┘                                                                      ░  ║
# «  c: 1/═══════════════════════════════════════════════════════════════════════════════════════╩═
# «                                                                                              0
# Job id : 8509154a12ce44859ce5ca7533437d94-16486225333645399
# Job Status: job has successfully run
# Raw counts: {'0': 8097, '1': 95}
# Measurement error mitigated counts {'0': 8147.251645198954, '1': 44.748354801045636}
# Final counts after applying the threshold : {'0': 8147.251645198954}
# Threshold : 819.2

# %%
results_10[0].draw('mpl',fold=100)

# %%
run(step=1, backend=backend, threshold='0.1', qc_qcs=results_10, shots=10000)
# Out:
# Job id : 680e672840c8440e95d8f3a39a7f867a-1648622561888044
# Job Status: job has successfully run

# %%
results_25 = icepp.pass_manager(qc=circuit_LBNL1, level=2, backend=backend, backend_tket=dev_b, shots=8192, measure_type='qc', threshold_type=['constant',0.25], zne='off').auto_manager()
# Out:
#              ░
#  p0_0: ──────░────
#        ┌───┐ ░
#  p0_1: ┤ X ├─░────
#        ├───┤ ░ ┌─┐
#  p0_2: ┤ X ├─░─┤M├
#        └───┘ ░ └╥┘
#  p1_0: ──────░──╫─
#              ░  ║
#  p1_1: ──────░──╫─
#              ░  ║
#  p1_2: ──────░──╫─
#              ░  ║
#  h1_0: ──────░──╫─
#              ░  ║
#   e_0: ──────░──╫─
#              ░  ║
# phi_0: ──────░──╫─
#              ░  ║
#   a_0: ──────░──╫─
#              ░  ║
#   b_0: ──────░──╫─
#              ░  ║
#   w_0: ──────░──╫─
#              ░  ║
#   w_1: ──────░──╫─
#              ░  ║
#   w_2: ──────░──╫─
#              ░  ║
#   c: 1/═════════╩═
#                 0
# Job id : 82ef05d84b2b4d67b8d2948a7d4a3622-16486226822762308
# Job Status: job has successfully run
# Raw counts: {'0': 47, '1': 8145}
# Measurement error mitigated counts {'0': 21.204486799365657, '1': 8170.795513200635}
# Final counts after applying the threshold : {'1': 8170.795513200635}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├───────────░──╫─┤M├
#             ├───┤           ░  ║ └╥┘
#  p0_2: ─────┤ X ├───────────░──╫──╫─
#             └───┘           ░  ║  ║
#  p1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  p1_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#  h1_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   e_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
# phi_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   a_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   b_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_0: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_1: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   w_2: ─────────────────────░──╫──╫─
#                             ░  ║  ║
#   c: 2/════════════════════════╩══╩═
#                                0  1
# Job id : 2f5a682af35e4c17b4a7226ca2e24c73-164862279058934
# Job Status: job has successfully run
# Raw counts: {'00': 30, '01': 63, '10': 2289, '11': 5810}
# Measurement error mitigated counts {'00': 0.5541941002908447, '01': 2.5176851570348976e-14, '10': 2242.1894512426597, '11': 5949.25635465705}
# Final counts after applying the threshold : {'10': 2242.1894512426597, '11': 5949.25635465705}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───░───────
#             ├───┤            │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───░────┤M├
#             └───┘            │   ░    └╥┘
#  p1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_1: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  p1_2: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#  h1_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   e_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
# phi_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   a_0: ──────────────────────┼───░─────╫─
#                              │   ░     ║
#   b_0: ──────────────────────┼───░─────╫─
#                            ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├─░─┤M├─╫─
#                            └───┘ ░ └╥┘ ║
#   w_1: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   w_2: ──────────────────────────░──╫──╫─
#                                  ░  ║  ║
#   c: 2/═════════════════════════════╩══╩═
#                                     0  1
# Job id : 51b6a999c0ea440696ceae5e4edcec74-1648622831736651
# Job Status: job has successfully run
# Raw counts: {'00': 28, '01': 77, '10': 2227, '11': 5860}
# Measurement error mitigated counts {'00': 5.205298073403105, '01': 8.246756187314162, '10': 2197.074711894983, '11': 5981.4732338443}
# Final counts after applying the threshold : {'10': 2197.074711894983, '11': 5981.4732338443}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼────────░────
#             ├───┤            │        ░
#  p0_2: ─────┤ X ├────────────┼────────░────
#             └───┘            │        ░
#  p1_0: ──────────────────────┼────────░────
#                              │        ░
#  p1_1: ──────────────────────┼────────░────
#                              │        ░
#  p1_2: ──────────────────────┼────────░────
#                              │        ░
#  h1_0: ──────────────────────┼────────░────
#                              │        ░
#   e_0: ──────────────────────┼────────░────
#                              │        ░
# phi_0: ──────────────────────┼────────░────
#                              │  ┌───┐ ░ ┌─┐
#   a_0: ──────────────────────┼──┤ X ├─░─┤M├
#                              │  └─┬─┘ ░ └╥┘
#   b_0: ──────────────────────┼────┼───░──╫─
#                            ┌─┴─┐  │   ░  ║
#   w_0: ────────────────────┤ X ├──■───░──╫─
#                            └───┘      ░  ║
#   w_1: ───────────────────────────────░──╫─
#                                       ░  ║
#   w_2: ───────────────────────────────░──╫─
#                                       ░  ║
#   c: 1/══════════════════════════════════╩═
#                                          0
# Job id : ed653278e1a845028f288d110cfc2f45-1648622881566693
# Job Status: job has successfully run
# Raw counts: {'0': 2285, '1': 5907}
# Measurement error mitigated counts {'0': 2236.0323021364525, '1': 5955.967697863547}
# Final counts after applying the threshold : {'0': 2236.0323021364525, '1': 5955.967697863547}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐ ░ ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├─░─┤M├───
#        └────┬───┬────┘└───┘  │                       │  └───┘ ░ └╥┘┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼────────░──╫─┤M├
#             ├───┤            │                       │        ░  ║ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼────────░──╫──╫─
#             └───┘            │                       │        ░  ║  ║
#  p1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_1: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  p1_2: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │                       │        ░  ║  ║
#  h1_0: ──────────────────────┼───────────────────────┼────────░──╫──╫─
#                              │       ┌────────────┐  │        ░  ║  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼────────░──╫──╫─
#                              │       └─────┬──────┘  │        ░  ║  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘      ░  ║  ║
#   w_1: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────░──╫──╫─
#                                                               ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════╩══╩═
#                                                                  0  1
# Job id : 1ef9647ed58041a49aed0a91acb13d37-16486229214660249
# Job Status: job has successfully run
# Raw counts: {'00': 97, '01': 29, '10': 5789, '11': 2277}
# Measurement error mitigated counts {'10': 5940.56614069769, '11': 2251.4338593023244}
# Final counts after applying the threshold : {'10': 5940.56614069769, '11': 2251.4338593023244}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │   ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░───────
#             ├───┤            │                       │         │   ░    ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼───░────┤M├
#             └───┘            │                       │         │   ░    └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │                       │         │   ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼───░─────╫─
#                              │       ┌────────────┐  │         │   ░     ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───░─────╫─
#                              │       └─────┬──────┘  │         │   ░     ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼───░─────╫─
#                              │  ┌───┐      │         │         │   ░     ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼───░─────╫─
#                              │  └─┬─┘                │         │   ░     ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼───░─────╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├─░─┤M├─╫─
#                            └───┘                   └───┘     └───┘ ░ └╥┘ ║
#   w_1: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   w_2: ────────────────────────────────────────────────────────────░──╫──╫─
#                                                                    ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════╩══╩═
#                                                                       0  1
# Job id : 14b961824f894a70a9822bdfbeb7433a-1648622961207231
# Job Status: job has successfully run
# Raw counts: {'00': 135, '01': 55, '10': 5800, '11': 2202}
# Measurement error mitigated counts {'01': 7.456057160588333, '10': 5972.059733640336, '11': 2212.4842091990754}
# Final counts after applying the threshold : {'10': 5972.059733640336, '11': 2212.4842091990754}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             ├───┤            │                       │         │        ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────░────
#             └───┘            │                       │         │        ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │                       │         │        ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────░────
#                              │       ┌────────────┐  │         │        ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼────────░────
#                              │       └─────┬──────┘  │         │        ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼────────░────
#                              │  ┌───┐      │         │         │        ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼────────░────
#                              │  └─┬─┘                │         │  ┌───┐ ░ ┌─┐
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├─░─┤M├
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘ ░ └╥┘
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■───░──╫─
#                            └───┘                   └───┘     └───┘      ░  ║
#   w_1: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   w_2: ─────────────────────────────────────────────────────────────────░──╫─
#                                                                         ░  ║
#   c: 1/════════════════════════════════════════════════════════════════════╩═
#                                                                            0
# Job id : 8556968d34be4222a28006aea97c5c2d-1648623011211749
# Job Status: job has successfully run
# Raw counts: {'0': 5750, '1': 2442}
# Measurement error mitigated counts {'0': 5769.316051844426, '1': 2422.6839481555744}
# Final counts after applying the threshold : {'0': 5769.316051844426, '1': 2422.6839481555744}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐ ░    ┌─┐
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├─░────┤M├
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘ ░    └╥┘
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             ├───┤            │                       │         │                        │        ░     ║
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#             └───┘            │                       │         │                        │        ░     ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │                       │         │                        │        ░     ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼────────░─────╫─
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │        ░ ┌─┐ ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼────────░─┤M├─╫─
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │        ░ └╥┘ ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  ┌───┐      │         │         │              │         │        ░  ║  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼────────░──╫──╫─
#                              │  └─┬─┘                │         │  ┌───┐       │         │        ░  ║  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼────────░──╫──╫─
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐      ░  ║  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├──────░──╫──╫─
#                            └───┘                   └───┘     └───┘                    └───┘      ░  ║  ║
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   w_2: ──────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                  ░  ║  ║
#   c: 2/═════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                     0  1
# Job id : a1d180f3fc8a496097784c892be6f43c-16486230410379279
# Job Status: job has successfully run
# Raw counts: {'00': 2020, '01': 487, '10': 544, '11': 5141}
# Measurement error mitigated counts {'00': 2068.0611622794027, '01': 430.1619980424813, '10': 453.5244031804433, '11': 5240.252436497673}
# Final counts after applying the threshold : {'00': 2068.0611622794027, '11': 5240.252436497673}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐      ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■───░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │   ░ ┌─┐
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░─┤M├───
#             ├───┤            │                       │         │                        │         │   ░ └╥┘
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#             └───┘            │                       │         │                        │         │   ░  ║
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │                       │         │                        │         │   ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼───░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │   ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼───░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │   ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼───░──╫────
#                              │  ┌───┐      │         │         │              │         │         │   ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼───░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │   ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼───░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐ ░  ║ ┌─┐
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├─░──╫─┤M├
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘ ░  ║ └╥┘
#   w_1: ───────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                       ░  ║  ║
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                       ░  ║  ║
#   c: 2/══════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                          0  1
# Job id : d9c5e7052dcc44cf8d981066f2043d90-16486231042071419
# Job Status: job has successfully run
# Raw counts: {'00': 21, '01': 2747, '10': 49, '11': 5375}
# Measurement error mitigated counts {'00': 3.830269434956891e-15, '01': 2726.487581274847, '10': 4.297009572257849, '11': 5461.215409152895}
# Final counts after applying the threshold : {'01': 2726.487581274847, '11': 5461.215409152895}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐           ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────░───────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │        ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░───────
#             ├───┤            │                       │         │                        │         │        ░ ┌─┐
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░─┤M├───
#             └───┘            │                       │         │                        │         │        ░ └╥┘
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │                       │         │                        │         │        ░  ║
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────░──╫────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │        ░  ║
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────░──╫────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │        ░  ║
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────░──╫────
#                              │  ┌───┐      │         │         │              │         │         │        ░  ║
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────░──╫────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │        ░  ║
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────░──╫────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐      ░  ║
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───░──╫────
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐ ░  ║ ┌─┐
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░──╫─┤M├
#                                                                                                      └───┘ ░  ║ └╥┘
#   w_2: ────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─
#                                                                                                            ░  ║  ║
#   c: 2/═══════════════════════════════════════════════════════════════════════════════════════════════════════╩══╩═
#                                                                                                               0  1
# Job id : ac3e6d9ecd1544a094cf685fbe942315-1648623150610337
# Job Status: job has successfully run
# Raw counts: {'00': 46, '01': 2596, '10': 77, '11': 5473}
# Measurement error mitigated counts {'00': 20.206239482079233, '01': 2604.3257471061966, '10': 22.364813080459676, '11': 5545.103200331266}
# Final counts after applying the threshold : {'01': 2604.3257471061966, '11': 5545.103200331266}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐                ░
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■─────────────░────
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │             ░
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#             ├───┤            │                       │         │                        │         │             ░
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#             └───┘            │                       │         │                        │         │             ░
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │                       │         │                        │         │             ░
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼─────────────░────
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │             ░
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼─────────────░────
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │             ░
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼─────────────░────
#                              │  ┌───┐      │         │         │              │         │         │             ░
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼─────────────░────
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │             ░
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼─────────────░────
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐           ░
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■────────░────
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐      ░
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■───░────
#                                                                                                      └───┘┌─┴─┐ ░ ┌─┐
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├─░─┤M├
#                                                                                                           └───┘ ░ └╥┘
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═
#                                                                                                                    0
# Job id : 571222c771da4c67b2f42825ae15e0b9-16486232151231492
# Job Status: job has successfully run
# Raw counts: {'0': 3077, '1': 5115}
# Measurement error mitigated counts {'0': 2710.524762906169, '1': 5481.475237093831}
# Final counts after applying the threshold : {'0': 2710.524762906169, '1': 5481.475237093831}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░    ┌─┐
# « p0_0: ─────────────────────■──┤ X ├─░────┤M├
# «                            │  └───┘ ░    └╥┘
# « p0_1: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p0_2: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_0: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_1: ─────────────────────┼────────░─────╫─
# «                            │        ░     ║
# « p1_2: ─────────────────────┼────────░─────╫─
# «       ┌───────┐            │        ░     ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░─────╫─
# «       └───┬───┘            │        ░ ┌─┐ ║
# «  e_0: ────┼────────────────┼────────░─┤M├─╫─
# «           │                │        ░ └╥┘ ║
# «phi_0: ────┼────────────────┼────────░──╫──╫─
# «           │                │        ░  ║  ║
# «  a_0: ────┼────────────────┼────────░──╫──╫─
# «           │                │        ░  ║  ║
# «  b_0: ────┼────────────────┼────────░──╫──╫─
# «           │              ┌─┴─┐      ░  ║  ║
# «  w_0: ────┼───────────■──┤ X ├──────░──╫──╫─
# «           │         ┌─┴─┐└───┘      ░  ║  ║
# «  w_1: ────┼──────■──┤ X ├───────────░──╫──╫─
# «           │    ┌─┴─┐└───┘           ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : 4055ba609fd14783bdb5c871016f59d1-1648623251898289
# Job Status: job has successfully run
# Raw counts: {'00': 571, '01': 5209, '10': 2047, '11': 365}
# Measurement error mitigated counts {'00': 482.4597710866108, '01': 5311.387107606986, '10': 2079.683637294167, '11': 318.46948401223625}
# Final counts after applying the threshold : {'01': 5311.387107606986, '10': 2079.683637294167}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░
# « p0_0: ─────────────────────■──┤ X ├─░───────
# «                            │  └───┘ ░ ┌─┐
# « p0_1: ─────────────────────┼────────░─┤M├───
# «                            │        ░ └╥┘
# « p0_2: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_0: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_1: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_2: ─────────────────────┼────────░──╫────
# «       ┌───────┐            │        ░  ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░──╫────
# «       └───┬───┘            │        ░  ║
# «  e_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «phi_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  a_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  b_0: ────┼────────────────┼────────░──╫────
# «           │              ┌─┴─┐      ░  ║ ┌─┐
# «  w_0: ────┼───────────■──┤ X ├──────░──╫─┤M├
# «           │         ┌─┴─┐└───┘      ░  ║ └╥┘
# «  w_1: ────┼──────■──┤ X ├───────────░──╫──╫─
# «           │    ┌─┴─┐└───┘           ░  ║  ║
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : fa4266a0e3c04d4d964285360c610b09-1648623291106974
# Job Status: job has successfully run
# Raw counts: {'00': 79, '01': 7785, '10': 2, '11': 326}
# Measurement error mitigated counts {'00': 2.1316282072797836e-13, '01': 7908.803143485426, '10': 5.1947972555726565e-14, '11': 283.1968565145743}
# Final counts after applying the threshold : {'01': 7908.803143485426}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 2/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐ ░
# « p0_0: ─────────────────────■──┤ X ├─░───────
# «                            │  └───┘ ░
# « p0_1: ─────────────────────┼────────░───────
# «                            │        ░ ┌─┐
# « p0_2: ─────────────────────┼────────░─┤M├───
# «                            │        ░ └╥┘
# « p1_0: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_1: ─────────────────────┼────────░──╫────
# «                            │        ░  ║
# « p1_2: ─────────────────────┼────────░──╫────
# «       ┌───────┐            │        ░  ║
# « h1_0: ┤ Ry(π) ├────────────┼────────░──╫────
# «       └───┬───┘            │        ░  ║
# «  e_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «phi_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  a_0: ────┼────────────────┼────────░──╫────
# «           │                │        ░  ║
# «  b_0: ────┼────────────────┼────────░──╫────
# «           │              ┌─┴─┐      ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────░──╫────
# «           │         ┌─┴─┐└───┘      ░  ║ ┌─┐
# «  w_1: ────┼──────■──┤ X ├───────────░──╫─┤M├
# «           │    ┌─┴─┐└───┘           ░  ║ └╥┘
# «  w_2: ────■────┤ X ├────────────────░──╫──╫─
# «                └───┘                ░  ║  ║
# «  c: 2/═════════════════════════════════╩══╩═
# «                                        0  1
# Job id : e1aeb3b1edbd40fdb82d466bd4455064-1648623331661846
# Job Status: job has successfully run
# Raw counts: {'00': 181, '01': 7594, '10': 8, '11': 409}
# Measurement error mitigated counts {'01': 8049.983138868546, '11': 142.01686113148372}
# Final counts after applying the threshold : {'01': 8049.983138868546}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘└───┘  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤            │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
# ...
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■───░───────
# «                            │  └───┘└───┘  │         │  └───┘  │   ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼───░───────
# «                            │              │         │         │   ░    ┌─┐
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼───░────┤M├
# «                ┌───┐       │              │         │         │   ░    └╥┘
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼───░─────╫─
# «                └─┬─┘       │              │         │         │   ░     ║
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «                  │         │              │         │         │   ░     ║
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «       ┌───────┐  │         │              │         │         │   ░     ║
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «       └───┬───┘            │              │         │         │   ░     ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «           │                │              │         │         │   ░     ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼───░─────╫─
# «           │                │              │  ┌───┐  │         │   ░     ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼───░─────╫─
# «           │                │              │  └─┬─┘  │         │   ░     ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼───░─────╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐ ░ ┌─┐ ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├─░─┤M├─╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘ ░ └╥┘ ║
# «  w_1: ────┼──────■──┤ X ├─────────────────────────────────────────░──╫──╫─
# «           │    ┌─┴─┐└───┘                                         ░  ║  ║
# «  w_2: ────■────┤ X ├──────────────────────────────────────────────░──╫──╫─
# «                └───┘                                              ░  ║  ║
# «  c: 2/═══════════════════════════════════════════════════════════════╩══╩═
# «                                                                      0  1
# Job id : 4327b3c2a2ba4d2291f6b269a8462c85-16486235708384461
# Job Status: job has successfully run
# Raw counts: {'00': 72, '01': 36, '10': 5796, '11': 2288}
# Measurement error mitigated counts {'00': 16.062199467168846, '01': 12.380881732389355, '10': 5866.3596351445685, '11': 2297.197283655874}
# Final counts after applying the threshold : {'10': 5866.3596351445685, '11': 2297.197283655874}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤     └───┘  │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐┌───┐               ┌───┐                ░
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■─────────■───░────
# «                            │  └───┘└───┘  │         │  └───┘  │         │   ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼───░────
# «                            │              │         │         │         │   ░ ┌─┐
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼───░─┤M├
# «                ┌───┐       │              │         │         │         │   ░ └╥┘
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «                └─┬─┘       │              │         │         │         │   ░  ║
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «                  │         │              │         │         │         │   ░  ║
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «       ┌───────┐  │         │              │         │         │         │   ░  ║
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «       └───┬───┘            │              │         │         │         │   ░  ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «           │                │              │         │         │         │   ░  ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼───░──╫─
# «           │                │              │  ┌───┐  │         │         │   ░  ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼─────────┼───░──╫─
# «           │                │              │  └─┬─┘  │         │  ┌───┐  │   ░  ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼──┤ X ├──┼───░──╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐└─┬─┘┌─┴─┐ ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├──■──┤ X ├─░──╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘     └───┘ ░  ║
# «  w_1: ────┼──────■──┤ X ├───────────────────────────────────────────────────░──╫─
# «           │    ┌─┴─┐└───┘                                                   ░  ║
# «  w_2: ────■────┤ X ├────────────────────────────────────────────────────────░──╫─
# «                └───┘                                                        ░  ║
# «  c: 1/═════════════════════════════════════════════════════════════════════════╩═
# «                                                                                0
# Job id : 6aa3711f7e3549cda22bf5f8d43e1622-1648623614048621
# Job Status: job has successfully run
# Raw counts: {'0': 108, '1': 8084}
# Measurement error mitigated counts {'0': 7.180565953325413, '1': 8184.819434046675}
# Final counts after applying the threshold : {'1': 8184.819434046675}
# Threshold : 2048.0
#        ┌─────────────┐┌───┐                             ┌───┐                              ┌───┐               »
#  p0_0: ┤ Ry(-1.1071) ├┤ X ├──■───────────────────────■──┤ X ├──■────────────────────────■──┤ X ├──■────────────»
#        └────┬───┬────┘├───┤  │                       │  └───┘  │                        │  └───┘  │            »
#  p0_1: ─────┤ X ├─────┤ X ├──┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             ├───┤     └───┘  │                       │         │                        │         │            »
#  p0_2: ─────┤ X ├────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#             └───┘            │                       │         │                        │         │            »
#  p1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_1: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  p1_2: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │                       │         │                        │         │            »
#  h1_0: ──────────────────────┼───────────────────────┼─────────┼────────────────────────┼─────────┼────────────»
#                              │       ┌────────────┐  │         │       ┌─────────────┐  │         │            »
#   e_0: ──────────────────────┼───────┤ Ry(2.8364) ├──┼─────────┼───────┤ Ry(0.56262) ├──┼─────────┼────────────»
#                              │       └─────┬──────┘  │         │       └──────┬──────┘  │         │            »
# phi_0: ──────────────────────┼─────────────┼─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  ┌───┐      │         │         │              │         │         │            »
#   a_0: ──────────────────────┼──┤ X ├──────■─────────┼─────────┼──────────────┼─────────┼─────────┼────────────»
#                              │  └─┬─┘                │         │  ┌───┐       │         │         │            »
#   b_0: ──────────────────────┼────┼──────────────────┼─────────┼──┤ X ├───────■─────────┼─────────┼────────────»
#                            ┌─┴─┐  │                ┌─┴─┐     ┌─┴─┐└─┬─┘               ┌─┴─┐     ┌─┴─┐          »
#   w_0: ────────────────────┤ X ├──■────────────────┤ X ├─────┤ X ├──■─────────────────┤ X ├─────┤ X ├──■───────»
#                            └───┘                   └───┘     └───┘                    └───┘     └───┘┌─┴─┐     »
#   w_1: ──────────────────────────────────────────────────────────────────────────────────────────────┤ X ├──■──»
#                                                                                                      └───┘┌─┴─┐»
#   w_2: ───────────────────────────────────────────────────────────────────────────────────────────────────┤ X ├»
#                                                                                                           └───┘»
#   c: 1/════════════════════════════════════════════════════════════════════════════════════════════════════════»
#                                                                                                                »
# «                               ┌───┐┌───┐               ┌───┐               ┌────────────┐ ░
# « p0_0: ─────────────────────■──┤ X ├┤ X ├──■─────────■──┤ X ├──■─────────■──┤ Ry(1.1071) ├─░────
# «                            │  └───┘└───┘  │         │  └───┘  │         │  └────────────┘ ░
# « p0_1: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                            │              │         │         │         │                 ░
# « p0_2: ─────────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                ┌───┐       │              │         │         │         │                 ░
# « p1_0: ─────────┤ X ├───────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                └─┬─┘       │              │         │         │         │                 ░
# « p1_1: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░────
# «                  │         │              │         │         │         │                 ░ ┌─┐
# « p1_2: ───────────┼─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░─┤M├
# «       ┌───────┐  │         │              │         │         │         │                 ░ └╥┘
# « h1_0: ┤ Ry(π) ├──■─────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «       └───┬───┘            │              │         │         │         │                 ░  ║
# «  e_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │         │         │         │                 ░  ║
# «phi_0: ────┼────────────────┼──────────────┼─────────┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │  ┌───┐  │         │         │                 ░  ║
# «  a_0: ────┼────────────────┼──────────────┼──┤ X ├──┼─────────┼─────────┼─────────────────░──╫─
# «           │                │              │  └─┬─┘  │         │  ┌───┐  │                 ░  ║
# «  b_0: ────┼────────────────┼──────────────┼────┼────┼─────────┼──┤ X ├──┼─────────────────░──╫─
# «           │              ┌─┴─┐          ┌─┴─┐  │  ┌─┴─┐     ┌─┴─┐└─┬─┘┌─┴─┐               ░  ║
# «  w_0: ────┼───────────■──┤ X ├──────────┤ X ├──■──┤ X ├─────┤ X ├──■──┤ X ├───────────────░──╫─
# «           │         ┌─┴─┐└───┘          └───┘     └───┘     └───┘     └───┘               ░  ║
# «  w_1: ────┼──────■──┤ X ├─────────────────────────────────────────────────────────────────░──╫─
# «           │    ┌─┴─┐└───┘                                                                 ░  ║
# «  w_2: ────■────┤ X ├──────────────────────────────────────────────────────────────────────░──╫─
# «                └───┘                                                                      ░  ║
# «  c: 1/═══════════════════════════════════════════════════════════════════════════════════════╩═
# «                                                                                              0
# Job id : 34baed7e2f464efc88d05236770eb08d-16486236522160692
# Job Status: job has successfully run
# Raw counts: {'0': 8112, '1': 80}
# Measurement error mitigated counts {'0': 8183.848756226783, '1': 8.151243773216471}
# Final counts after applying the threshold : {'0': 8183.848756226783}
# Threshold : 2048.0

# %%
results_25[0].draw('mpl',fold=100)

# %%
run(step=1, backend=backend, threshold='0.25', qc_qcs=results_25, shots=10000)
# Out:
# Job id : 1b0cd8b741d6472c92af0917610ae439-1648623733398651
# Job Status: job has successfully run
