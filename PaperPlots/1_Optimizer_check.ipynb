# %% [markdown]
# # Full test of new optimizer
# ・Pattern recognition algorithm
# <br>
# ・Slimming algorithm (slimming level =1, 2)
# <br>
# Sample algorithm is "Parton shower quantum algorithm fullmodel of 2steps by LBNL".
# <br>
# ## Slimming level1

# %%
from transpiler.optimization import slim

# %%
from sample_algorithm.twostepSim_LBNL import runQuantum
circuit_LBNL1 = runQuantum(gLR=1,dophisplit=1)

# %%
example1 = slim.circuit_optimization( circuit=circuit_LBNL1, slim_level=1)
circuit_LBNL1_op = example1.slim()

# %%
circuit_LBNL1_op.draw(output='mpl')

# %% [markdown]
# ## Pattern recognition

# %%
from transpiler.optimization import pattern

# %%
from sample_algorithm.twostepSim_LBNL import runQuantum
circuit_LBNL1 = runQuantum(gLR=1,dophisplit=1)

# %%
example2 = pattern.recognition( circuit=circuit_LBNL1, level=3, n_patterns=5, min_num_nodes=5, max_num_nodes=7, min_n_repetition=4)

# %%
circ_max, designated_gates2 = example2.quantum_pattern()

# %%
circ_max.draw(output='mpl')

# %% [markdown]
#  ## Slimming level 2

# %%
from transpiler.optimization import optimization

# %%
from sample_algorithm.twostepSim_LBNL import runQuantum
circuit_LBNL1 = runQuantum(gLR=1,dophisplit=1)

# %%
example3 = optimization.optimizer( circuit=circuit_LBNL1, slim_level=2, pattern_level =3, n_patterns=5, min_num_nodes=5, max_num_nodes=7, min_n_repetition=4)

# %%
circuit_LBNL1_op2 = example3.slimer()

# %%
circuit_LBNL1_op2.draw(output='mpl')

# %%
from qiskit import(
  QuantumCircuit,
  execute,
  Aer)
from qiskit.visualization import plot_histogram

# %%
from sample_algorithm.twostepSim_LBNL import runQuantum
circuit_LBNL1 = runQuantum(gLR=1,dophisplit=1)

# %%
circuit=circuit_LBNL1
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots=2000)
result = job.result()
counts = result.get_counts(circuit)

plot_histogram(counts,number_to_keep=None)

# %%
circuit=circuit_LBNL1_op
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots=2000)
result = job.result()
counts = result.get_counts(circuit)

plot_histogram(counts,number_to_keep=None)

# %%
circuit=circuit_LBNL1_op2
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots=2000)
result = job.result()
counts = result.get_counts(circuit)

plot_histogram(counts,number_to_keep=None)
