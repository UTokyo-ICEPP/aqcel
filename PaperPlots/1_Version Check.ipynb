# %%
conda info
# Out:
#      active environment : base
#     active env location : /opt/anaconda3
#             shell level : 1
#        user config file : /Users/bigbangfourth/.condarc
#  populated config files : /Users/bigbangfourth/.condarc
#           conda version : 4.9.2
#     conda-build version : 3.20.5
#          python version : 3.8.1.final.0
#        virtual packages : __osx=10.15.7=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /opt/anaconda3  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /opt/anaconda3/pkgs
#                           /Users/bigbangfourth/.conda/pkgs
#        envs directories : /opt/anaconda3/envs
#                           /Users/bigbangfourth/.conda/envs
#                platform : osx-64
#              user-agent : conda/4.9.2 requests/2.22.0 CPython/3.8.1 Darwin/19.6.0 OSX/10.15.7
#                 UID:GID : 501:20
#              netrc file : None
#            offline mode : False
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
 conda install python=3.8
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _ipyw_jlab_nb_ext_conf-0.1.0|           py38_0         192 KB
#     alabaster-0.7.12           |             py_0          16 KB
#     anaconda-2020.02           |           py38_0          16 KB
#     anaconda-client-1.7.2      |           py38_0         154 KB
#     anaconda-navigator-1.10.0  |           py38_0         6.2 MB
#     appnope-0.1.0              |           py38_0           8 KB
#     appscript-1.1.0            |   py38h1de35cc_0         134 KB
#     argh-0.26.2                |           py38_0          36 KB
#     asn1crypto-1.3.0           |           py38_0         168 KB
#     astroid-2.3.3              |           py38_0         274 KB
#     astropy-4.0                |   py38h1de35cc_0         6.0 MB
#     atomicwrites-1.3.0         |             py_0          10 KB
#     backcall-0.1.0             |           py38_0          21 KB
#     backports.shutil_get_terminal_size-1.0.0|           py38_2           9 KB
#     beautifulsoup4-4.8.2       |           py38_0         163 KB
#     bitarray-1.2.1             |   py38h1de35cc_0          80 KB
#     bkcharts-0.2               |           py38_0         132 KB
#     bleach-3.1.0               |             py_0         111 KB
#     bokeh-1.4.0                |           py38_0         8.2 MB
#     boto-2.49.0                |           py38_0         1.2 MB
#     bottleneck-1.3.2           |   py38h776bbcc_0         106 KB
#     certifi-2019.11.28         |           py38_0         153 KB
#     cffi-1.14.0                |   py38hb5b8e2f_0         216 KB
#     chardet-3.0.4              |        py38_1003         174 KB
#     click-7.0                  |             py_0          68 KB
#     clyent-1.2.2               |           py38_1          20 KB
#     conda-4.9.2                |   py38hecd8cb5_0         2.9 MB
#     conda-build-3.20.5         |           py38_1         543 KB
#     conda-package-handling-1.7.2|   py38h22f3db7_0         1.5 MB
#     cryptography-2.8           |   py38ha12b0ac_0         523 KB
#     cycler-0.10.0              |           py38_0          14 KB
#     cython-0.29.15             |   py38h0a44026_0         1.9 MB
#     cytoolz-0.10.1             |   py38h1de35cc_0         316 KB
#     distributed-2.11.0         |           py38_0         950 KB
#     docutils-0.16              |           py38_0         672 KB
#     entrypoints-0.3            |           py38_0          10 KB
#     et_xmlfile-1.0.1           |           py38_0          22 KB
#     fastcache-1.1.0            |   py38h1de35cc_0          35 KB
#     flake8-3.7.9               |           py38_0         168 KB
#     future-0.18.2              |           py38_0         642 KB
#     gevent-1.3.7               |   py38h1de35cc_1         1.3 MB
#     gmpy2-2.0.8                |   py38h6ef4df4_3         159 KB
#     greenlet-0.4.15            |   py38h1de35cc_0          27 KB
#     h5py-2.10.0                |   py38h3134771_0         833 KB
#     html5lib-1.0.1             |             py_0          91 KB
#     idna-2.8                   |        py38_1000          88 KB
#     imageio-2.6.1              |           py38_0         3.2 MB
#     importlib_metadata-1.5.0   |           py38_0          48 KB
#     ipykernel-5.1.4            |   py38h39e3cac_0         171 KB
#     ipython-7.12.0             |   py38h5ca1d4c_0         977 KB
#     ipython_genutils-0.2.0     |           py38_0          39 KB
#     isort-4.3.21               |           py38_0          65 KB
#     itsdangerous-1.1.0         |             py_0          17 KB
#     jedi-0.14.1                |           py38_0         692 KB
#     jsonschema-3.2.0           |           py38_0          96 KB
#     jupyter-1.0.0              |           py38_7           7 KB
#     jupyter_client-5.3.4       |           py38_0         140 KB
#     jupyter_core-4.6.1         |           py38_0          67 KB
#     keyring-21.1.0             |           py38_0          55 KB
#     kiwisolver-1.0.1           |   py38h0a44026_0          58 KB
#     lazy-object-proxy-1.4.3    |   py38h1de35cc_0          35 KB
#     liblief-0.10.1             |       h0a44026_0         1.5 MB
#     llvmlite-0.31.0            |   py38h1341992_0        11.2 MB
#     locket-0.2.0               |           py38_1           9 KB
#     lxml-4.5.0                 |   py38hef8c89e_0         1.2 MB
#     markupsafe-1.1.1           |   py38h1de35cc_0          31 KB
#     matplotlib-3.1.3           |           py38_0          21 KB
#     matplotlib-base-3.1.3      |   py38h9aa3819_0         4.9 MB
#     mccabe-0.6.1               |           py38_1          15 KB
#     mistune-0.8.4              |py38h1de35cc_1000          54 KB
#     mkl-service-2.3.0          |   py38hfbe908c_0          42 KB
#     mkl_fft-1.0.15             |   py38h5e564d8_0         138 KB
#     mkl_random-1.1.0           |   py38h6440ff4_0           5 KB
#     mpmath-1.1.0               |           py38_0         776 KB
#     msgpack-python-0.6.1       |   py38h04f5b5a_1          77 KB
#     multipledispatch-0.6.0     |           py38_0          23 KB
#     navigator-updater-0.2.1    |           py38_0         723 KB
#     nbconvert-5.6.1            |           py38_0         453 KB
#     nltk-3.4.5                 |           py38_0         1.7 MB
#     nose-1.3.7                 |           py38_2         217 KB
#     notebook-6.0.3             |           py38_0         4.0 MB
#     numba-0.48.0               |   py38h6c726b0_0         2.9 MB
#     numexpr-2.7.1              |   py38hce01a72_0         122 KB
#     numpy-1.18.1               |   py38h7241aed_0           5 KB
#     numpy-base-1.18.1          |   py38h6575580_1         3.9 MB
#     olefile-0.46               |             py_0          33 KB
#     pandas-1.0.1               |   py38h6c726b0_0         7.9 MB
#     pandocfilters-1.4.2        |           py38_1          13 KB
#     path-13.1.0                |           py38_0          35 KB
#     pathlib2-2.3.5             |           py38_0          36 KB
#     patsy-0.5.1                |           py38_0         275 KB
#     pep8-1.7.1                 |           py38_0          53 KB
#     pexpect-4.8.0              |           py38_0          82 KB
#     pickleshare-0.7.5          |        py38_1000          13 KB
#     pillow-7.0.0               |   py38h4655f20_0         568 KB
#     pip-20.0.2                 |           py38_1         1.7 MB
#     pkginfo-1.5.0.1            |           py38_0          43 KB
#     pluggy-0.13.1              |           py38_0          33 KB
#     ply-3.11                   |           py38_0          80 KB
#     psutil-5.6.7               |   py38h1de35cc_0         334 KB
#     ptyprocess-0.6.0           |           py38_0          23 KB
#     py-lief-0.10.1             |   py38haf313ee_0         1.1 MB
#     pycodestyle-2.5.0          |           py38_0          62 KB
#     pycosat-0.6.3              |   py38h1de35cc_0          88 KB
#     pycparser-2.19             |             py_0          89 KB
#     pycrypto-2.6.1             |  py38haf1e3a3_10         371 KB
#     pycurl-7.43.0.5            |   py38ha12b0ac_0          68 KB
#     pyflakes-2.1.1             |           py38_0         105 KB
#     pylint-2.4.4               |           py38_0         417 KB
#     pyodbc-4.0.30              |   py38h0a44026_0          64 KB
#     pyopenssl-19.1.0           |           py38_0          87 KB
#     pyqt-5.9.2                 |   py38h655552a_2         3.6 MB
#     pyrsistent-0.15.7          |   py38h1de35cc_0          91 KB
#     pysocks-1.7.1              |           py38_0          28 KB
#     pytables-3.6.1             |   py38h4727e94_0         1.2 MB
#     pytest-5.3.5               |           py38_0         369 KB
#     pytest-arraydiff-0.2       |   py38h39e3cac_0          15 KB
#     pytest-remotedata-0.3.2    |           py38_0          14 KB
#     python-3.8.1               |       h359304d_1        20.7 MB
#     python-language-server-0.31.7|           py38_0          75 KB
#     python-libarchive-c-2.8    |           py38_7          21 KB
#     python.app-2               |          py38_10         1.5 MB
#     pywavelets-1.1.1           |   py38h1de35cc_0         3.4 MB
#     pyyaml-5.3                 |   py38h1de35cc_0         164 KB
#     pyzmq-18.1.1               |   py38h0a44026_0         405 KB
#     requests-2.22.0            |           py38_1          92 KB
#     rtree-0.9.3                |           py38_0          45 KB
#     ruamel_yaml-0.15.87        |   py38h1de35cc_0         238 KB
#     scikit-image-0.16.2        |   py38h6c726b0_0        22.6 MB
#     scikit-learn-0.22.1        |   py38h27c97d8_0         4.7 MB
#     scipy-1.4.1                |   py38h44e99c9_0        13.0 MB
#     send2trash-1.5.0           |           py38_0          17 KB
#     setuptools-46.0.0          |           py38_0         522 KB
#     simplegeneric-0.8.1        |           py38_2          10 KB
#     singledispatch-3.4.0.3     |           py38_0          16 KB
#     sip-4.19.8                 |   py38h0a44026_0         239 KB
#     six-1.14.0                 |           py38_0          26 KB
#     sortedcollections-1.1.1    |             py_0          11 KB
#     sortedcontainers-2.1.0     |           py38_0          42 KB
#     soupsieve-1.9.5            |           py38_0          61 KB
#     sphinxcontrib-1.0          |           py38_1           4 KB
#     spyder-4.0.1               |           py38_0         5.2 MB
#     spyder-kernels-1.8.1       |           py38_0          93 KB
#     sqlalchemy-1.3.13          |   py38h1de35cc_0         1.4 MB
#     statsmodels-0.11.0         |   py38h1de35cc_0         7.4 MB
#     sympy-1.5.1                |           py38_0         8.4 MB
#     terminado-0.8.3            |           py38_0          25 KB
#     tornado-6.0.3              |   py38h1de35cc_3         592 KB
#     traitlets-4.3.3            |           py38_0         138 KB
#     ujson-1.35                 |   py38h1de35cc_0          32 KB
#     unicodecsv-0.14.1          |           py38_0          27 KB
#     urllib3-1.25.8             |           py38_0         167 KB
#     watchdog-0.10.2            |   py38h1de35cc_0          98 KB
#     webencodings-0.5.1         |           py38_1          20 KB
#     wheel-0.34.2               |           py38_0          51 KB
#     widgetsnbextension-3.5.1   |           py38_0         867 KB
#     wrapt-1.11.2               |   py38h1de35cc_0          50 KB
#     wurlitzer-2.0.0            |           py38_0          14 KB
#     xlrd-1.2.0                 |             py_0         103 KB
#     xlwings-0.17.1             |           py38_0         433 KB
#     xlwt-1.3.0                 |           py38_0         159 KB
#     ------------------------------------------------------------
#                                            Total:       188.1 MB
#
# The following packages will be UPDATED:
#
#   anaconda-navigator                          1.9.12-py37_0 --> 1.10.0-py38_0
#   conda                                        4.8.2-py37_0 --> 4.9.2-py38hecd8cb5_0
#   conda-build                                3.18.11-py37_0 --> 3.20.5-py38_1
#   conda-package-han~                   1.6.0-py37h1de35cc_0 --> 1.7.2-py38h22f3db7_0
#   gmpy2                                2.0.8-py37h6ef4df4_2 --> 2.0.8-py38h6ef4df4_3
#   idna                                           2.8-py37_0 --> 2.8-py38_1000
#   liblief                                  0.9.0-h2a1bed3_2 --> 0.10.1-h0a44026_0
#   mistune                              0.8.4-py37h1de35cc_0 --> 0.8.4-py38h1de35cc_1000
#   pickleshare                                  0.7.5-py37_0 --> 0.7.5-py38_1000
#   py-lief                              0.9.0-py37h1413db1_2 --> 0.10.1-py38haf313ee_0
#   pycrypto                             2.6.1-py37h1de35cc_9 --> 2.6.1-py38haf1e3a3_10
#   python                                   3.7.6-h359304d_2 --> 3.8.1-h359304d_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   alabaster          pkgs/main/osx-64::alabaster-0.7.12-py~ --> pkgs/main/noarch::alabaster-0.7.12-py_0
#   atomicwrites       pkgs/main/osx-64::atomicwrites-1.3.0-~ --> pkgs/main/noarch::atomicwrites-1.3.0-py_0
#   bleach              pkgs/main/osx-64::bleach-3.1.0-py37_0 --> pkgs/main/noarch::bleach-3.1.0-py_0
#   click                  pkgs/main/osx-64::click-7.0-py37_0 --> pkgs/main/noarch::click-7.0-py_0
#   html5lib           pkgs/main/osx-64::html5lib-1.0.1-py37~ --> pkgs/main/noarch::html5lib-1.0.1-py_0
#   itsdangerous       pkgs/main/osx-64::itsdangerous-1.1.0-~ --> pkgs/main/noarch::itsdangerous-1.1.0-py_0
#   olefile             pkgs/main/osx-64::olefile-0.46-py37_0 --> pkgs/main/noarch::olefile-0.46-py_0
#   pycparser          pkgs/main/osx-64::pycparser-2.19-py37~ --> pkgs/main/noarch::pycparser-2.19-py_0
#   sortedcollections  pkgs/main/osx-64::sortedcollections-1~ --> pkgs/main/noarch::sortedcollections-1.1.1-py_0
#   xlrd                  pkgs/main/osx-64::xlrd-1.2.0-py37_0 --> pkgs/main/noarch::xlrd-1.2.0-py_0
#
# The following packages will be DOWNGRADED:
#
#   _ipyw_jlab_nb_ext~                           0.1.0-py37_0 --> 0.1.0-py38_0
#   anaconda                                   2020.02-py37_0 --> 2020.02-py38_0
#   anaconda-client                              1.7.2-py37_0 --> 1.7.2-py38_0
#   appnope                                      0.1.0-py37_0 --> 0.1.0-py38_0
#   appscript                            1.1.0-py37h1de35cc_0 --> 1.1.0-py38h1de35cc_0
#   argh                                        0.26.2-py37_0 --> 0.26.2-py38_0
#   asn1crypto                                   1.3.0-py37_0 --> 1.3.0-py38_0
#   astroid                                      2.3.3-py37_0 --> 2.3.3-py38_0
#   astropy                                4.0-py37h1de35cc_0 --> 4.0-py38h1de35cc_0
#   backcall                                     0.1.0-py37_0 --> 0.1.0-py38_0
#   backports.shutil_~                           1.0.0-py37_2 --> 1.0.0-py38_2
#   beautifulsoup4                               4.8.2-py37_0 --> 4.8.2-py38_0
#   bitarray                             1.2.1-py37h1de35cc_0 --> 1.2.1-py38h1de35cc_0
#   bkcharts                                       0.2-py37_0 --> 0.2-py38_0
#   bokeh                                        1.4.0-py37_0 --> 1.4.0-py38_0
#   boto                                        2.49.0-py37_0 --> 2.49.0-py38_0
#   bottleneck                           1.3.2-py37h776bbcc_0 --> 1.3.2-py38h776bbcc_0
#   certifi                                 2019.11.28-py37_0 --> 2019.11.28-py38_0
#   cffi                                1.14.0-py37hb5b8e2f_0 --> 1.14.0-py38hb5b8e2f_0
#   chardet                                   3.0.4-py37_1003 --> 3.0.4-py38_1003
#   clyent                                       1.2.2-py37_1 --> 1.2.2-py38_1
#   cryptography                           2.8-py37ha12b0ac_0 --> 2.8-py38ha12b0ac_0
#   cycler                                      0.10.0-py37_0 --> 0.10.0-py38_0
#   cython                             0.29.15-py37h0a44026_0 --> 0.29.15-py38h0a44026_0
#   cytoolz                             0.10.1-py37h1de35cc_0 --> 0.10.1-py38h1de35cc_0
#   distributed                                 2.11.0-py37_0 --> 2.11.0-py38_0
#   docutils                                      0.16-py37_0 --> 0.16-py38_0
#   entrypoints                                    0.3-py37_0 --> 0.3-py38_0
#   et_xmlfile                                   1.0.1-py37_0 --> 1.0.1-py38_0
#   fastcache                            1.1.0-py37h1de35cc_0 --> 1.1.0-py38h1de35cc_0
#   flake8                                       3.7.9-py37_0 --> 3.7.9-py38_0
#   future                                      0.18.2-py37_0 --> 0.18.2-py38_0
#   gevent                               1.4.0-py37h1de35cc_0 --> 1.3.7-py38h1de35cc_1
#   greenlet                            0.4.15-py37h1de35cc_0 --> 0.4.15-py38h1de35cc_0
#   h5py                                2.10.0-py37h3134771_0 --> 2.10.0-py38h3134771_0
#   imageio                                      2.6.1-py37_0 --> 2.6.1-py38_0
#   importlib_metadata                           1.5.0-py37_0 --> 1.5.0-py38_0
#   ipykernel                            5.1.4-py37h39e3cac_0 --> 5.1.4-py38h39e3cac_0
#   ipython                             7.12.0-py37h5ca1d4c_0 --> 7.12.0-py38h5ca1d4c_0
#   ipython_genutils                             0.2.0-py37_0 --> 0.2.0-py38_0
#   isort                                       4.3.21-py37_0 --> 4.3.21-py38_0
#   jedi                                        0.14.1-py37_0 --> 0.14.1-py38_0
#   jsonschema                                   3.2.0-py37_0 --> 3.2.0-py38_0
#   jupyter                                      1.0.0-py37_7 --> 1.0.0-py38_7
#   jupyter_client                               5.3.4-py37_0 --> 5.3.4-py38_0
#   jupyter_core                                 4.6.1-py37_0 --> 4.6.1-py38_0
#   keyring                                     21.1.0-py37_0 --> 21.1.0-py38_0
#   kiwisolver                           1.1.0-py37h0a44026_0 --> 1.0.1-py38h0a44026_0
#   lazy-object-proxy                    1.4.3-py37h1de35cc_0 --> 1.4.3-py38h1de35cc_0
#   llvmlite                            0.31.0-py37h1341992_0 --> 0.31.0-py38h1341992_0
#   locket                                       0.2.0-py37_1 --> 0.2.0-py38_1
#   lxml                                 4.5.0-py37hef8c89e_0 --> 4.5.0-py38hef8c89e_0
#   markupsafe                           1.1.1-py37h1de35cc_0 --> 1.1.1-py38h1de35cc_0
#   matplotlib                                   3.1.3-py37_0 --> 3.1.3-py38_0
#   matplotlib-base                      3.1.3-py37h9aa3819_0 --> 3.1.3-py38h9aa3819_0
#   mccabe                                       0.6.1-py37_1 --> 0.6.1-py38_1
#   mkl-service                          2.3.0-py37hfbe908c_0 --> 2.3.0-py38hfbe908c_0
#   mkl_fft                             1.0.15-py37h5e564d8_0 --> 1.0.15-py38h5e564d8_0
#   mkl_random                           1.1.0-py37ha771720_0 --> 1.1.0-py38h6440ff4_0
#   mpmath                                       1.1.0-py37_0 --> 1.1.0-py38_0
#   msgpack-python                       0.6.1-py37h04f5b5a_1 --> 0.6.1-py38h04f5b5a_1
#   multipledispatch                             0.6.0-py37_0 --> 0.6.0-py38_0
#   navigator-updater                            0.2.1-py37_0 --> 0.2.1-py38_0
#   nbconvert                                    5.6.1-py37_0 --> 5.6.1-py38_0
#   nltk                                         3.4.5-py37_0 --> 3.4.5-py38_0
#   nose                                         1.3.7-py37_2 --> 1.3.7-py38_2
#   notebook                                     6.0.3-py37_0 --> 6.0.3-py38_0
#   numba                               0.48.0-py37h6c726b0_0 --> 0.48.0-py38h6c726b0_0
#   numexpr                              2.7.1-py37hce01a72_0 --> 2.7.1-py38hce01a72_0
#   numpy                               1.18.1-py37h7241aed_0 --> 1.18.1-py38h7241aed_0
#   numpy-base                          1.18.1-py37h6575580_1 --> 1.18.1-py38h6575580_1
#   pandas                               1.0.1-py37h6c726b0_0 --> 1.0.1-py38h6c726b0_0
#   pandocfilters                                1.4.2-py37_1 --> 1.4.2-py38_1
#   path                                        13.1.0-py37_0 --> 13.1.0-py38_0
#   pathlib2                                     2.3.5-py37_0 --> 2.3.5-py38_0
#   patsy                                        0.5.1-py37_0 --> 0.5.1-py38_0
#   pep8                                         1.7.1-py37_0 --> 1.7.1-py38_0
#   pexpect                                      4.8.0-py37_0 --> 4.8.0-py38_0
#   pillow                               7.0.0-py37h4655f20_0 --> 7.0.0-py38h4655f20_0
#   pip                                         20.0.2-py37_1 --> 20.0.2-py38_1
#   pkginfo                                    1.5.0.1-py37_0 --> 1.5.0.1-py38_0
#   pluggy                                      0.13.1-py37_0 --> 0.13.1-py38_0
#   ply                                           3.11-py37_0 --> 3.11-py38_0
#   psutil                               5.6.7-py37h1de35cc_0 --> 5.6.7-py38h1de35cc_0
#   ptyprocess                                   0.6.0-py37_0 --> 0.6.0-py38_0
#   pycodestyle                                  2.5.0-py37_0 --> 2.5.0-py38_0
#   pycosat                              0.6.3-py37h1de35cc_0 --> 0.6.3-py38h1de35cc_0
#   pycurl                            7.43.0.5-py37ha12b0ac_0 --> 7.43.0.5-py38ha12b0ac_0
#   pyflakes                                     2.1.1-py37_0 --> 2.1.1-py38_0
#   pylint                                       2.4.4-py37_0 --> 2.4.4-py38_0
#   pyodbc                              4.0.30-py37h0a44026_0 --> 4.0.30-py38h0a44026_0
#   pyopenssl                                   19.1.0-py37_0 --> 19.1.0-py38_0
#   pyqt                                 5.9.2-py37h655552a_2 --> 5.9.2-py38h655552a_2
#   pyrsistent                          0.15.7-py37h1de35cc_0 --> 0.15.7-py38h1de35cc_0
#   pysocks                                      1.7.1-py37_0 --> 1.7.1-py38_0
#   pytables                             3.6.1-py37h5bccee9_0 --> 3.6.1-py38h4727e94_0
#   pytest                                       5.3.5-py37_0 --> 5.3.5-py38_0
#   pytest-arraydiff                       0.3-py37h39e3cac_0 --> 0.2-py38h39e3cac_0
#   pytest-remotedata                            0.3.2-py37_0 --> 0.3.2-py38_0
#   python-language-s~                          0.31.7-py37_0 --> 0.31.7-py38_0
#   python-libarchive~                            2.8-py37_13 --> 2.8-py38_7
#   python.app                                      2-py37_10 --> 2-py38_10
#   pywavelets                           1.1.1-py37h1de35cc_0 --> 1.1.1-py38h1de35cc_0
#   pyyaml                                 5.3-py37h1de35cc_0 --> 5.3-py38h1de35cc_0
#   pyzmq                               18.1.1-py37h0a44026_0 --> 18.1.1-py38h0a44026_0
#   requests                                    2.22.0-py37_1 --> 2.22.0-py38_1
#   rtree                                        0.9.3-py37_0 --> 0.9.3-py38_0
#   ruamel_yaml                        0.15.87-py37h1de35cc_0 --> 0.15.87-py38h1de35cc_0
#   scikit-image                        0.16.2-py37h6c726b0_0 --> 0.16.2-py38h6c726b0_0
#   scikit-learn                        0.22.1-py37h27c97d8_0 --> 0.22.1-py38h27c97d8_0
#   scipy                                1.4.1-py37h9fa6033_0 --> 1.4.1-py38h44e99c9_0
#   send2trash                                   1.5.0-py37_0 --> 1.5.0-py38_0
#   setuptools                                  46.0.0-py37_0 --> 46.0.0-py38_0
#   simplegeneric                                0.8.1-py37_2 --> 0.8.1-py38_2
#   singledispatch                             3.4.0.3-py37_0 --> 3.4.0.3-py38_0
#   sip                                 4.19.8-py37h0a44026_0 --> 4.19.8-py38h0a44026_0
#   six                                         1.14.0-py37_0 --> 1.14.0-py38_0
#   sortedcontainers                             2.1.0-py37_0 --> 2.1.0-py38_0
#   soupsieve                                    1.9.5-py37_0 --> 1.9.5-py38_0
#   sphinxcontrib                                  1.0-py37_1 --> 1.0-py38_1
#   spyder                                       4.0.1-py37_0 --> 4.0.1-py38_0
#   spyder-kernels                               1.8.1-py37_0 --> 1.8.1-py38_0
#   sqlalchemy                          1.3.13-py37h1de35cc_0 --> 1.3.13-py38h1de35cc_0
#   statsmodels                         0.11.0-py37h1de35cc_0 --> 0.11.0-py38h1de35cc_0
#   sympy                                        1.5.1-py37_0 --> 1.5.1-py38_0
#   terminado                                    0.8.3-py37_0 --> 0.8.3-py38_0
#   tornado                              6.0.3-py37h1de35cc_3 --> 6.0.3-py38h1de35cc_3
#   traitlets                                    4.3.3-py37_0 --> 4.3.3-py38_0
#   ujson                                 1.35-py37h1de35cc_0 --> 1.35-py38h1de35cc_0
#   unicodecsv                                  0.14.1-py37_0 --> 0.14.1-py38_0
#   urllib3                                     1.25.8-py37_0 --> 1.25.8-py38_0
#   watchdog                            0.10.2-py37h1de35cc_0 --> 0.10.2-py38h1de35cc_0
#   webencodings                                 0.5.1-py37_1 --> 0.5.1-py38_1
#   wheel                                       0.34.2-py37_0 --> 0.34.2-py38_0
#   widgetsnbextension                           3.5.1-py37_0 --> 3.5.1-py38_0
#   wrapt                               1.11.2-py37h1de35cc_0 --> 1.11.2-py38h1de35cc_0
#   wurlitzer                                    2.0.0-py37_0 --> 2.0.0-py38_0
#   xlwings                                     0.17.1-py37_0 --> 0.17.1-py38_0
#   xlwt                                         1.3.0-py37_0 --> 1.3.0-py38_0
#
#
#
# Downloading and Extracting Packages
# pyflakes-2.1.1       | 105 KB    | ##################################### | 100%
# pyopenssl-19.1.0     | 87 KB     | ##################################### | 100%
# matplotlib-base-3.1. | 4.9 MB    | ##################################### | 100%
# wrapt-1.11.2         | 50 KB     | ##################################### | 100%
# pyrsistent-0.15.7    | 91 KB     | ##################################### | 100%
# watchdog-0.10.2      | 98 KB     | ##################################### | 100%
# appscript-1.1.0      | 134 KB    | ##################################### | 100%
# ipython-7.12.0       | 977 KB    | ##################################### | 100%
# sphinxcontrib-1.0    | 4 KB      | ##################################### | 100%
# liblief-0.10.1       | 1.5 MB    | ##################################### | 100%
# backcall-0.1.0       | 21 KB     | ##################################### | 100%
# pyodbc-4.0.30        | 64 KB     | ##################################### | 100%
# pyqt-5.9.2           | 3.6 MB    | ##################################### | 100%
# multipledispatch-0.6 | 23 KB     | ##################################### | 100%
# flake8-3.7.9         | 168 KB    | ##################################### | 100%
# atomicwrites-1.3.0   | 10 KB     | ##################################### | 100%
# mkl_random-1.1.0     | 5 KB      | ##################################### | 100%
# python-libarchive-c- | 21 KB     | ##################################### | 100%
# matplotlib-3.1.3     | 21 KB     | ##################################### | 100%
# pluggy-0.13.1        | 33 KB     | ##################################### | 100%
# setuptools-46.0.0    | 522 KB    | ##################################### | 100%
# spyder-4.0.1         | 5.2 MB    | ##################################### | 100%
# nbconvert-5.6.1      | 453 KB    | ##################################### | 100%
# mkl_fft-1.0.15       | 138 KB    | ##################################### | 100%
# pycurl-7.43.0.5      | 68 KB     | ##################################### | 100%
# ipykernel-5.1.4      | 171 KB    | ##################################### | 100%
# spyder-kernels-1.8.1 | 93 KB     | ##################################### | 100%
# bitarray-1.2.1       | 80 KB     | ##################################### | 100%
# sortedcollections-1. | 11 KB     | ##################################### | 100%
# distributed-2.11.0   | 950 KB    | ##################################### | 100%
# pandas-1.0.1         | 7.9 MB    | ##################################### | 100%
# jupyter_core-4.6.1   | 67 KB     | ##################################### | 100%
# jupyter_client-5.3.4 | 140 KB    | ##################################### | 100%
# clyent-1.2.2         | 20 KB     | ##################################### | 100%
# mkl-service-2.3.0    | 42 KB     | ##################################### | 100%
# statsmodels-0.11.0   | 7.4 MB    | ##################################### | 100%
# send2trash-1.5.0     | 17 KB     | ##################################### | 100%
# patsy-0.5.1          | 275 KB    | ##################################### | 100%
# traitlets-4.3.3      | 138 KB    | ##################################### | 100%
# itsdangerous-1.1.0   | 17 KB     | ##################################### | 100%
# conda-package-handli | 1.5 MB    | ##################################### | 100%
# _ipyw_jlab_nb_ext_co | 192 KB    | ##################################### | 100%
# jsonschema-3.2.0     | 96 KB     | ##################################### | 100%
# kiwisolver-1.0.1     | 58 KB     | ##################################### | 100%
# pep8-1.7.1           | 53 KB     | ##################################### | 100%
# mistune-0.8.4        | 54 KB     | ##################################### | 100%
# wheel-0.34.2         | 51 KB     | ##################################### | 100%
# argh-0.26.2          | 36 KB     | ##################################### | 100%
# pylint-2.4.4         | 417 KB    | ##################################### | 100%
# singledispatch-3.4.0 | 16 KB     | ##################################### | 100%
# soupsieve-1.9.5      | 61 KB     | ##################################### | 100%
# cycler-0.10.0        | 14 KB     | ##################################### | 100%
# keyring-21.1.0       | 55 KB     | ##################################### | 100%
# ptyprocess-0.6.0     | 23 KB     | ##################################### | 100%
# notebook-6.0.3       | 4.0 MB    | ##################################### | 100%
# numexpr-2.7.1        | 122 KB    | ##################################### | 100%
# beautifulsoup4-4.8.2 | 163 KB    | ##################################### | 100%
# conda-build-3.20.5   | 543 KB    | ##################################### | 100%
# entrypoints-0.3      | 10 KB     | ##################################### | 100%
# numba-0.48.0         | 2.9 MB    | ##################################### | 100%
# gmpy2-2.0.8          | 159 KB    | ##################################### | 100%
# python.app-2         | 1.5 MB    | ##################################### | 100%
# pytest-arraydiff-0.2 | 15 KB     | ##################################### | 100%
# unicodecsv-0.14.1    | 27 KB     | ##################################### | 100%
# astropy-4.0          | 6.0 MB    | ##################################### | 100%
# pyzmq-18.1.1         | 405 KB    | ##################################### | 100%
# et_xmlfile-1.0.1     | 22 KB     | ##################################### | 100%
# anaconda-navigator-1 | 6.2 MB    | ##################################### | 100%
# cytoolz-0.10.1       | 316 KB    | ##################################### | 100%
# sortedcontainers-2.1 | 42 KB     | ##################################### | 100%
# ujson-1.35           | 32 KB     | ##################################### | 100%
# anaconda-2020.02     | 16 KB     | ##################################### | 100%
# greenlet-0.4.15      | 27 KB     | ##################################### | 100%
# pillow-7.0.0         | 568 KB    | ##################################### | 100%
# nose-1.3.7           | 217 KB    | ##################################### | 100%
# anaconda-client-1.7. | 154 KB    | ##################################### | 100%
# ply-3.11             | 80 KB     | ##################################### | 100%
# mccabe-0.6.1         | 15 KB     | ##################################### | 100%
# pyyaml-5.3           | 164 KB    | ##################################### | 100%
# terminado-0.8.3      | 25 KB     | ##################################### | 100%
# sqlalchemy-1.3.13    | 1.4 MB    | ##################################### | 100%
# sympy-1.5.1          | 8.4 MB    | ##################################### | 100%
# pysocks-1.7.1        | 28 KB     | ##################################### | 100%
# html5lib-1.0.1       | 91 KB     | ##################################### | 100%
# numpy-base-1.18.1    | 3.9 MB    | ##################################### | 100%
# pip-20.0.2           | 1.7 MB    | ##################################### | 100%
# lxml-4.5.0           | 1.2 MB    | ##################################### | 100%
# markupsafe-1.1.1     | 31 KB     | ##################################### | 100%
# asn1crypto-1.3.0     | 168 KB    | ##################################### | 100%
# pandocfilters-1.4.2  | 13 KB     | ##################################### | 100%
# webencodings-0.5.1   | 20 KB     | ##################################### | 100%
# boto-2.49.0          | 1.2 MB    | ##################################### | 100%
# cython-0.29.15       | 1.9 MB    | ##################################### | 100%
# chardet-3.0.4        | 174 KB    | ##################################### | 100%
# wurlitzer-2.0.0      | 14 KB     | ##################################### | 100%
# locket-0.2.0         | 9 KB      | ##################################### | 100%
# scikit-image-0.16.2  | 22.6 MB   | ##################################### | 100%
# alabaster-0.7.12     | 16 KB     | ##################################### | 100%
# bleach-3.1.0         | 111 KB    | ##################################### | 100%
# xlwings-0.17.1       | 433 KB    | ##################################### | 100%
# backports.shutil_get | 9 KB      | ##################################### | 100%
# isort-4.3.21         | 65 KB     | ##################################### | 100%
# urllib3-1.25.8       | 167 KB    | ##################################### | 100%
# pexpect-4.8.0        | 82 KB     | ##################################### | 100%
# imageio-2.6.1        | 3.2 MB    | ##################################### | 100%
# pickleshare-0.7.5    | 13 KB     | ##################################### | 100%
# scipy-1.4.1          | 13.0 MB   | ##################################### | 100%
# importlib_metadata-1 | 48 KB     | ##################################### | 100%
# six-1.14.0           | 26 KB     | ##################################### | 100%
# llvmlite-0.31.0      | 11.2 MB   | ##################################### | 100%
# olefile-0.46         | 33 KB     | ##################################### | 100%
# astroid-2.3.3        | 274 KB    | ##################################### | 100%
# navigator-updater-0. | 723 KB    | ##################################### | 100%
# cryptography-2.8     | 523 KB    | ##################################### | 100%
# pytest-5.3.5         | 369 KB    | ##################################### | 100%
# gevent-1.3.7         | 1.3 MB    | ##################################### | 100%
# pycrypto-2.6.1       | 371 KB    | ##################################### | 100%
# msgpack-python-0.6.1 | 77 KB     | ##################################### | 100%
# idna-2.8             | 88 KB     | ##################################### | 100%
# pkginfo-1.5.0.1      | 43 KB     | ##################################### | 100%
# pycodestyle-2.5.0    | 62 KB     | ##################################### | 100%
# ruamel_yaml-0.15.87  | 238 KB    | ##################################### | 100%
# future-0.18.2        | 642 KB    | ##################################### | 100%
# jedi-0.14.1          | 692 KB    | ##################################### | 100%
# requests-2.22.0      | 92 KB     | ##################################### | 100%
# simplegeneric-0.8.1  | 10 KB     | ##################################### | 100%
# bokeh-1.4.0          | 8.2 MB    | ##################################### | 100%
# conda-4.9.2          | 2.9 MB    | ##################################### | 100%
# pycparser-2.19       | 89 KB     | ##################################### | 100%
# nltk-3.4.5           | 1.7 MB    | ##################################### | 100%
# pytest-remotedata-0. | 14 KB     | ##################################### | 100%
# bottleneck-1.3.2     | 106 KB    | ##################################### | 100%
# xlwt-1.3.0           | 159 KB    | ##################################### | 100%
# widgetsnbextension-3 | 867 KB    | ##################################### | 100%
# lazy-object-proxy-1. | 35 KB     | ##################################### | 100%
# bkcharts-0.2         | 132 KB    | ##################################### | 100%
# click-7.0            | 68 KB     | ##################################### | 100%
# sip-4.19.8           | 239 KB    | ##################################### | 100%
# jupyter-1.0.0        | 7 KB      | ##################################### | 100%
# fastcache-1.1.0      | 35 KB     | ##################################### | 100%
# docutils-0.16        | 672 KB    | ##################################### | 100%
# numpy-1.18.1         | 5 KB      | ##################################### | 100%
# certifi-2019.11.28   | 153 KB    | ##################################### | 100%
# pytables-3.6.1       | 1.2 MB    | ##################################### | 100%
# appnope-0.1.0        | 8 KB      | ##################################### | 100%
# psutil-5.6.7         | 334 KB    | ##################################### | 100%
# h5py-2.10.0          | 833 KB    | ##################################### | 100%
# rtree-0.9.3          | 45 KB     | ##################################### | 100%
# python-language-serv | 75 KB     | ##################################### | 100%
# cffi-1.14.0          | 216 KB    | ##################################### | 100%
# mpmath-1.1.0         | 776 KB    | ##################################### | 100%
# pycosat-0.6.3        | 88 KB     | ##################################### | 100%
# xlrd-1.2.0           | 103 KB    | ##################################### | 100%
# pathlib2-2.3.5       | 36 KB     | ##################################### | 100%
# tornado-6.0.3        | 592 KB    | ##################################### | 100%
# scikit-learn-0.22.1  | 4.7 MB    | ##################################### | 100%
# pywavelets-1.1.1     | 3.4 MB    | ##################################### | 100%
# py-lief-0.10.1       | 1.1 MB    | ##################################### | 100%
# path-13.1.0          | 35 KB     | ##################################### | 100%
# ipython_genutils-0.2 | 39 KB     | ##################################### | 100%
# python-3.8.1         | 20.7 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# https://github.com/Qiskit/qiskit-ignis/issues/419

# %%
pip show qiskit
# Out:
# Name: qiskit
# Version: 0.22.0
# Summary: Software for developing quantum computing programs
# Home-page: https://github.com/Qiskit/qiskit
# Author: Qiskit Development Team
# Author-email: hello@qiskit.org
# License: Apache 2.0
# Location: /opt/anaconda3/lib/python3.8/site-packages
# Requires: qiskit-aqua, qiskit-terra, qiskit-ignis, qiskit-ibmq-provider, qiskit-aer
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import qiskit
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.15.2',
#  'qiskit-aer': '0.6.1',
#  'qiskit-ignis': '0.4.0',
#  'qiskit-ibmq-provider': '0.10.0',
#  'qiskit-aqua': '0.7.5',
#  'qiskit': '0.22.0'}

# %%
pip show pytket
# Out:
# Name: pytket
# Version: 0.6.1
# Summary: Python module for interfacing with the CQC t|ket> library of quantum software
# Home-page: https://cqcl.github.io/pytket
# Author: Seyon Sivarajah
# Author-email: seyon.sivarajah@cambridgequantum.com
# License: CQC Non-Commercial Use Software Licence
# Location: /opt/anaconda3/lib/python3.8/site-packages
# Requires: numpy, scipy, graphviz, lark-parser, openfermion, networkx, sympy
# Required-by: pytket-qiskit
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show pytket-qiskit
# Out:
# Name: pytket-qiskit
# Version: 0.6.1
# Summary: Extension for pytket, providing translation to and from the Qiskit framework
# Home-page: https://github.com/CQCL/pytket
# Author: Will Simmons
# Author-email: will.simmons@cambridgequantum.com
# License: CQC Non-Commercial Use Software Licence
# Location: /opt/anaconda3/lib/python3.8/site-packages
# Requires: qiskit, pytket
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show retworkx
# Out:
# Name: retworkx
# Version: 0.6.0
# Summary: A python graph library implemented in Rust
# Home-page: https://github.com/Qiskit/retworkx
# Author: Matthew Treinish
# Author-email: mtreinish@kortar.org
# License: Apache 2.0
# Location: /opt/anaconda3/lib/python3.8/site-packages
# Requires: numpy
# Required-by: qiskit-terra
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pylatexenc
# Out:
# Collecting pylatexenc
#   Downloading pylatexenc-2.8.tar.gz (158 kB)
#      |████████████████████████████████| 158 kB 4.6 MB/s eta 0:00:01
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.8-py3-none-any.whl size=131377 sha256=3e3627e1482f7bdd3be56e8165b1c3778c3a75be06f6fb3e8f4c194a49622621
#   Stored in directory: /Users/bigbangfourth/Library/Caches/pip/wheels/0c/40/cf/9346d76550d875ccb829bc5076927ad484caed8d85c9ffa225
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.8
# Note: you may need to restart the kernel to use updated packages.
